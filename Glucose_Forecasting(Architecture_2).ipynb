# %% [markdown]
# #Data

# %% [markdown]
# ##Exploration

# %% [markdown]
#   In this chapter, we are going to study the data that we are going to use to train and validate our models. We are going to preprocess the data too.
#
# First, we need to import our data from the drive:

# %%
import time

notebook_startime = time.time()
ARCHITECTURE_NUMBER=2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install --quiet hyperas

# %%
from google.colab import drive    #We first import the dataset from the drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
import random
import keras
import os

seed=0

def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(seed)

# %% [markdown]
# We need to import the dataset as a pandas dataframe

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/drive/MyDrive/Glucose_measurements_sample(1).csv')     #Import of the dataset as a pandas dataframe

# %% [markdown]
# Next, we need to join the Year/Month/Day column withe the Hour:Minute:Second column to create a single column with all the information of the dates tha we need

# %%
df['Measurement_date']=df['Measurement_date']+' '+df['Measurement_time']   #Joining of those two date columns in a single one
df=df.drop(columns=['Measurement_time'])         #Drop the Hour:Minute:Second column now that this information is contained in the 'Measurement_Date' column

# %%
df.head()      #Display of the whole dataframe
# Out:
#   Patient_ID     Measurement_date  Measurement
# 0  LIB193263  2020-06-09 19:08:00           99
# 1  LIB193263  2020-06-09 19:23:00           92
# 2  LIB193263  2020-06-09 19:38:00           86
# 3  LIB193263  2020-06-09 19:53:00           85
# 4  LIB193263  2020-06-09 20:08:00           85

# %%
df.describe()    #get some general statistics from the dataframe in question
# Out:
#         Measurement
# count  3.000000e+06
# mean   1.589509e+02
# std    6.543033e+01
# min    4.000000e+01
# 25%    1.100000e+02
# 50%    1.480000e+02
# 75%    1.970000e+02
# max    5.000000e+02

# %% [markdown]
# Each element of date column that we have just created next to be converted from string to TimeStamp

# %%
df['Measurement_date']=pd.to_datetime(df['Measurement_date'],format='%Y-%m-%d %H:%M:%S.%f')   #Conversion from string to timestamp

# %%
print(type(df['Measurement_date'][0]))                #Check if we have the 'Measurement_date' column in a timestamp format
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# Next, the date column that we just have converted to timestamp is going to be set as the index of our dataframe

# %%
df.set_index('Measurement_date', inplace = True)      #Making the whole date column the index of the dataframe

# %% [markdown]
# Making a simple visualization of the csv of the data

# %%
df.head()       #Visualization of the head of the dataframe
# Out:
#                     Patient_ID  Measurement
# Measurement_date
# 2020-06-09 19:08:00  LIB193263           99
# 2020-06-09 19:23:00  LIB193263           92
# 2020-06-09 19:38:00  LIB193263           86
# 2020-06-09 19:53:00  LIB193263           85
# 2020-06-09 20:08:00  LIB193263           85

# %% [markdown]
# Now, we can start playing with the dataframe to extract information. First, we are going to extract the number of different patients whose glucose time series are present in this dataframe by getting all the unique elements from the column 'Patient_ID', column that represents the patient to which the glucose measurement belongs to.

# %%
patients=df['Patient_ID'].unique()     #Getting the unique patients and putting them into a list of unique patients
print(len(patients))                   #Visualization of the number of unique patients of this dataset
# Out:
# 110

# %%
print(patients[0])                     #Print the first patient ID in the list
# Out:
# LIB193263

# %%
print(df.isnull().sum())               #Check the number of Nans that there are in the whole dataframe of patients. As we can see, we don't have to worry in Nan values.
# Out:
# Patient_ID     0
# Measurement    0
# dtype: int64

# %% [markdown]
# Now, we are going to take the glucose time series data related to the first patient of this list of unique patients. Next we are going to plot this timeseries with different frequencies, just so we can visualize the data which we are working with.

# %%
patient1 = df[df['Patient_ID'] == 'LIB193263']      #the glucose time series dataframe related to the first patient of the list of unique patients

# %% [markdown]
# We first make a visualization of the data in a little timespam, like a few hours

# %%
import matplotlib.pyplot as plt        #Simple matplotlib visualization of a patient levels of glucose time series in a relatively small time range
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
original_data=patient1['Measurement'][400:430]
ax.plot(patient1['Measurement'][400:430])
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 30]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.grid()
plt.show()

# %% [markdown]
# And them we are going to make a visualization of the data in a larger timespam, like a few days

# %%
import matplotlib.pyplot as plt       #Simple matplotlib visualization of a patient levels of glucose time series in a wider time range
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
ax.plot(patient1['Measurement'][:3000])
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.DayLocator(interval=3))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.grid()
plt.show()

# %% [markdown]
# And them, we need to append in a list the different timeseries related to every patient each one as a element of a list that will contain the dataframes of all patients differentiated

# %%
time_series_per_patient=[]     #List in which we are going to store the part of the dataframe related to each patient each one as a different element of this list

for patient in patients:
  time_series_per_patient.append(df[df['Patient_ID'] == patient])     #Appending the information related to each patient each one as a different element of this list

# %%
time_series_per_patient[0].head()              #check the time series correspondent to the first patient in the list
# Out:
#                     Patient_ID  Measurement
# Measurement_date
# 2020-06-09 19:08:00  LIB193263           99
# 2020-06-09 19:23:00  LIB193263           92
# 2020-06-09 19:38:00  LIB193263           86
# 2020-06-09 19:53:00  LIB193263           85
# 2020-06-09 20:08:00  LIB193263           85

# %% [markdown]
# ##Resampling

# %% [markdown]
# Now, we are going to measure the elements of every time series that are oversampled or undersampled, under and over 15 min, timestamp that have to be the sampling frequency of every time series. For those elements that are undersampled, we are going to take the missing values until the next value of glucose, because maybe if we miss one or two ticks of glucose measurement in a gap, we can interpolate this gap. For more ticks of missing values, we could treat this gap of missing values as a real gap that will not be interpolated, because if we interpolate two days of missing values of glucose, the dataset will change a lot in terms of reality, which is something that we dont want at all.

# %%
oversamples=[]              #list which contains a counter of oversample values for every patient
undersamples=[]             #list which contains a counter of undersample values for every patient
undersample_freq=[]         #list which contains the number of missing values in an undersampled gap

for time_series in time_series_per_patient:
  time_diff = time_series.index.to_series().diff()[1:]                              #list of sampling frequencies
  morethan15min_positions = time_diff[time_diff > pd.Timedelta(minutes=15)].index   #+1 index of those positions with a sampling frequency with more than 15 minutes of value
  lessthan15min_positions = time_diff[time_diff < pd.Timedelta(minutes=15)].index   #+1 index of those positions with a sampling frequency with less than 15 minutes of value
  oversamples.append(len(lessthan15min_positions))                                  #list of number of samples  with less than 15 minutes of sampling frequency from every every patient
  undersamples.append(len(morethan15min_positions))                                 #list of number of samples  with more than 15 minutes of sampling frequency from every every patient
  undersample_freq+=list(time_diff[time_diff > pd.Timedelta(minutes=15)])           #list of sampling frequency values that are over 15 minutes from every patient

# %%
print(np.sum(oversamples))        #Number of oversample values in the whole dataframe
print(np.sum(undersamples))       #Number of undersample values in the whole dataframe
# Out:
# 136533
# 167091

# %%
print(np.sum(pd.Series(undersample_freq) > pd.Timedelta(minutes=45)))     #If the gap of missing values is equal or less than 30 minutes, we are going to interpolate that gap
# Out:
# 16345

# %% [markdown]
# Then, we check the date of beginning and end of some time series correspondent to the first 5 patients in the list, the length of every time series and the length that every time series from every patient must have to obey an uniform sampling frequency. The uniform length is the length that the time series must have to achieve sampling every 15 minutes form start date to end date of the time series.
#
# Of course, with the resampling of these time series, we will do various things:
#
# 1- First, we are going to determine where the gaps with more that 45 minutes are, i.e. those gaps where more two values of glucose are missing, those gaps are going to be untouched. But next to finding where this gaps are, we are going to locate those gaps that are less or equal to 45 minutes, i.e. those gaps where there are two or one values missing and we are going to interpolate this gaps.
#
# 2- Next, we are going to correct uneven sampling frequencies. You see, the mayority of the samples of the time series are separated by 15 minutes, but some values are separated 16 minutes or 14 minutes or even less or more. We are going to make this values be separated by 15 minutes only with interpolating tools.
#
# by doing these steps in the resample phase of this work, we are most likely not to achieve this Uniform Length mencioned earlier, because, we are going to leave these more than 45 minutes gaps untouched, so at the end, the actual length of the time series of every patient will be most likely different to its uniform length.

# %%
for time_series in time_series_per_patient[:5]:
  print('Patient_ID:',time_series['Patient_ID'][0])
  print('Beggining datetime:',time_series.index[0])
  print('Ending datetime:',time_series.index[-1])
  print('Actual Length:',len(time_series))
  print('Uniform Length:',int((time_series.index[-1]-time_series.index[0])/pd.Timedelta(minutes=15)))
  print('TimeDelta:',(time_series.index[-1]-time_series.index[0]))
  print('--------------------------------\n')
# Out:
# Patient_ID: LIB193263
# Beggining datetime: 2020-06-09 19:08:00
# Ending datetime: 2022-03-19 07:32:00
# Actual Length: 60098
# Uniform Length: 62161
# TimeDelta: 647 days 12:24:00
# --------------------------------
#
# Patient_ID: LIB193264
# Beggining datetime: 2020-06-10 00:54:00
# Ending datetime: 2022-03-19 11:56:00
# Actual Length: 26787
# Uniform Length: 62156
# TimeDelta: 647 days 11:02:00
# --------------------------------
#
# Patient_ID: LIB193265
# Beggining datetime: 2019-01-27 10:52:00
# Ending datetime: 2022-03-19 22:04:00
# Actual Length: 46576
# Uniform Length: 110156
# TimeDelta: 1147 days 11:12:00
# --------------------------------
#
# Patient_ID: LIB193266
# Beggining datetime: 2020-10-08 18:03:00
# Ending datetime: 2022-03-21 12:09:00
# Actual Length: 55308
# Uniform Length: 50760
# TimeDelta: 528 days 18:06:00
# --------------------------------
#
# Patient_ID: LIB193267
# Beggining datetime: 2020-06-09 19:07:00
# Ending datetime: 2022-03-17 20:15:00
# Actual Length: 55501
# Uniform Length: 62020
# TimeDelta: 646 days 01:08:00
# --------------------------------

# %% [markdown]
# Next cell is to delete rare cases of duplicate values from every patient, i.e. timestamps where there are more than one glucose measurements in one patient. We are going to drop the column 'patient_ID' that we don't need because we have stored the patient's ID index and location in the 'patients' list.

# %%
#print(time_series_per_patient[0].loc['2020-06-10 09:20:00':])

for i in range(0,len(time_series_per_patient)):
  time_series_per_patient[i]= time_series_per_patient[i][~time_series_per_patient[i].index.duplicated(keep='first')]         #We are going to delete rare cases of duplicates from every patient's time series and we are going to keep the first value of the duplicate. For duplicate, we mean, various glucose measurements for one timestamp
  time_series_per_patient[i]=time_series_per_patient[i].drop(columns=['Patient_ID'])                                         #Drop the Patient_ID column, because the location of the patients_IDs are located in the 'patients' list

# %% [markdown]
# Next, we are going to reindex and resample between every gap of more than 45 minutes (leaving those gaps untouched) to have a uniform sampling frequency for every patient between those gaps.

# %%
for index,time_series in enumerate(time_series_per_patient):                                       #Loop from every patient's glucose time series
  time_diffs = time_series.index.to_series().diff()                                                #List of sampling frequencies from the current time series' iteration
  time_diffs=time_diffs.shift(periods=-1)                                                          #Shift this list so that value and sampling frequency correspond to each other
  morethan15min_positions = time_diffs[time_diffs > pd.Timedelta(minutes=45)].index                #Index of those positions where the gaps of missing data is more than 45 minutes

  last_datetime=time_series.index[0]                                                               #These two values are the last datetime index and the 'total_slice' parameter is where we are going to store current slices in the next loop
  total_slice=None

  for datetime in morethan15min_positions:                                                         #Loop through every gap of more that 45 minutes
    current_slice=time_series[last_datetime:datetime]                                              #This is the dataframe slice between gaps of more than 45 values of the current iteration
    #https://stackoverflow.com/questions/47148446/pandas-resample-interpolate-is-producing-nans
    oidx = current_slice.index                                                                     #Parameter where we are going to store the current slice index (old index)
    nidx = pd.date_range(oidx.min(), oidx[-1], freq='15T')                                         #Parameter where we are going to store the current slice index is there were a uniform sampling frequency of 15 minutes (new index)
    current_slice = current_slice.reindex(oidx.union(nidx)).interpolate('index').reindex(nidx)     #Current slice with the new index values interpolated from the values of the old index
    total_slice=pd.concat([total_slice, current_slice], axis=0)                                    #Store this resampled slice in the 'total_slice' parameter
    last_datetime=datetime+pd.Timedelta(seconds=1)                                                 #Update the 'last_datetime' parameter so the next current slice (in the next iteration) is located correctly

  time_series_per_patient[index]=total_slice                                                       #We are going to store the resampled and reindexed time series from every patient in the 'time_series_per_patient' list

# %%
import matplotlib.pyplot as plt        #Simple matplotlib visualization of the graph that we plotted earlier to check whether if the data keeps the coherence after getting resampled. We can see that the two graphs matches
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
ax.plot(time_series_per_patient[0]['Measurement'][400:430],label='Datos remuestreados')
ax.plot(original_data,label='Datos originales')
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 30]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# We check wether if we have created nans in the process of resampling, we can see in the next code cell that we haven created such nan values.

# %%
sumatory=0

for time_series in time_series_per_patient:
  sumatory+=int(time_series.isnull().sum())

print(sumatory)
# Out:
# 0

# %% [markdown]
# In the next code cell, we are going to check if we have values that are sampled over and less than 15 minutes.

# %%
oversamples=[]              #list which contains a counter of oversample values for every patient
undersamples=[]             #list which contains a counter of undersample values for every patient
undersample_freq=[]         #list which contains the number of missing values in an undersampled gap

for time_series in time_series_per_patient:
  time_diff = time_series.index.to_series().diff()[1:]
  morethan15min_positions = time_diff[time_diff > pd.Timedelta(minutes=15)].index
  lessthan15min_positions = time_diff[time_diff < pd.Timedelta(minutes=15)].index
  oversamples.append(len(lessthan15min_positions))
  undersamples.append(len(morethan15min_positions))
  undersample_freq+=list(time_diff[time_diff > pd.Timedelta(minutes=15)])

print(np.sum(oversamples))        #Number of oversample values in the whole dataframe
print(np.sum(undersamples))       #Number of undersample values in the whole dataframe
print(np.sum(pd.Series(undersample_freq) > pd.Timedelta(minutes=45)))     #If the gap of missing values is equal or less than 30 minutes, we are going to interpolate that gap
# Out:
# 0
# 16235
# 16235

# %% [markdown]
# We can observe that there are not values with less sampling frequency than 15 minutes, with only have samples over that value, other than the elements that are separated by a uniform 15 minutes, we only have elements which sampling frequency is over 15 minutes, and those gaps correspond to over 45 minutes gaps, i.e. more than two missing vale gaps. That is correct, because, as we said earlier we will only have one uniform sampling frequency other than the gaps over 45 minutes that will be untouched.

# %%
for index,time_series in enumerate(time_series_per_patient[:5]):
  print('Patient_ID:',patients[index])
  print('Beggining datetime:',time_series.index[0])
  print('Ending datetime:',time_series.index[-1])
  print('Actual Length:',len(time_series))
  print('Uniform Length:',int((time_series.index[-1]-time_series.index[0])/pd.Timedelta(minutes=15)))
  print('TimeDelta:',(time_series.index[-1]-time_series.index[0]))
  print('--------------------------------\n')
# Out:
# Patient_ID: LIB193263
# Beggining datetime: 2020-06-09 19:08:00
# Ending datetime: 2022-03-18 23:00:00
# Actual Length: 60157
# Uniform Length: 62127
# TimeDelta: 647 days 03:52:00
# --------------------------------
#
# Patient_ID: LIB193264
# Beggining datetime: 2020-06-10 00:54:00
# Ending datetime: 2022-03-18 20:16:00
# Actual Length: 26797
# Uniform Length: 62093
# TimeDelta: 646 days 19:22:00
# --------------------------------
#
# Patient_ID: LIB193265
# Beggining datetime: 2019-01-27 10:52:00
# Ending datetime: 2022-03-16 21:29:00
# Actual Length: 46381
# Uniform Length: 109866
# TimeDelta: 1144 days 10:37:00
# --------------------------------
#
# Patient_ID: LIB193266
# Beggining datetime: 2020-10-08 18:03:00
# Ending datetime: 2022-03-17 18:22:00
# Actual Length: 44514
# Uniform Length: 50401
# TimeDelta: 525 days 00:19:00
# --------------------------------
#
# Patient_ID: LIB193267
# Beggining datetime: 2020-06-09 19:07:00
# Ending datetime: 2022-03-17 07:43:00
# Actual Length: 54693
# Uniform Length: 61970
# TimeDelta: 645 days 12:36:00
# --------------------------------

# %% [markdown]
# We can observe that the actual length is not equal to the desired length (the length that the time series would have if we had measurements every 15 minutes non stop from start date to end date from the time series) because we have left the gaps over 45 minutes untouched.

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# The plan for the work is that the neural network uses a fit_generator function, so that we can utilize the GPU in the training of our neural network without running out of GPU memory in the way.
#
# To do that, we are going to take the time series of every patient, we are going to window every time series, and we are going to store within the folder 'src_folder' the windowed time series of every patient in a npy file (every patient will have a npy file named after its own patient_ID), this windowed time series must be of shape (len(time_series)-WINDOW_LENGTH+1,WINDOW_LENGTH, NUM_FEATURES), because we are working with an unidimensional time series, NUM_FEATURES must be equal to one.

# %%
import os

src_folder = "/content/windowed_dataset/"                                                   #The name of the folder where we are going to store the windowed time series of each patient

def create_folder(folder_name):                                                             #Function to create a directory only if that directory doesn't exist
  if not os.path.exists(folder_name):
      os.makedirs(folder_name)

create_folder(src_folder)                                                                   #Creation of the folder mentioned earlier
AHEAD_STEPS_PREDICTION=4                                                                    #Number of steps to predict ahead. In the case that we want to predict 1 hour ahead, AHEAD_STEPS_PREDICTION must be 4, because every value corresponds to the sampling frequency separation (15 minutes), 4 values ahead correspond to one hour ahead
WINDOW_STEPS=20                                                                              #Number of steps before the actual step we are going to take to input a window for the model to predict
PREDICTION_WINDOW=AHEAD_STEPS_PREDICTION+WINDOW_STEPS                                       #Add of these two parameters mentioned earlier                                                                         #Maybe we could take a normalization parameter to normalize those values that we are going to input our model
window_count=0

for patient_index,time_series in enumerate(time_series_per_patient):                        #Loop though every patient's glucose time series
  time_diffs = time_series.index.to_series().diff()                                         #Parameter where we are going to store the sampling frequency between every element of the current time series
  time_diffs=time_diffs.shift(periods=-1)                                                   #Shift of this parameter to make it correspong to every element of the current time series
  morethan15min_positions = time_diffs[time_diffs > pd.Timedelta(minutes=45)].index         #Those index position where there is a gap of data (over 45 minutes)
  last_datetime=time_series.index[0]                                                        #We set the last datetime of the slice to be the first index of the slice in the next loop's iterations

  for iter,datetime in enumerate(morethan15min_positions):                                  #Loop trough every gap of missing data (over 45 minutes)
    current_slice=time_series[last_datetime:datetime]                                       #Slice of time series between gaps of missing data (over 45 minutes)
    if len(current_slice)>=PREDICTION_WINDOW:                                               #If the current_slice of time series is bigger that the PREDICTION_WINDOW parameter, we can window this slice, so we keep ourselves in the loop
      windows=np.zeros((len(current_slice)-PREDICTION_WINDOW+1,PREDICTION_WINDOW,1))        #Array of zeros where we are going to store the current_slice of time series after being windowed
      for ind in range(0,len(current_slice)-PREDICTION_WINDOW+1):                           #Loop through the range of number of windows that we can create as from the current slice of time series
        windows[ind,:,:]=current_slice[ind:ind + PREDICTION_WINDOW]                         #We store the current window in the array of zeros mentioned earlier
      if iter==0:                                                                           #The general_windows parameter if where we are going to store all windows from all slices of data of the current patient. At the first slice, we initialize it as the windowed time_series of the current_slice of the current_slice
        general_windows=windows
      else:                                                                                 #But in the next slices we store the windowed current_slice with the last iteration general window with the numpy command 'concat' which allow us to update the 'general_windows' parameter without losing information at every iteration
        general_windows=np.concatenate((general_windows,windows),axis=0)
    last_datetime=datetime+pd.Timedelta(seconds=1)                                          #We update the next first datetime to index the next current_slice iteration

  np.save(src_folder+patients[patient_index],general_windows,allow_pickle=True)             #Next, we store the windowed time series of all of the current slices between gaps of missing data of each patient as a npy file named after the Patient's ID
  window_count+=np.shape(general_windows)[0]

print(np.shape(general_windows))                                                            #In order to check if everything is in order, we check the shape of the last windowed time series of the last patient of the iteration to check if the shape matches (n,PREDICTION_WINDOW,1), being n a parameter that changes in terms of the time series' length
print(window_count)                                                                         #Check number of windows
# Out:
# (5453, 24, 1)
# 2713333

# %% [markdown]
# ##Train/Test Data Split

# %% [markdown]
# The development of this Master's Thesis involves choosing a sample group of patients (between 5 and 10 patients), we are going to call this group of patients 'control group'.We need to train our 'from the scratch' model individually in the control group. Next we are going to take a pretrained model, pretrained with the rest odf the patients, when it is pretrained, we are going to train this pretrained model in the every patient of the control group individually.
#
# Finally, we are going to compare the performance of this 'from the scratch' model to the pretrained one, using different metrics.
# Ideally, the time series of the patients from  the control group must be long time series, to have a good portion of time range of the time series to test the performance of our models, for that, for the control group, we should take patients with time series with good length.

# %%
from sklearn.model_selection import train_test_split

CONTROL_GROUP_SIZE=5                                                                                               #Number of patients that will be in the control group

lengths=[]
for patient in patients:                                                                                           #A loop trough every filenames patient
  array=np.load(os.path.join(src_folder,patient)+'.npy',allow_pickle=True)                                         #Load its correspondent windowed dataset
  lengths.append(len(array))                                                                                       #Store its length in the self.lengths list

# Use sorted() to get a sorted version of the list along with their indices
sorted_numbers = sorted(enumerate(lengths), key=lambda x: x[1], reverse=True)

# Get the indices of the 5 highest values
highest_length_indices = [index for index, _ in sorted_numbers[:5]]

test_patients=[patients[index] for index in highest_length_indices]                                               #The test patients are those who have the five time series with more legth within all the patients
other_patients=[patients[index] for index in range(0,len(patients)) if index not in highest_length_indices]       #The train patients are the rest of the patients
train_patients,validation_patients=train_test_split(other_patients,test_size=0.2,random_state=0)
print(len(test_patients)+len(validation_patients)+len(train_patients))                                                                     #Check if the number of total patients is correct (It's correct, 110 patients, same as before)
# Out:
# 110

# %%
timestamps_test=[]
partial_timestamps=[]

for patient_index,patient in enumerate(test_patients):
  partial_timestamp=np.array(time_series_per_patient)[patients==patient]
  partial_timestamp=partial_timestamp[0].index
  partial_timestamps.append(partial_timestamp)
  timestamps_test+=list(partial_timestamp)

# %%
from keras.utils import Sequence

class Custom_Generator(Sequence) :

  def __init__(self, filenames, batch_size) :
    self.filenames = filenames                                                                             #The list of patients that we are going to take in our fit_generator
    self.lengths=[]                                                                                        #A list where the legths of every windowed time series of each filenames patient will be stored
    self.indexes=[0]                                                                                       # The indexes where the windowed time series of every each filenames patients end

    for filename in self.filenames:                                                                        #A loop trough every filenames patient
        array=np.load(os.path.join(src_folder,filename)+'.npy',allow_pickle=True)                          #Load its correspondent windowed dataset
        self.lengths.append(len(array))                                                                    #Store its length in the self.lengths list
        self.indexes.append(np.sum(self.lengths))                                                          #And store its ending index in the self.indexes list

    self.n_frames=np.sum(self.lengths)                                                                     #self.n_frames will be the number of windows that we are going to have in this fit_generator
    self.batch_size = batch_size                                                                           #Specification of the batch size as an argument of the class
    self.current_filename=self.filenames[0]                                                                #Specification of the name of the first patient windowed time series that we are going to feed to the neural network
    self.last_iter_index=0                                                                                 #Parameter which is going to tell us if we have reached the end of a windowed file initializated to zero
    self.windowed_file=np.load(os.path.join(src_folder,self.filenames[0])+'.npy',allow_pickle=True)        #the first patient windowed file that we are going to feed to the neural network

  def __len__(self) :                                                                                      #Method which simply returns the number of steps per epoch that we need to run through an epoch of data in this fit_generator
    return (np.floor(self.n_frames / float(self.batch_size))).astype(np.int)                               #The number of steps per epoch is going to be defined as the floor of the total number of windows that we have in this fit generator divided by its batch size

  def __getitem__(self, idx) :                                                                             #Method with give us batch in terms of the input parameter idx, in the training of a model, the range of values of idx should go from zero to the number of steps per epoch
    first_batch_index=idx * self.batch_size                                                                #These two parameters combined with the self.indexes and self.lengths can give us the correspondent batches from every time series
    second_batch_index=(idx+1) * self.batch_size

    first_index=np.sum(np.array(self.indexes)<=first_batch_index)-1                                        #Indexes that specify us where the first and last window of the batch is in terms of self.filenames index positions
    last_index=np.sum(np.array(self.indexes)<=second_batch_index)-1

    beginning_filename=self.filenames[first_index]                                                         #first and windowed time series name files where the first and last windows of time series belongs to in this current batch of data
    ending_filename=self.filenames[last_index]

    series_first_index=np.abs(self.indexes[first_index]-first_batch_index)                                 #indexes wich will help us locate the windows that we want to add in the current batch of windows
    series_last_index=np.abs(self.indexes[last_index]-second_batch_index)

    batch_x=np.zeros((self.batch_size,WINDOW_STEPS,1))                                                     #arrays of zeros where we are going to store our x and y values to feed batches to the model in which the fit generator is hooked on
    batch_y=np.zeros((self.batch_size,1))

    if first_index==0 and self.last_iter_index!=0:                                                         #When we are at the first patient windowed dataset but the last iteration was not the first windowed dataset, i.e. when idx have reached the value of steps per epoch and is reseting again from zero
      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[0])+'.npy',allow_pickle=True)      #We just set the first windowed dataset as the first patient windowed dataset without taking into account that the last windowed dataset was different

    if first_index!=0:                                                                                     #Explaining this later
      if self.last_iter_index!=first_index:
        self.windowed_file=np.load(os.path.join(src_folder,self.filenames[first_index])+'.npy',allow_pickle=True)

    if first_index==last_index:
      batch_x[:,:,:]=self.windowed_file[series_first_index:series_last_index,:WINDOW_STEPS,:]
      batch_y[:,:]=self.windowed_file[series_first_index:series_last_index,-1,:]
    elif np.abs(last_index-first_index)==1:
      len_first_slice=self.indexes[last_index]-first_batch_index
      batch_x[:len_first_slice,:,:]=self.windowed_file[series_first_index:,:WINDOW_STEPS,:]
      batch_y[:len_first_slice,:]=self.windowed_file[series_first_index:,-1,:]

      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[last_index])+'.npy',allow_pickle=True)

      batch_x[len_first_slice:,:,:]=self.windowed_file[:series_last_index,:WINDOW_STEPS,:]
      batch_y[len_first_slice:,:]=self.windowed_file[:series_last_index,-1,:]
    else:
      len_first_slice=self.indexes[first_index+1]-first_batch_index
      batch_x[:len_first_slice,:,:]=self.windowed_file[series_first_index:,:WINDOW_STEPS,:]
      batch_y[:len_first_slice,:]=self.windowed_file[series_first_index:,-1,:]
      last_slice=len_first_slice

      for i in range(first_index+1,last_index):
        self.windowed_file=np.load(os.path.join(src_folder,self.filenames[i])+'.npy',allow_pickle=True)
        #print(i)
        intermediate_array=self.windowed_file[:,:,:]
        batch_x[last_slice:last_slice+len(intermediate_array),:,:]=intermediate_array[:,:WINDOW_STEPS,:]
        batch_y[last_slice:last_slice+len(intermediate_array),:]=intermediate_array[:,-1,:]
        last_slice+=len(intermediate_array)

      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[last_index])+'.npy',allow_pickle=True)
      batch_x[last_slice:,:,:]=self.windowed_file[:series_last_index,:WINDOW_STEPS,:]
      batch_y[last_slice:,:]=self.windowed_file[:series_last_index,-1,:]

    #batch_x=batch_x
    #batch_y=denormalize(batch_y)
    batch=(batch_x,batch_y)
    self.last_iter_index=last_index
    return batch                                                                                                       #Returning the correspondent batch to the parameter idx

# %% [markdown]
# #Training

# %% [markdown]
# ##Neural Network Arquitecture

# %% [markdown]
# Next, It's the phase related to designing the model, training it, and extracting the correspondent results of metrics. First, the presentation of the design of the model that we have proposed for the development of this Master's Thesis.

# %%
import keras
import tensorflow as tf
from tensorflow.keras import layers

TOTAL_EPOCHS=15

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

def build_model(input_shape,head_size,num_heads,ff_dim,num_transformer_blocks,mlp_units,dropout=0,mlp_dropout=0):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    #x=layers.Lambda(lambda y: y * 400)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

input_shape=(WINDOW_STEPS,1)

def create_model():
  model = build_model(input_shape,head_size=256,num_heads=4,ff_dim=4,num_transformer_blocks=4,mlp_units=[128],mlp_dropout=0.4,dropout=0.25)
  return model

model=create_model()                        #Then, we just call this function to create the correspondent model and plot it for visualization
keras.utils.vis_utils.plot_model(model, show_shapes=True, show_layer_names=False)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 20, 1)]      0           []
#
#  multi_head_attention_4 (MultiH  (None, 20, 1)       7169        ['input_2[0][0]',
#  eadAttention)                                                    'input_2[0][0]']
#
#  dropout_9 (Dropout)            (None, 20, 1)        0           ['multi_head_attention_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 20, 1)       2           ['dropout_9[0][0]']
#  rmalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 20, 1)       0           ['layer_normalization_8[0][0]',
#  mbda)                                                            'input_2[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 20, 4)        8           ['tf.__operators__.add_8[0][0]']
#
#  dropout_10 (Dropout)           (None, 20, 4)        0           ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 20, 1)        5           ['dropout_10[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 20, 1)       2           ['conv1d_9[0][0]']
#  rmalization)
#
#  tf.__operators__.add_9 (TFOpLa  (None, 20, 1)       0           ['layer_normalization_9[0][0]',
#  mbda)                                                            'tf.__operators__.add_8[0][0]']
#
#  multi_head_attention_5 (MultiH  (None, 20, 1)       7169        ['tf.__operators__.add_9[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_9[0][0]']
#
#  dropout_11 (Dropout)           (None, 20, 1)        0           ['multi_head_attention_5[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 20, 1)       2           ['dropout_11[0][0]']
#  ormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 20, 1)       0           ['layer_normalization_10[0][0]',
#  ambda)                                                           'tf.__operators__.add_9[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 20, 4)        8           ['tf.__operators__.add_10[0][0]']
#
#  dropout_12 (Dropout)           (None, 20, 4)        0           ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 20, 1)        5           ['dropout_12[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 20, 1)       2           ['conv1d_11[0][0]']
#  ormalization)
#
#  tf.__operators__.add_11 (TFOpL  (None, 20, 1)       0           ['layer_normalization_11[0][0]',
#  ambda)                                                           'tf.__operators__.add_10[0][0]']
#
#  multi_head_attention_6 (MultiH  (None, 20, 1)       7169        ['tf.__operators__.add_11[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_11[0][0]']
#
#  dropout_13 (Dropout)           (None, 20, 1)        0           ['multi_head_attention_6[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 20, 1)       2           ['dropout_13[0][0]']
#  ormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 20, 1)       0           ['layer_normalization_12[0][0]',
#  ambda)                                                           'tf.__operators__.add_11[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 20, 4)        8           ['tf.__operators__.add_12[0][0]']
#
#  dropout_14 (Dropout)           (None, 20, 4)        0           ['conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 20, 1)        5           ['dropout_14[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 20, 1)       2           ['conv1d_13[0][0]']
#  ormalization)
#
#  tf.__operators__.add_13 (TFOpL  (None, 20, 1)       0           ['layer_normalization_13[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  multi_head_attention_7 (MultiH  (None, 20, 1)       7169        ['tf.__operators__.add_13[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_13[0][0]']
#
#  dropout_15 (Dropout)           (None, 20, 1)        0           ['multi_head_attention_7[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 20, 1)       2           ['dropout_15[0][0]']
#  ormalization)
#
#  tf.__operators__.add_14 (TFOpL  (None, 20, 1)       0           ['layer_normalization_14[0][0]',
#  ambda)                                                           'tf.__operators__.add_13[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 20, 4)        8           ['tf.__operators__.add_14[0][0]']
#
#  dropout_16 (Dropout)           (None, 20, 4)        0           ['conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 20, 1)        5           ['dropout_16[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 20, 1)       2           ['conv1d_15[0][0]']
#  ormalization)
#
#  tf.__operators__.add_15 (TFOpL  (None, 20, 1)       0           ['layer_normalization_15[0][0]',
#  ambda)                                                           'tf.__operators__.add_14[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 20)          0           ['tf.__operators__.add_15[0][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 128)          2688        ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dropout_17 (Dropout)           (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            129         ['dropout_17[0][0]']
#
# ==================================================================================================
# Total params: 31,561
# Trainable params: 31,561
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ##Hyperparameter Optimization

# %% [markdown]
# Next, It's the time to optimize the parameters that are involved in the compile of the model, like learning rate, optimizer and loss. It's just like doing a random walk to find this parameters, but instead, we are going to use an especialized library for optimization of parameters (hyperas library). We first create the fit_generators that we are going to use for this hyperparameter optimization.

# %%
train_generator=Custom_Generator(train_patients,128)    #Instantiation of Custon Generator mentioned earlier
validation_generator=Custom_Generator(validation_patients,128)
test_generator=Custom_Generator(test_patients,128)

# %% [markdown]
# Next, we perform hyperparameters oiptimization with the library that we mantioned earlier within the range that we set for every hyperparameter, for exple, for loss, we are only going to search in the space of 4 losses: msle, mse, mae and Huber.

# %%
from hyperas.distributions import choice,loguniform,uniform
from hyperopt import Trials, STATUS_OK, tpe
from keras import backend as K
from keras.backend import clear_session
from tqdm.notebook import tqdm

optimization_startime=time.time()

losses=['mse','mae','huber_loss','msle','mean_absolute_percentage_error']                              #We first define the search space to optimize parameters
optimizers=['SGD','RMSprop','Adam','Adagrad']
space_tf = {'loss': choice('loss',losses),'optimizer': choice('optimizer',optimizers),'learning_rate':loguniform('learning_rate',np.log(1e-8),np.log(0.6))}
#space_tf = {'dense_depth':uniform('dense_depth',5,20),'n_hidden_neurons': uniform('n_hidden_neurons',1000,3000),'loss': choice('loss',losses),'optimizer': choice('optimizer',optimizers),'learning_rate':loguniform('learning_rate',np.log(1e-6),np.log(0.6))}

max_evals=15                                                     #Max of evaluations over the parameters that we want to optimize
epochs_per_eval=1                                                #number of epoch that our neural network will perform in each evaluation of the optimization of the parameters
pbar = tqdm(total=max_evals*epochs_per_eval, desc="Hyperopt")    #Custom loading bar to visualize the progress of the optimization algorithm

def create_optimized_model(space_sample):                        #Function to evaluate the performance of the algorithm with a set of hyperparameters to optimize. In this case, those parameters are the optimizer, the loos and the learning rate
    global pbar                                                  #This function just creates a model and lets it run truogh one epoch of out fit generator with with different hyperparameter combinations, those hyperparameters are in fact, the ones that we want to optimize
    clear_session()
    tf.random.set_seed(0)

    #dense_depth=int(space_sample['dense_depth'])
    #n_hidden_neurons=int(space_sample['n_hidden_neurons'])
    loss=space_sample['loss']
    optimizer=space_sample['optimizer']
    learning_rate=space_sample['learning_rate']

    model=create_model()     #n_hidden_neurons,dense_depth)
    model.compile(loss=loss,optimizer=optimizer,metrics=['mse'])
    K.set_value(model.optimizer.learning_rate, learning_rate)

    history=model.fit_generator(train_generator,epochs=epochs_per_eval,steps_per_epoch=int(train_generator.__len__()),verbose=0,shuffle=False)
    acc=np.amin(history.history['mse'])
    pbar.update()
    return acc                                                  #This function just returns the minimum loss reached trough one epoch

from hyperopt import tpe, fmin

best_classifier = fmin(create_optimized_model, space_tf, algo=tpe.suggest, max_evals=max_evals)    #function to return the best combination of hyperparameters that the earlier algorithm has reached
pbar.close()                                                                                       #Closes the progress bar

print('_________________________')

print(best_classifier)
print('Loss:',losses[best_classifier['loss']])
print('Optimizer:',optimizers[best_classifier['optimizer']])                                                                          #Print of the best combination of hyperparameters that we have reached in this cell of code
print('Learning Rate:',float(best_classifier['learning_rate']))

optimization_endtime=time.time()
optimization_time=(optimization_endtime-optimization_startime)
# Out:
# Hyperopt:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
#   7%|▋         | 1/15 [05:06<1:11:26, 306.17s/trial, best loss: 21030.990234375]
#  13%|█▎        | 2/15 [10:35<1:09:17, 319.79s/trial, best loss: 21030.990234375]
#  20%|██        | 3/15 [15:26<1:01:20, 306.70s/trial, best loss: 21030.990234375]
#  27%|██▋       | 4/15 [20:18<55:08, 300.76s/trial, best loss: 21030.990234375]
#  33%|███▎      | 5/15 [25:47<51:50, 311.01s/trial, best loss: 6931.14404296875]
#  40%|████      | 6/15 [30:37<45:36, 304.04s/trial, best loss: 6931.14404296875]
#  47%|████▋     | 7/15 [36:04<41:31, 311.46s/trial, best loss: 2219.01953125]
#  53%|█████▎    | 8/15 [41:18<36:25, 312.19s/trial, best loss: 2219.01953125]
#  60%|██████    | 9/15 [46:19<30:51, 308.62s/trial, best loss: 1949.8662109375]
#  67%|██████▋   | 10/15 [51:47<26:13, 314.79s/trial, best loss: 1949.8662109375]
#  73%|███████▎  | 11/15 [57:14<21:14, 318.50s/trial, best loss: 1949.8662109375]
#  80%|████████  | 12/15 [1:02:05<15:29, 309.94s/trial, best loss: 1949.8662109375]
#  87%|████████▋ | 13/15 [1:06:57<10:09, 304.57s/trial, best loss: 1797.329345703125]
#  93%|█████████▎| 14/15 [1:11:52<05:01, 301.66s/trial, best loss: 1797.329345703125]
# 100%|██████████| 15/15 [1:16:59<00:00, 307.95s/trial, best loss: 1797.329345703125]
# _________________________
# {'learning_rate': 0.0008227686725569347, 'loss': 2, 'optimizer': 1}
# Loss: huber_loss
# Optimizer: RMSprop
# Learning Rate: 0.0008227686725569347

# %% [markdown]
# ##Pretraining Phase

# %% [markdown]
# In this part of the notebook, we are going to pretrain a model with the optimized combination of hyperparameters that we have searched earlier with the time series data of the patients not belonging to the control group.

# %%
pretraining_startime=time.time()
loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
optimizer=optimizers[best_classifier['optimizer']]
learning_rate=float(best_classifier['learning_rate'])
EPOCHS=TOTAL_EPOCHS                                                     #define the number of epochs in which we want to pretrain the model for the next individual trainings in the patients of the control group

metrics=[tf.keras.losses.Huber(),tf.keras.losses.MeanSquaredError(),tf.keras.losses.MeanAbsoluteError(),tf.keras.losses.MeanAbsolutePercentageError(),
         tf.keras.losses.MeanSquaredLogarithmicError(),tf.keras.losses.LogCosh()]        #Define of some metrics that we could use to evaluate our models

tf.random.set_seed(0)                                         #set random set of tensorflow
model=create_model()                                          #create one neural network from scratch with our function 'create_model()'
model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
K.set_value(model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

checkpoint_folder='/content/drive/MyDrive/Checkpoint/'        #drive folder name where we are going to save our pretrained model, and to prevent executing this pretraining every time we want to execute this notebook
create_folder(checkpoint_folder)                              #create folder
model_checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_folder+'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',save_best_only=True,monitor='val_loss',mode='auto')  #save model callback in such folder mentioned in the above lines

history=model.fit_generator(train_generator,shuffle=False,epochs=EPOCHS,steps_per_epoch=int(train_generator.__len__()),validation_data=validation_generator,validation_steps=int(validation_generator.__len__()),verbose=1,callbacks=[model_checkpoint_callback])     #pretrain this model with that callback
pretraining_endtime=time.time()
pretraining_time=(pretraining_endtime-pretraining_startime)
# Out:
# Epoch 1/15
# 14461/14461 [==============================] - 384s 26ms/step - loss: 31.3076 - huber_loss: 31.3076 - mean_squared_error: 1800.4006 - mean_absolute_error: 31.8037 - mean_absolute_percentage_error: 21.0515 - mean_squared_logarithmic_error: 0.0804 - log_cosh: 31.1203 - val_loss: 30.3086 - val_huber_loss: 30.3086 - val_mean_squared_error: 1717.2039 - val_mean_absolute_error: 30.8043 - val_mean_absolute_percentage_error: 19.8783 - val_mean_squared_logarithmic_error: 0.0696 - val_log_cosh: 30.1217
# Epoch 2/15
# 14461/14461 [==============================] - 349s 24ms/step - loss: 29.8104 - huber_loss: 29.8104 - mean_squared_error: 1628.6658 - mean_absolute_error: 30.3064 - mean_absolute_percentage_error: 20.1228 - mean_squared_logarithmic_error: 0.0694 - log_cosh: 29.6231 - val_loss: 28.9611 - val_huber_loss: 28.9611 - val_mean_squared_error: 1578.7454 - val_mean_absolute_error: 29.4567 - val_mean_absolute_percentage_error: 19.4920 - val_mean_squared_logarithmic_error: 0.0645 - val_log_cosh: 28.7744
# Epoch 3/15
# 14461/14461 [==============================] - 345s 24ms/step - loss: 29.4100 - huber_loss: 29.4100 - mean_squared_error: 1585.9575 - mean_absolute_error: 29.9060 - mean_absolute_percentage_error: 19.8900 - mean_squared_logarithmic_error: 0.0674 - log_cosh: 29.2228 - val_loss: 30.1200 - val_huber_loss: 30.1200 - val_mean_squared_error: 1701.5427 - val_mean_absolute_error: 30.6157 - val_mean_absolute_percentage_error: 19.6497 - val_mean_squared_logarithmic_error: 0.0668 - val_log_cosh: 29.9331
# Epoch 4/15
# 14461/14461 [==============================] - 346s 24ms/step - loss: 29.1652 - huber_loss: 29.1652 - mean_squared_error: 1560.6091 - mean_absolute_error: 29.6611 - mean_absolute_percentage_error: 19.7580 - mean_squared_logarithmic_error: 0.0662 - log_cosh: 28.9781 - val_loss: 29.3532 - val_huber_loss: 29.3532 - val_mean_squared_error: 1624.0895 - val_mean_absolute_error: 29.8489 - val_mean_absolute_percentage_error: 19.2878 - val_mean_squared_logarithmic_error: 0.0642 - val_log_cosh: 29.1665
# Epoch 5/15
# 14461/14461 [==============================] - 346s 24ms/step - loss: 28.9302 - huber_loss: 28.9302 - mean_squared_error: 1537.2064 - mean_absolute_error: 29.4260 - mean_absolute_percentage_error: 19.6057 - mean_squared_logarithmic_error: 0.0652 - log_cosh: 28.7430 - val_loss: 30.3089 - val_huber_loss: 30.3089 - val_mean_squared_error: 1722.9940 - val_mean_absolute_error: 30.8046 - val_mean_absolute_percentage_error: 19.5755 - val_mean_squared_logarithmic_error: 0.0666 - val_log_cosh: 30.1219
# Epoch 6/15
# 14461/14461 [==============================] - 344s 24ms/step - loss: 28.7283 - huber_loss: 28.7283 - mean_squared_error: 1518.0308 - mean_absolute_error: 29.2242 - mean_absolute_percentage_error: 19.4793 - mean_squared_logarithmic_error: 0.0643 - log_cosh: 28.5412 - val_loss: 32.8709 - val_huber_loss: 32.8709 - val_mean_squared_error: 1995.3311 - val_mean_absolute_error: 33.3669 - val_mean_absolute_percentage_error: 20.3537 - val_mean_squared_logarithmic_error: 0.0745 - val_log_cosh: 32.6834
# Epoch 7/15
# 14461/14461 [==============================] - 347s 24ms/step - loss: 28.5315 - huber_loss: 28.5315 - mean_squared_error: 1499.9343 - mean_absolute_error: 29.0274 - mean_absolute_percentage_error: 19.3494 - mean_squared_logarithmic_error: 0.0635 - log_cosh: 28.3445 - val_loss: 30.4893 - val_huber_loss: 30.4893 - val_mean_squared_error: 1740.3605 - val_mean_absolute_error: 30.9851 - val_mean_absolute_percentage_error: 19.5580 - val_mean_squared_logarithmic_error: 0.0668 - val_log_cosh: 30.3024
# Epoch 8/15
# 14461/14461 [==============================] - 351s 24ms/step - loss: 28.3724 - huber_loss: 28.3724 - mean_squared_error: 1485.3186 - mean_absolute_error: 28.8681 - mean_absolute_percentage_error: 19.2506 - mean_squared_logarithmic_error: 0.0628 - log_cosh: 28.1853 - val_loss: 31.5938 - val_huber_loss: 31.5938 - val_mean_squared_error: 1859.2206 - val_mean_absolute_error: 32.0897 - val_mean_absolute_percentage_error: 19.8662 - val_mean_squared_logarithmic_error: 0.0700 - val_log_cosh: 31.4068
# Epoch 9/15
# 14461/14461 [==============================] - 345s 24ms/step - loss: 28.1829 - huber_loss: 28.1829 - mean_squared_error: 1469.8475 - mean_absolute_error: 28.6786 - mean_absolute_percentage_error: 19.1249 - mean_squared_logarithmic_error: 0.0621 - log_cosh: 27.9960 - val_loss: 29.9347 - val_huber_loss: 29.9347 - val_mean_squared_error: 1682.0726 - val_mean_absolute_error: 30.4304 - val_mean_absolute_percentage_error: 19.4485 - val_mean_squared_logarithmic_error: 0.0652 - val_log_cosh: 29.7478
# Epoch 10/15
# 14461/14461 [==============================] - 346s 24ms/step - loss: 28.0316 - huber_loss: 28.0316 - mean_squared_error: 1456.9850 - mean_absolute_error: 28.5273 - mean_absolute_percentage_error: 19.0181 - mean_squared_logarithmic_error: 0.0615 - log_cosh: 27.8446 - val_loss: 31.2669 - val_huber_loss: 31.2669 - val_mean_squared_error: 1823.8136 - val_mean_absolute_error: 31.7627 - val_mean_absolute_percentage_error: 19.7593 - val_mean_squared_logarithmic_error: 0.0689 - val_log_cosh: 31.0799
# Epoch 11/15
# 14461/14461 [==============================] - 345s 24ms/step - loss: 27.9080 - huber_loss: 27.9080 - mean_squared_error: 1446.5790 - mean_absolute_error: 28.4036 - mean_absolute_percentage_error: 18.9289 - mean_squared_logarithmic_error: 0.0610 - log_cosh: 27.7210 - val_loss: 30.9102 - val_huber_loss: 30.9102 - val_mean_squared_error: 1786.6866 - val_mean_absolute_error: 31.4061 - val_mean_absolute_percentage_error: 19.6895 - val_mean_squared_logarithmic_error: 0.0678 - val_log_cosh: 30.7232
# Epoch 12/15
# 14461/14461 [==============================] - 357s 25ms/step - loss: 27.8255 - huber_loss: 27.8255 - mean_squared_error: 1439.4863 - mean_absolute_error: 28.3212 - mean_absolute_percentage_error: 18.8723 - mean_squared_logarithmic_error: 0.0606 - log_cosh: 27.6387 - val_loss: 31.2171 - val_huber_loss: 31.2171 - val_mean_squared_error: 1826.1519 - val_mean_absolute_error: 31.7129 - val_mean_absolute_percentage_error: 19.7747 - val_mean_squared_logarithmic_error: 0.0687 - val_log_cosh: 31.0301
# Epoch 13/15
# 14461/14461 [==============================] - 368s 25ms/step - loss: 27.6430 - huber_loss: 27.6430 - mean_squared_error: 1423.7755 - mean_absolute_error: 28.1386 - mean_absolute_percentage_error: 18.7582 - mean_squared_logarithmic_error: 0.0599 - log_cosh: 27.4562 - val_loss: 30.8606 - val_huber_loss: 30.8606 - val_mean_squared_error: 1779.5593 - val_mean_absolute_error: 31.3564 - val_mean_absolute_percentage_error: 19.6782 - val_mean_squared_logarithmic_error: 0.0675 - val_log_cosh: 30.6736
# Epoch 14/15
# 14461/14461 [==============================] - 348s 24ms/step - loss: 27.5178 - huber_loss: 27.5178 - mean_squared_error: 1414.8158 - mean_absolute_error: 28.0134 - mean_absolute_percentage_error: 18.6563 - mean_squared_logarithmic_error: 0.0595 - log_cosh: 27.3311 - val_loss: 30.8235 - val_huber_loss: 30.8235 - val_mean_squared_error: 1782.3345 - val_mean_absolute_error: 31.3192 - val_mean_absolute_percentage_error: 19.6146 - val_mean_squared_logarithmic_error: 0.0674 - val_log_cosh: 30.6365
# Epoch 15/15
# 14461/14461 [==============================] - 351s 24ms/step - loss: 27.4292 - huber_loss: 27.4292 - mean_squared_error: 1406.7247 - mean_absolute_error: 27.9247 - mean_absolute_percentage_error: 18.6029 - mean_squared_logarithmic_error: 0.0591 - log_cosh: 27.2425 - val_loss: 31.3377 - val_huber_loss: 31.3377 - val_mean_squared_error: 1833.2103 - val_mean_absolute_error: 31.8336 - val_mean_absolute_percentage_error: 19.7817 - val_mean_squared_logarithmic_error: 0.0687 - val_log_cosh: 31.1507

# %%
print(list(history.history.keys()))
print(list(history.history.keys())[1:7])
# Out:
# ['loss', 'huber_loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'log_cosh', 'val_loss', 'val_huber_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_mean_absolute_percentage_error', 'val_mean_squared_logarithmic_error', 'val_log_cosh']
# ['huber_loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'log_cosh']

# %% [markdown]
# This is not relevant for the Master's Thesis, but we can check out some metrics in the pretraining phase, to check wether if our model is learning while in the pretraining phase

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

keys=list(history.history.keys())[1:7]

plt.style.use("ggplot")
fig, axs = plt.subplots(3, 2, sharex=True, sharey=False, figsize=(10, 15))
fig.suptitle(t='Arquitectura '+str(ARCHITECTURE_NUMBER),y=1)
fig.supxlabel('Episodios de Entrenamiento')
fig.tight_layout()

for key_index,key in enumerate(keys):
  column=key_index%2
  row=int(key_index/2)

  axs[row,column].plot(np.arange(1,EPOCHS+1),history.history[key],label='Preentrenamiento')
  axs[row,column].plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='Validación')
  axs[row,column].grid(which='major', color='white', linewidth=1.2)
  axs[row,column].set_ylabel(key.replace("_", " " ).title())
  axs[row,column].ticklabel_format(axis="y", style="sci", scilimits=(0,0))

  if column==1:
    axs[row,column].yaxis.set_label_coords(-0.07,0.5)

  if row==0 and column==0:
    axs[row,column].legend(loc='upper center', bbox_to_anchor=(0.2, 1.20), fancybox=True, shadow=True)

plt.show()

'''
for key_index,key in list(history.history.keys())[1:7]:
  fig, ax = plt.subplots()                               #simple matplotlib visualization of the performance in training loss of the model over the training epochs
  ax.plot(np.arange(1,EPOCHS+1),history.history[key],label=key)
  ax.plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='val_'+key)
  ax.xaxis.set_major_locator(MaxNLocator(integer=True))
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid()
  plt.show()
  print('------------------------')
'''
# Out:
# "\nfor key_index,key in list(history.history.keys())[1:7]:\n  fig, ax = plt.subplots()                               #simple matplotlib visualization of the performance in training loss of the model over the training epochs\n  ax.plot(np.arange(1,EPOCHS+1),history.history[key],label=key)\n  ax.plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='val_'+key)\n  ax.xaxis.set_major_locator(MaxNLocator(integer=True))\n  plt.xlabel('Epochs')\n  plt.ylabel('Loss')\n  plt.legend()\n  plt.grid()\n  plt.show()\n  print('------------------------')\n"

# %%
test_history=model.evaluate_generator(test_generator,steps=int(test_generator.__len__()))

# %%
print(test_history)
# Out:
# [25.299240112304688, 25.299240112304688, 1241.393310546875, 25.794214248657227, 17.194110870361328, 0.05416828393936157, 25.113670349121094]

# %% [markdown]
# And yet, in this situation, we can visualize the predictions of the model over the patients in the control group, patients that our model have not yet seen. We can check visually with a simple matplotlib graph wether this predictions have some coherence comparing with the ground truth of the data over some patients in the control group.

# %%
pretrained_model = keras.models.load_model(checkpoint_folder + 'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',compile=False)

loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
optimizer=optimizers[best_classifier['optimizer']]
learning_rate=float(best_classifier['learning_rate'])

pretrained_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
K.set_value(pretrained_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

# %%
test_generator=Custom_Generator([test_patients[0]],1)     #create a fit generator over patients in the control group with batch size equal to 1

# %%
import matplotlib.pyplot as plt

X_test=np.array([np.squeeze(test_generator.__getitem__(i)[0]) for i in range(0,int(test_generator.__len__()-1))])   #we first extract the X data and the ground truth from the test generator
Y_test=np.array([np.squeeze(test_generator.__getitem__(i)[1]) for i in range(0,int(test_generator.__len__()-1))])
#X_test=denormalize(X_test)
#Y_test=denormalize(Y_test)

print(np.shape(X_test))   #Check those shapes to observe if it have coherence over the sahpe that it have to have (number of windows,WINDOW_LENGTH,1)
print(np.shape(Y_test))   #(number of windows,1)
# Out:
# (102546, 20)
# (102546,)

# %%
predictions=model.predict(X_test[:80])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()
ax.plot(timestamps_test[:80],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[:80],Y_test[:80],label='Datos Reales',color='orange')

#ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 20]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 1s 32ms/step

# %%
predictions=model.predict(X_test[100:180])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()

ax.plot(timestamps_test[100:180],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[100:180],Y_test[100:180],label='Datos Reales',color='orange')

ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %%
predictions=model.predict(X_test[300:380])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()

ax.plot(timestamps_test[300:380],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[300:380],Y_test[300:380],label='Datos Reales',color='orange')

ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 0s 6ms/step

# %% [markdown]
# ##Pretrained Model vs From the Scratch Model

# %% [markdown]
# Now, we are going to try to train individually in each patient from the control group. We are going o try to do that without fit generator, fit generator was aahelpful tool to train the neural network trough all the patients with a single call and without having to worry about GPU memory, now, we are going to try to work with this data without fit generator, which is more helpful for individually training.

# %%
training_startime=time.time()
pretrained_metrics=[]                                                                             #Lists where we are going to store the control group patients metrics for the pretrained and the 'from the scratch' model
fromthescratch_metrics=[]
test_pretrained_metrics=[]                                                                             #Lists where we are going to store the control group patients metrics for the pretrained and the 'from the scratch' model
test_fromthescratch_metrics=[]

for ind,patient in enumerate(test_patients):                                                                      #A loop trough every filenames patient
  print(str(ind)+'-'+(patient)+'\n')

  pretrained_model = keras.models.load_model(checkpoint_folder + 'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',compile=False)#custom_objects={"Huber": tf.keras.losses.Huber() })    #Load the pretrained model and create a 'from the scratch' model
  fromthescratch_model=create_model()
  loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
  optimizer=optimizers[best_classifier['optimizer']]
  learning_rate=float(best_classifier['learning_rate'])
  fromthescratch_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
  K.set_value(fromthescratch_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier
  pretrained_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
  K.set_value(pretrained_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

  windowed_data=np.load(os.path.join(src_folder,patient)+'.npy',allow_pickle=True)                          #Load its correspondent windowed dataset
  X=np.array([window[:WINDOW_STEPS,:] for window in windowed_data])
  Y=np.array([window[-1,:] for window in windowed_data])

  X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False, random_state=42)

  print('PRETRAINED_MODEL')
  pretrained_history=pretrained_model.fit(x=X_train,y=y_train,shuffle=False,epochs=TOTAL_EPOCHS,batch_size=32,validation_split=0.1,verbose=1)
  print('\nFROMTHESCRATCH_MODEL')
  fromthescratch_history=fromthescratch_model.fit(x=X_train,y=y_train,shuffle=False,epochs=TOTAL_EPOCHS,batch_size=32,validation_split=0.1,verbose=1)

  test_pretrained_history=pretrained_model.evaluate(x=X_test,y=y_test,batch_size=32)
  test_fromthescratch_history=fromthescratch_model.evaluate(x=X_test,y=y_test,batch_size=32)

  pretrained_metrics.append(pretrained_history)
  fromthescratch_metrics.append(fromthescratch_history)
  test_pretrained_metrics.append(test_pretrained_history)
  test_fromthescratch_metrics.append(test_fromthescratch_history)

  Y_pretrained_prediction=pretrained_model.predict(X_test)
  Y_fromthescratch_prediction=fromthescratch_model.predict(X_test)
  plt.plot(partial_timestamps[ind][:300],Y_pretrained_prediction[:300],label='Predicciones Preentrenadas')
  plt.plot(partial_timestamps[ind][:300],Y_fromthescratch_prediction[:300],label='Predicciones sin Preentrenar')
  plt.plot(partial_timestamps[ind][:300],Y_test[:300],label='Datos Reales')
  plt.legend()
  plt.ylabel('Nivel de Glucosa [mg/dL]')
  plt.xlabel('Tiempo')
  plt.grid(which='major', color='white', linewidth=1.2)
  plt.show()

  print('\n-------------------------------------------------------\n')

training_endtime=time.time()
training_time=(training_endtime-training_startime)
# Out:
# 0-LIB193277
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2308/2308 [==============================] - 61s 21ms/step - loss: 21.5964 - huber_loss: 21.5955 - mean_squared_error: 846.5991 - mean_absolute_error: 22.0903 - mean_absolute_percentage_error: 18.6170 - mean_squared_logarithmic_error: 0.0585 - log_cosh: 21.4101 - val_loss: 16.9870 - val_huber_loss: 16.9935 - val_mean_squared_error: 517.1707 - val_mean_absolute_error: 17.4876 - val_mean_absolute_percentage_error: 16.5790 - val_mean_squared_logarithmic_error: 0.0404 - val_log_cosh: 16.8090
# Epoch 2/15
# 2308/2308 [==============================] - 45s 20ms/step - loss: 21.5880 - huber_loss: 21.5859 - mean_squared_error: 842.6574 - mean_absolute_error: 22.0806 - mean_absolute_percentage_error: 18.5761 - mean_squared_logarithmic_error: 0.0582 - log_cosh: 21.4004 - val_loss: 18.0592 - val_huber_loss: 18.0673 - val_mean_squared_error: 553.8309 - val_mean_absolute_error: 18.5620 - val_mean_absolute_percentage_error: 17.9609 - val_mean_squared_logarithmic_error: 0.0436 - val_log_cosh: 17.8815
# Epoch 3/15
# 2308/2308 [==============================] - 45s 20ms/step - loss: 21.5638 - huber_loss: 21.5611 - mean_squared_error: 842.0397 - mean_absolute_error: 22.0559 - mean_absolute_percentage_error: 18.5570 - mean_squared_logarithmic_error: 0.0580 - log_cosh: 21.3756 - val_loss: 18.3090 - val_huber_loss: 18.3010 - val_mean_squared_error: 652.7878 - val_mean_absolute_error: 18.7933 - val_mean_absolute_percentage_error: 15.5706 - val_mean_squared_logarithmic_error: 0.0494 - val_log_cosh: 18.1186
# Epoch 4/15
# 2308/2308 [==============================] - 48s 21ms/step - loss: 21.5663 - huber_loss: 21.5651 - mean_squared_error: 841.5756 - mean_absolute_error: 22.0600 - mean_absolute_percentage_error: 18.5775 - mean_squared_logarithmic_error: 0.0579 - log_cosh: 21.3796 - val_loss: 16.7972 - val_huber_loss: 16.8044 - val_mean_squared_error: 508.5342 - val_mean_absolute_error: 17.2990 - val_mean_absolute_percentage_error: 16.3748 - val_mean_squared_logarithmic_error: 0.0397 - val_log_cosh: 16.6197
# Epoch 5/15
# 2308/2308 [==============================] - 45s 19ms/step - loss: 21.4356 - huber_loss: 21.4344 - mean_squared_error: 833.5698 - mean_absolute_error: 21.9295 - mean_absolute_percentage_error: 18.4586 - mean_squared_logarithmic_error: 0.0574 - log_cosh: 21.2489 - val_loss: 20.6686 - val_huber_loss: 20.6795 - val_mean_squared_error: 672.9530 - val_mean_absolute_error: 21.1754 - val_mean_absolute_percentage_error: 20.9697 - val_mean_squared_logarithmic_error: 0.0527 - val_log_cosh: 20.4923
# Epoch 6/15
# 2308/2308 [==============================] - 45s 20ms/step - loss: 21.4799 - huber_loss: 21.4780 - mean_squared_error: 834.7791 - mean_absolute_error: 21.9728 - mean_absolute_percentage_error: 18.4931 - mean_squared_logarithmic_error: 0.0573 - log_cosh: 21.2926 - val_loss: 19.5910 - val_huber_loss: 19.6013 - val_mean_squared_error: 619.6086 - val_mean_absolute_error: 20.0965 - val_mean_absolute_percentage_error: 19.7836 - val_mean_squared_logarithmic_error: 0.0489 - val_log_cosh: 19.4147
# Epoch 7/15
# 2308/2308 [==============================] - 45s 19ms/step - loss: 21.4107 - huber_loss: 21.4084 - mean_squared_error: 829.5118 - mean_absolute_error: 21.9033 - mean_absolute_percentage_error: 18.4647 - mean_squared_logarithmic_error: 0.0570 - log_cosh: 21.2227 - val_loss: 16.7847 - val_huber_loss: 16.7916 - val_mean_squared_error: 507.8839 - val_mean_absolute_error: 17.2856 - val_mean_absolute_percentage_error: 16.3718 - val_mean_squared_logarithmic_error: 0.0397 - val_log_cosh: 16.6072
# Epoch 8/15
# 2308/2308 [==============================] - 46s 20ms/step - loss: 21.3651 - huber_loss: 21.3634 - mean_squared_error: 827.9985 - mean_absolute_error: 21.8581 - mean_absolute_percentage_error: 18.3856 - mean_squared_logarithmic_error: 0.0570 - log_cosh: 21.1782 - val_loss: 18.3194 - val_huber_loss: 18.3287 - val_mean_squared_error: 561.5446 - val_mean_absolute_error: 18.8235 - val_mean_absolute_percentage_error: 18.3697 - val_mean_squared_logarithmic_error: 0.0446 - val_log_cosh: 18.1430
# Epoch 9/15
# 2308/2308 [==============================] - 46s 20ms/step - loss: 21.2214 - huber_loss: 21.2197 - mean_squared_error: 818.1257 - mean_absolute_error: 21.7142 - mean_absolute_percentage_error: 18.3063 - mean_squared_logarithmic_error: 0.0562 - log_cosh: 21.0345 - val_loss: 19.5872 - val_huber_loss: 19.5979 - val_mean_squared_error: 618.7730 - val_mean_absolute_error: 20.0930 - val_mean_absolute_percentage_error: 19.8212 - val_mean_squared_logarithmic_error: 0.0490 - val_log_cosh: 19.4114
# Epoch 10/15
# 2308/2308 [==============================] - 45s 19ms/step - loss: 21.2668 - huber_loss: 21.2653 - mean_squared_error: 818.3089 - mean_absolute_error: 21.7599 - mean_absolute_percentage_error: 18.3644 - mean_squared_logarithmic_error: 0.0561 - log_cosh: 21.0801 - val_loss: 18.1305 - val_huber_loss: 18.1396 - val_mean_squared_error: 554.9124 - val_mean_absolute_error: 18.6346 - val_mean_absolute_percentage_error: 18.1211 - val_mean_squared_logarithmic_error: 0.0440 - val_log_cosh: 17.9537
# Epoch 11/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 21.3031 - huber_loss: 21.3001 - mean_squared_error: 819.3303 - mean_absolute_error: 21.7948 - mean_absolute_percentage_error: 18.3685 - mean_squared_logarithmic_error: 0.0561 - log_cosh: 21.1147 - val_loss: 18.2372 - val_huber_loss: 18.2467 - val_mean_squared_error: 559.1448 - val_mean_absolute_error: 18.7420 - val_mean_absolute_percentage_error: 18.2623 - val_mean_squared_logarithmic_error: 0.0444 - val_log_cosh: 18.0606
# Epoch 12/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 21.2620 - huber_loss: 21.2588 - mean_squared_error: 817.1465 - mean_absolute_error: 21.7535 - mean_absolute_percentage_error: 18.3790 - mean_squared_logarithmic_error: 0.0561 - log_cosh: 21.0734 - val_loss: 17.6380 - val_huber_loss: 17.6468 - val_mean_squared_error: 534.8272 - val_mean_absolute_error: 18.1422 - val_mean_absolute_percentage_error: 17.5677 - val_mean_squared_logarithmic_error: 0.0425 - val_log_cosh: 17.4615
# Epoch 13/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 21.1847 - huber_loss: 21.1816 - mean_squared_error: 811.3513 - mean_absolute_error: 21.6762 - mean_absolute_percentage_error: 18.2816 - mean_squared_logarithmic_error: 0.0558 - log_cosh: 20.9964 - val_loss: 16.2255 - val_huber_loss: 16.2310 - val_mean_squared_error: 492.9904 - val_mean_absolute_error: 16.7236 - val_mean_absolute_percentage_error: 15.5831 - val_mean_squared_logarithmic_error: 0.0382 - val_log_cosh: 16.0481
# Epoch 14/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 21.1925 - huber_loss: 21.1904 - mean_squared_error: 812.0640 - mean_absolute_error: 21.6852 - mean_absolute_percentage_error: 18.3018 - mean_squared_logarithmic_error: 0.0556 - log_cosh: 21.0050 - val_loss: 16.7139 - val_huber_loss: 16.7211 - val_mean_squared_error: 503.4512 - val_mean_absolute_error: 17.2144 - val_mean_absolute_percentage_error: 16.3484 - val_mean_squared_logarithmic_error: 0.0396 - val_log_cosh: 16.5369
# Epoch 15/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 21.1054 - huber_loss: 21.1041 - mean_squared_error: 806.6476 - mean_absolute_error: 21.5988 - mean_absolute_percentage_error: 18.2192 - mean_squared_logarithmic_error: 0.0552 - log_cosh: 20.9189 - val_loss: 17.3250 - val_huber_loss: 17.3333 - val_mean_squared_error: 522.6708 - val_mean_absolute_error: 17.8275 - val_mean_absolute_percentage_error: 17.1879 - val_mean_squared_logarithmic_error: 0.0415 - val_log_cosh: 17.1482
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2308/2308 [==============================] - 56s 20ms/step - loss: 26.0466 - huber_loss: 26.0428 - mean_squared_error: 1251.3370 - mean_absolute_error: 26.5382 - mean_absolute_percentage_error: 22.3231 - mean_squared_logarithmic_error: 0.1087 - log_cosh: 25.8562 - val_loss: 18.6607 - val_huber_loss: 18.6677 - val_mean_squared_error: 615.2253 - val_mean_absolute_error: 19.1625 - val_mean_absolute_percentage_error: 17.8737 - val_mean_squared_logarithmic_error: 0.0461 - val_log_cosh: 18.4823
# Epoch 2/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 23.7723 - huber_loss: 23.7685 - mean_squared_error: 1015.9751 - mean_absolute_error: 24.2636 - mean_absolute_percentage_error: 20.3300 - mean_squared_logarithmic_error: 0.0710 - log_cosh: 23.5826 - val_loss: 18.1072 - val_huber_loss: 18.1126 - val_mean_squared_error: 583.3326 - val_mean_absolute_error: 18.6067 - val_mean_absolute_percentage_error: 17.3685 - val_mean_squared_logarithmic_error: 0.0441 - val_log_cosh: 17.9276
# Epoch 3/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 23.4049 - huber_loss: 23.4004 - mean_squared_error: 982.9280 - mean_absolute_error: 23.8956 - mean_absolute_percentage_error: 20.0414 - mean_squared_logarithmic_error: 0.0688 - log_cosh: 23.2144 - val_loss: 17.9672 - val_huber_loss: 17.9731 - val_mean_squared_error: 572.3434 - val_mean_absolute_error: 18.4680 - val_mean_absolute_percentage_error: 17.2944 - val_mean_squared_logarithmic_error: 0.0435 - val_log_cosh: 17.7877
# Epoch 4/15
# 2308/2308 [==============================] - 45s 20ms/step - loss: 23.1429 - huber_loss: 23.1401 - mean_squared_error: 963.3130 - mean_absolute_error: 23.6353 - mean_absolute_percentage_error: 19.8218 - mean_squared_logarithmic_error: 0.0676 - log_cosh: 22.9541 - val_loss: 18.1950 - val_huber_loss: 18.2012 - val_mean_squared_error: 577.3653 - val_mean_absolute_error: 18.6958 - val_mean_absolute_percentage_error: 17.7019 - val_mean_squared_logarithmic_error: 0.0441 - val_log_cosh: 18.0156
# Epoch 5/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 22.9179 - huber_loss: 22.9149 - mean_squared_error: 947.5429 - mean_absolute_error: 23.4097 - mean_absolute_percentage_error: 19.6267 - mean_squared_logarithmic_error: 0.0662 - log_cosh: 22.7291 - val_loss: 17.3422 - val_huber_loss: 17.3472 - val_mean_squared_error: 543.1396 - val_mean_absolute_error: 17.8417 - val_mean_absolute_percentage_error: 16.6704 - val_mean_squared_logarithmic_error: 0.0415 - val_log_cosh: 17.1623
# Epoch 6/15
# 2308/2308 [==============================] - 46s 20ms/step - loss: 22.7802 - huber_loss: 22.7779 - mean_squared_error: 932.5458 - mean_absolute_error: 23.2730 - mean_absolute_percentage_error: 19.5373 - mean_squared_logarithmic_error: 0.0650 - log_cosh: 22.5919 - val_loss: 18.4595 - val_huber_loss: 18.4667 - val_mean_squared_error: 582.8943 - val_mean_absolute_error: 18.9611 - val_mean_absolute_percentage_error: 18.1203 - val_mean_squared_logarithmic_error: 0.0448 - val_log_cosh: 18.2811
# Epoch 7/15
# 2308/2308 [==============================] - 46s 20ms/step - loss: 22.6805 - huber_loss: 22.6780 - mean_squared_error: 927.4995 - mean_absolute_error: 23.1730 - mean_absolute_percentage_error: 19.4392 - mean_squared_logarithmic_error: 0.0646 - log_cosh: 22.4924 - val_loss: 17.7353 - val_huber_loss: 17.7429 - val_mean_squared_error: 551.6675 - val_mean_absolute_error: 18.2373 - val_mean_absolute_percentage_error: 17.3178 - val_mean_squared_logarithmic_error: 0.0425 - val_log_cosh: 17.5581
# Epoch 8/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 22.5117 - huber_loss: 22.5098 - mean_squared_error: 912.8845 - mean_absolute_error: 23.0048 - mean_absolute_percentage_error: 19.2901 - mean_squared_logarithmic_error: 0.0635 - log_cosh: 22.3242 - val_loss: 20.0220 - val_huber_loss: 20.0302 - val_mean_squared_error: 650.2861 - val_mean_absolute_error: 20.5258 - val_mean_absolute_percentage_error: 20.0559 - val_mean_squared_logarithmic_error: 0.0502 - val_log_cosh: 19.8436
# Epoch 9/15
# 2308/2308 [==============================] - 45s 20ms/step - loss: 22.3860 - huber_loss: 22.3831 - mean_squared_error: 902.0742 - mean_absolute_error: 22.8778 - mean_absolute_percentage_error: 19.2034 - mean_squared_logarithmic_error: 0.0624 - log_cosh: 22.1975 - val_loss: 18.5495 - val_huber_loss: 18.5575 - val_mean_squared_error: 584.2250 - val_mean_absolute_error: 19.0530 - val_mean_absolute_percentage_error: 18.3413 - val_mean_squared_logarithmic_error: 0.0451 - val_log_cosh: 18.3714
# Epoch 10/15
# 2308/2308 [==============================] - 45s 19ms/step - loss: 22.2914 - huber_loss: 22.2891 - mean_squared_error: 895.4208 - mean_absolute_error: 22.7842 - mean_absolute_percentage_error: 19.1562 - mean_squared_logarithmic_error: 0.0619 - log_cosh: 22.1034 - val_loss: 17.1279 - val_huber_loss: 17.1344 - val_mean_squared_error: 528.3266 - val_mean_absolute_error: 17.6286 - val_mean_absolute_percentage_error: 16.6231 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 16.9500
# Epoch 11/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 22.2000 - huber_loss: 22.1978 - mean_squared_error: 887.6243 - mean_absolute_error: 22.6928 - mean_absolute_percentage_error: 19.0483 - mean_squared_logarithmic_error: 0.0614 - log_cosh: 22.0121 - val_loss: 21.4906 - val_huber_loss: 21.5004 - val_mean_squared_error: 722.0497 - val_mean_absolute_error: 21.9959 - val_mean_absolute_percentage_error: 21.6449 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 21.3135
# Epoch 12/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 22.1553 - huber_loss: 22.1518 - mean_squared_error: 882.6243 - mean_absolute_error: 22.6468 - mean_absolute_percentage_error: 19.0491 - mean_squared_logarithmic_error: 0.0612 - log_cosh: 21.9661 - val_loss: 16.2617 - val_huber_loss: 16.2655 - val_mean_squared_error: 503.8585 - val_mean_absolute_error: 16.7580 - val_mean_absolute_percentage_error: 15.3497 - val_mean_squared_logarithmic_error: 0.0384 - val_log_cosh: 16.0831
# Epoch 13/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 22.0228 - huber_loss: 22.0210 - mean_squared_error: 877.4406 - mean_absolute_error: 22.5160 - mean_absolute_percentage_error: 18.9398 - mean_squared_logarithmic_error: 0.0606 - log_cosh: 21.8355 - val_loss: 16.5292 - val_huber_loss: 16.5342 - val_mean_squared_error: 507.9339 - val_mean_absolute_error: 17.0282 - val_mean_absolute_percentage_error: 15.8287 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 16.3503
# Epoch 14/15
# 2308/2308 [==============================] - 44s 19ms/step - loss: 21.9728 - huber_loss: 21.9703 - mean_squared_error: 871.7759 - mean_absolute_error: 22.4652 - mean_absolute_percentage_error: 18.8943 - mean_squared_logarithmic_error: 0.0602 - log_cosh: 21.7847 - val_loss: 19.3139 - val_huber_loss: 19.3228 - val_mean_squared_error: 611.5369 - val_mean_absolute_error: 19.8192 - val_mean_absolute_percentage_error: 19.3546 - val_mean_squared_logarithmic_error: 0.0478 - val_log_cosh: 19.1358
# Epoch 15/15
# 2308/2308 [==============================] - 47s 20ms/step - loss: 21.9466 - huber_loss: 21.9435 - mean_squared_error: 870.0676 - mean_absolute_error: 22.4381 - mean_absolute_percentage_error: 18.8707 - mean_squared_logarithmic_error: 0.0599 - log_cosh: 21.7582 - val_loss: 17.0729 - val_huber_loss: 17.0798 - val_mean_squared_error: 519.4996 - val_mean_absolute_error: 17.5741 - val_mean_absolute_percentage_error: 16.7113 - val_mean_squared_logarithmic_error: 0.0406 - val_log_cosh: 16.8954
# 641/641 [==============================] - 4s 6ms/step - loss: 16.2690 - huber_loss: 16.2682 - mean_squared_error: 461.2756 - mean_absolute_error: 16.7620 - mean_absolute_percentage_error: 15.6341 - mean_squared_logarithmic_error: 0.0348 - log_cosh: 16.0839
# 641/641 [==============================] - 4s 7ms/step - loss: 16.1087 - huber_loss: 16.1080 - mean_squared_error: 462.2682 - mean_absolute_error: 16.6021 - mean_absolute_percentage_error: 15.2818 - mean_squared_logarithmic_error: 0.0344 - log_cosh: 15.9240
# 641/641 [==============================] - 3s 4ms/step
# 641/641 [==============================] - 3s 4ms/step
# -------------------------------------------------------
#
# 1-LIB193307
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2203/2203 [==============================] - 58s 20ms/step - loss: 27.7827 - huber_loss: 27.7825 - mean_squared_error: 1421.9498 - mean_absolute_error: 28.2781 - mean_absolute_percentage_error: 19.3294 - mean_squared_logarithmic_error: 0.0642 - log_cosh: 27.5957 - val_loss: 23.0974 - val_huber_loss: 23.0967 - val_mean_squared_error: 997.3003 - val_mean_absolute_error: 23.5909 - val_mean_absolute_percentage_error: 15.5916 - val_mean_squared_logarithmic_error: 0.0501 - val_log_cosh: 22.9116
# Epoch 2/15
# 2203/2203 [==============================] - 43s 20ms/step - loss: 27.5636 - huber_loss: 27.5634 - mean_squared_error: 1402.8455 - mean_absolute_error: 28.0590 - mean_absolute_percentage_error: 19.1320 - mean_squared_logarithmic_error: 0.0633 - log_cosh: 27.3767 - val_loss: 22.2215 - val_huber_loss: 22.2210 - val_mean_squared_error: 904.3036 - val_mean_absolute_error: 22.7152 - val_mean_absolute_percentage_error: 16.4270 - val_mean_squared_logarithmic_error: 0.0437 - val_log_cosh: 22.0360
# Epoch 3/15
# 2203/2203 [==============================] - 44s 20ms/step - loss: 27.4944 - huber_loss: 27.4942 - mean_squared_error: 1391.2556 - mean_absolute_error: 27.9900 - mean_absolute_percentage_error: 19.1394 - mean_squared_logarithmic_error: 0.0629 - log_cosh: 27.3075 - val_loss: 22.8178 - val_huber_loss: 22.8172 - val_mean_squared_error: 972.9232 - val_mean_absolute_error: 23.3114 - val_mean_absolute_percentage_error: 15.4813 - val_mean_squared_logarithmic_error: 0.0475 - val_log_cosh: 22.6322
# Epoch 4/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 27.4109 - huber_loss: 27.4107 - mean_squared_error: 1388.0990 - mean_absolute_error: 27.9062 - mean_absolute_percentage_error: 19.0489 - mean_squared_logarithmic_error: 0.0623 - log_cosh: 27.2242 - val_loss: 25.1551 - val_huber_loss: 25.1554 - val_mean_squared_error: 1149.1984 - val_mean_absolute_error: 25.6506 - val_mean_absolute_percentage_error: 16.4359 - val_mean_squared_logarithmic_error: 0.0565 - val_log_cosh: 24.9693
# Epoch 5/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 27.3629 - huber_loss: 27.3627 - mean_squared_error: 1380.2382 - mean_absolute_error: 27.8583 - mean_absolute_percentage_error: 19.0546 - mean_squared_logarithmic_error: 0.0624 - log_cosh: 27.1761 - val_loss: 21.9248 - val_huber_loss: 21.9242 - val_mean_squared_error: 893.9863 - val_mean_absolute_error: 22.4191 - val_mean_absolute_percentage_error: 15.7037 - val_mean_squared_logarithmic_error: 0.0438 - val_log_cosh: 21.7386
# Epoch 6/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 27.3728 - huber_loss: 27.3726 - mean_squared_error: 1379.0675 - mean_absolute_error: 27.8682 - mean_absolute_percentage_error: 19.0864 - mean_squared_logarithmic_error: 0.0620 - log_cosh: 27.1859 - val_loss: 22.1936 - val_huber_loss: 22.1925 - val_mean_squared_error: 919.4592 - val_mean_absolute_error: 22.6871 - val_mean_absolute_percentage_error: 15.4053 - val_mean_squared_logarithmic_error: 0.0444 - val_log_cosh: 22.0069
# Epoch 7/15
# 2203/2203 [==============================] - 47s 21ms/step - loss: 27.2614 - huber_loss: 27.2612 - mean_squared_error: 1366.2892 - mean_absolute_error: 27.7566 - mean_absolute_percentage_error: 18.9921 - mean_squared_logarithmic_error: 0.0617 - log_cosh: 27.0746 - val_loss: 22.3305 - val_huber_loss: 22.3292 - val_mean_squared_error: 932.0938 - val_mean_absolute_error: 22.8237 - val_mean_absolute_percentage_error: 15.3799 - val_mean_squared_logarithmic_error: 0.0451 - val_log_cosh: 22.1441
# Epoch 8/15
# 2203/2203 [==============================] - 48s 22ms/step - loss: 27.1710 - huber_loss: 27.1708 - mean_squared_error: 1360.4679 - mean_absolute_error: 27.6666 - mean_absolute_percentage_error: 18.9571 - mean_squared_logarithmic_error: 0.0611 - log_cosh: 26.9842 - val_loss: 22.5128 - val_huber_loss: 22.5118 - val_mean_squared_error: 943.3256 - val_mean_absolute_error: 23.0069 - val_mean_absolute_percentage_error: 15.4212 - val_mean_squared_logarithmic_error: 0.0447 - val_log_cosh: 22.3262
# Epoch 9/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 27.1976 - huber_loss: 27.1975 - mean_squared_error: 1359.4037 - mean_absolute_error: 27.6933 - mean_absolute_percentage_error: 18.9769 - mean_squared_logarithmic_error: 0.0610 - log_cosh: 27.0106 - val_loss: 24.2687 - val_huber_loss: 24.2682 - val_mean_squared_error: 1081.6228 - val_mean_absolute_error: 24.7636 - val_mean_absolute_percentage_error: 15.9645 - val_mean_squared_logarithmic_error: 0.0516 - val_log_cosh: 24.0823
# Epoch 10/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 27.1155 - huber_loss: 27.1153 - mean_squared_error: 1349.3311 - mean_absolute_error: 27.6109 - mean_absolute_percentage_error: 18.9442 - mean_squared_logarithmic_error: 0.0607 - log_cosh: 26.9286 - val_loss: 22.1890 - val_huber_loss: 22.1878 - val_mean_squared_error: 915.0665 - val_mean_absolute_error: 22.6828 - val_mean_absolute_percentage_error: 15.4189 - val_mean_squared_logarithmic_error: 0.0435 - val_log_cosh: 22.0022
# Epoch 11/15
# 2203/2203 [==============================] - 48s 22ms/step - loss: 27.0943 - huber_loss: 27.0940 - mean_squared_error: 1352.0865 - mean_absolute_error: 27.5896 - mean_absolute_percentage_error: 18.9199 - mean_squared_logarithmic_error: 0.0606 - log_cosh: 26.9073 - val_loss: 21.8944 - val_huber_loss: 21.8931 - val_mean_squared_error: 885.2350 - val_mean_absolute_error: 22.3874 - val_mean_absolute_percentage_error: 15.5946 - val_mean_squared_logarithmic_error: 0.0422 - val_log_cosh: 21.7076
# Epoch 12/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 27.1631 - huber_loss: 27.1630 - mean_squared_error: 1356.9347 - mean_absolute_error: 27.6586 - mean_absolute_percentage_error: 18.9396 - mean_squared_logarithmic_error: 0.0609 - log_cosh: 26.9762 - val_loss: 22.2559 - val_huber_loss: 22.2545 - val_mean_squared_error: 922.6572 - val_mean_absolute_error: 22.7496 - val_mean_absolute_percentage_error: 15.3982 - val_mean_squared_logarithmic_error: 0.0439 - val_log_cosh: 22.0692
# Epoch 13/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 27.0606 - huber_loss: 27.0605 - mean_squared_error: 1347.0959 - mean_absolute_error: 27.5562 - mean_absolute_percentage_error: 18.8945 - mean_squared_logarithmic_error: 0.0604 - log_cosh: 26.8738 - val_loss: 22.8026 - val_huber_loss: 22.8016 - val_mean_squared_error: 968.3273 - val_mean_absolute_error: 23.2960 - val_mean_absolute_percentage_error: 15.5006 - val_mean_squared_logarithmic_error: 0.0467 - val_log_cosh: 22.6163
# Epoch 14/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 27.0541 - huber_loss: 27.0539 - mean_squared_error: 1343.6029 - mean_absolute_error: 27.5496 - mean_absolute_percentage_error: 18.8960 - mean_squared_logarithmic_error: 0.0604 - log_cosh: 26.8672 - val_loss: 21.9236 - val_huber_loss: 21.9221 - val_mean_squared_error: 892.6118 - val_mean_absolute_error: 22.4167 - val_mean_absolute_percentage_error: 15.5340 - val_mean_squared_logarithmic_error: 0.0433 - val_log_cosh: 21.7365
# Epoch 15/15
# 2203/2203 [==============================] - 43s 20ms/step - loss: 27.0315 - huber_loss: 27.0313 - mean_squared_error: 1345.4865 - mean_absolute_error: 27.5267 - mean_absolute_percentage_error: 18.8844 - mean_squared_logarithmic_error: 0.0602 - log_cosh: 26.8446 - val_loss: 22.3510 - val_huber_loss: 22.3499 - val_mean_squared_error: 931.6923 - val_mean_absolute_error: 22.8449 - val_mean_absolute_percentage_error: 15.4606 - val_mean_squared_logarithmic_error: 0.0454 - val_log_cosh: 22.1646
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2203/2203 [==============================] - 55s 20ms/step - loss: 36.2733 - huber_loss: 36.2731 - mean_squared_error: 2604.2441 - mean_absolute_error: 36.7694 - mean_absolute_percentage_error: 25.2673 - mean_squared_logarithmic_error: 0.1822 - log_cosh: 36.0850 - val_loss: 25.6762 - val_huber_loss: 25.6799 - val_mean_squared_error: 1195.7679 - val_mean_absolute_error: 26.1752 - val_mean_absolute_percentage_error: 18.8684 - val_mean_squared_logarithmic_error: 0.0568 - val_log_cosh: 25.4938
# Epoch 2/15
# 2203/2203 [==============================] - 43s 19ms/step - loss: 31.2344 - huber_loss: 31.2342 - mean_squared_error: 1785.1058 - mean_absolute_error: 31.7304 - mean_absolute_percentage_error: 21.6991 - mean_squared_logarithmic_error: 0.0838 - log_cosh: 31.0468 - val_loss: 24.2803 - val_huber_loss: 24.2829 - val_mean_squared_error: 1092.6387 - val_mean_absolute_error: 24.7777 - val_mean_absolute_percentage_error: 17.5130 - val_mean_squared_logarithmic_error: 0.0517 - val_log_cosh: 24.0975
# Epoch 3/15
# 2203/2203 [==============================] - 43s 19ms/step - loss: 30.2885 - huber_loss: 30.2884 - mean_squared_error: 1686.0186 - mean_absolute_error: 30.7841 - mean_absolute_percentage_error: 20.9427 - mean_squared_logarithmic_error: 0.0779 - log_cosh: 30.1014 - val_loss: 25.1348 - val_huber_loss: 25.1371 - val_mean_squared_error: 1150.3988 - val_mean_absolute_error: 25.6319 - val_mean_absolute_percentage_error: 18.5473 - val_mean_squared_logarithmic_error: 0.0530 - val_log_cosh: 24.9511
# Epoch 4/15
# 2203/2203 [==============================] - 43s 19ms/step - loss: 29.7260 - huber_loss: 29.7258 - mean_squared_error: 1627.4098 - mean_absolute_error: 30.2216 - mean_absolute_percentage_error: 20.5889 - mean_squared_logarithmic_error: 0.0751 - log_cosh: 29.5389 - val_loss: 23.5686 - val_huber_loss: 23.5692 - val_mean_squared_error: 1042.1531 - val_mean_absolute_error: 24.0640 - val_mean_absolute_percentage_error: 16.2312 - val_mean_squared_logarithmic_error: 0.0522 - val_log_cosh: 23.3834
# Epoch 5/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 29.3393 - huber_loss: 29.3391 - mean_squared_error: 1594.1472 - mean_absolute_error: 29.8349 - mean_absolute_percentage_error: 20.2843 - mean_squared_logarithmic_error: 0.0728 - log_cosh: 29.1523 - val_loss: 23.1564 - val_huber_loss: 23.1581 - val_mean_squared_error: 989.0309 - val_mean_absolute_error: 23.6530 - val_mean_absolute_percentage_error: 16.8194 - val_mean_squared_logarithmic_error: 0.0475 - val_log_cosh: 22.9723
# Epoch 6/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 29.0781 - huber_loss: 29.0779 - mean_squared_error: 1556.0680 - mean_absolute_error: 29.5738 - mean_absolute_percentage_error: 20.1658 - mean_squared_logarithmic_error: 0.0713 - log_cosh: 28.8908 - val_loss: 23.0463 - val_huber_loss: 23.0479 - val_mean_squared_error: 985.0894 - val_mean_absolute_error: 23.5427 - val_mean_absolute_percentage_error: 16.7365 - val_mean_squared_logarithmic_error: 0.0473 - val_log_cosh: 22.8624
# Epoch 7/15
# 2203/2203 [==============================] - 50s 23ms/step - loss: 28.7259 - huber_loss: 28.7257 - mean_squared_error: 1522.1599 - mean_absolute_error: 29.2214 - mean_absolute_percentage_error: 19.8953 - mean_squared_logarithmic_error: 0.0697 - log_cosh: 28.5389 - val_loss: 22.9814 - val_huber_loss: 22.9826 - val_mean_squared_error: 975.8762 - val_mean_absolute_error: 23.4772 - val_mean_absolute_percentage_error: 16.7816 - val_mean_squared_logarithmic_error: 0.0468 - val_log_cosh: 22.7973
# Epoch 8/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 28.6513 - huber_loss: 28.6512 - mean_squared_error: 1515.8450 - mean_absolute_error: 29.1471 - mean_absolute_percentage_error: 19.8950 - mean_squared_logarithmic_error: 0.0687 - log_cosh: 28.4641 - val_loss: 22.8036 - val_huber_loss: 22.8047 - val_mean_squared_error: 962.5740 - val_mean_absolute_error: 23.2997 - val_mean_absolute_percentage_error: 16.5902 - val_mean_squared_logarithmic_error: 0.0464 - val_log_cosh: 22.6194
# Epoch 9/15
# 2203/2203 [==============================] - 44s 20ms/step - loss: 28.5219 - huber_loss: 28.5218 - mean_squared_error: 1494.4153 - mean_absolute_error: 29.0176 - mean_absolute_percentage_error: 19.7998 - mean_squared_logarithmic_error: 0.0680 - log_cosh: 28.3350 - val_loss: 22.5577 - val_huber_loss: 22.5584 - val_mean_squared_error: 935.2667 - val_mean_absolute_error: 23.0542 - val_mean_absolute_percentage_error: 16.3270 - val_mean_squared_logarithmic_error: 0.0449 - val_log_cosh: 22.3724
# Epoch 10/15
# 2203/2203 [==============================] - 44s 20ms/step - loss: 28.4408 - huber_loss: 28.4407 - mean_squared_error: 1482.9181 - mean_absolute_error: 28.9367 - mean_absolute_percentage_error: 19.7845 - mean_squared_logarithmic_error: 0.0676 - log_cosh: 28.2536 - val_loss: 23.4858 - val_huber_loss: 23.4854 - val_mean_squared_error: 1026.0790 - val_mean_absolute_error: 23.9802 - val_mean_absolute_percentage_error: 15.8513 - val_mean_squared_logarithmic_error: 0.0496 - val_log_cosh: 23.3003
# Epoch 11/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 28.2654 - huber_loss: 28.2653 - mean_squared_error: 1470.7855 - mean_absolute_error: 28.7610 - mean_absolute_percentage_error: 19.6209 - mean_squared_logarithmic_error: 0.0664 - log_cosh: 28.0786 - val_loss: 22.3889 - val_huber_loss: 22.3890 - val_mean_squared_error: 925.1626 - val_mean_absolute_error: 22.8837 - val_mean_absolute_percentage_error: 15.9901 - val_mean_squared_logarithmic_error: 0.0443 - val_log_cosh: 22.2032
# Epoch 12/15
# 2203/2203 [==============================] - 46s 21ms/step - loss: 28.2783 - huber_loss: 28.2781 - mean_squared_error: 1467.4994 - mean_absolute_error: 28.7737 - mean_absolute_percentage_error: 19.6401 - mean_squared_logarithmic_error: 0.0663 - log_cosh: 28.0913 - val_loss: 22.4169 - val_huber_loss: 22.4165 - val_mean_squared_error: 939.4838 - val_mean_absolute_error: 22.9117 - val_mean_absolute_percentage_error: 15.6892 - val_mean_squared_logarithmic_error: 0.0453 - val_log_cosh: 22.2307
# Epoch 13/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 28.0497 - huber_loss: 28.0494 - mean_squared_error: 1452.2605 - mean_absolute_error: 28.5451 - mean_absolute_percentage_error: 19.4804 - mean_squared_logarithmic_error: 0.0655 - log_cosh: 27.8626 - val_loss: 24.5576 - val_huber_loss: 24.5570 - val_mean_squared_error: 1107.7148 - val_mean_absolute_error: 25.0524 - val_mean_absolute_percentage_error: 16.2388 - val_mean_squared_logarithmic_error: 0.0540 - val_log_cosh: 24.3709
# Epoch 14/15
# 2203/2203 [==============================] - 45s 20ms/step - loss: 28.0462 - huber_loss: 28.0460 - mean_squared_error: 1443.7104 - mean_absolute_error: 28.5416 - mean_absolute_percentage_error: 19.5068 - mean_squared_logarithmic_error: 0.0651 - log_cosh: 27.8593 - val_loss: 22.3749 - val_huber_loss: 22.3745 - val_mean_squared_error: 929.2008 - val_mean_absolute_error: 22.8690 - val_mean_absolute_percentage_error: 15.8948 - val_mean_squared_logarithmic_error: 0.0449 - val_log_cosh: 22.1891
# Epoch 15/15
# 2203/2203 [==============================] - 44s 20ms/step - loss: 27.8972 - huber_loss: 27.8970 - mean_squared_error: 1428.0477 - mean_absolute_error: 28.3926 - mean_absolute_percentage_error: 19.3947 - mean_squared_logarithmic_error: 0.0646 - log_cosh: 27.7102 - val_loss: 23.3107 - val_huber_loss: 23.3103 - val_mean_squared_error: 1013.3194 - val_mean_absolute_error: 23.8048 - val_mean_absolute_percentage_error: 15.8555 - val_mean_squared_logarithmic_error: 0.0508 - val_log_cosh: 23.1250
# 612/612 [==============================] - 5s 8ms/step - loss: 22.6386 - huber_loss: 22.6386 - mean_squared_error: 945.7974 - mean_absolute_error: 23.1336 - mean_absolute_percentage_error: 15.3120 - mean_squared_logarithmic_error: 0.0437 - log_cosh: 22.4529
# 612/612 [==============================] - 4s 6ms/step - loss: 23.6259 - huber_loss: 23.6259 - mean_squared_error: 1023.9270 - mean_absolute_error: 24.1203 - mean_absolute_percentage_error: 15.7345 - mean_squared_logarithmic_error: 0.0484 - log_cosh: 23.4407
# 612/612 [==============================] - 3s 4ms/step
# 612/612 [==============================] - 6s 9ms/step
# -------------------------------------------------------
#
# 2-LIB193368
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2142/2142 [==============================] - 63s 23ms/step - loss: 28.4012 - huber_loss: 28.4019 - mean_squared_error: 1475.6022 - mean_absolute_error: 28.8977 - mean_absolute_percentage_error: 19.3685 - mean_squared_logarithmic_error: 0.0655 - log_cosh: 28.2150 - val_loss: 27.7586 - val_huber_loss: 27.7594 - val_mean_squared_error: 1383.9645 - val_mean_absolute_error: 28.2546 - val_mean_absolute_percentage_error: 18.0390 - val_mean_squared_logarithmic_error: 0.0591 - val_log_cosh: 27.5732
# Epoch 2/15
# 2142/2142 [==============================] - 48s 22ms/step - loss: 28.3595 - huber_loss: 28.3621 - mean_squared_error: 1469.9167 - mean_absolute_error: 28.8578 - mean_absolute_percentage_error: 19.3330 - mean_squared_logarithmic_error: 0.0654 - log_cosh: 28.1751 - val_loss: 27.0517 - val_huber_loss: 27.0522 - val_mean_squared_error: 1249.8958 - val_mean_absolute_error: 27.5490 - val_mean_absolute_percentage_error: 20.3973 - val_mean_squared_logarithmic_error: 0.0583 - val_log_cosh: 26.8642
# Epoch 3/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 28.3049 - huber_loss: 28.3067 - mean_squared_error: 1460.0443 - mean_absolute_error: 28.8026 - mean_absolute_percentage_error: 19.2957 - mean_squared_logarithmic_error: 0.0647 - log_cosh: 28.1198 - val_loss: 25.7827 - val_huber_loss: 25.7833 - val_mean_squared_error: 1170.2129 - val_mean_absolute_error: 26.2788 - val_mean_absolute_percentage_error: 18.7589 - val_mean_squared_logarithmic_error: 0.0536 - val_log_cosh: 25.5964
# Epoch 4/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 28.2733 - huber_loss: 28.2747 - mean_squared_error: 1455.6290 - mean_absolute_error: 28.7705 - mean_absolute_percentage_error: 19.2500 - mean_squared_logarithmic_error: 0.0645 - log_cosh: 28.0877 - val_loss: 25.8763 - val_huber_loss: 25.8770 - val_mean_squared_error: 1181.9552 - val_mean_absolute_error: 26.3727 - val_mean_absolute_percentage_error: 18.3929 - val_mean_squared_logarithmic_error: 0.0530 - val_log_cosh: 25.6897
# Epoch 5/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 28.1539 - huber_loss: 28.1561 - mean_squared_error: 1448.1088 - mean_absolute_error: 28.6519 - mean_absolute_percentage_error: 19.1852 - mean_squared_logarithmic_error: 0.0641 - log_cosh: 27.9692 - val_loss: 26.6070 - val_huber_loss: 26.6076 - val_mean_squared_error: 1212.2942 - val_mean_absolute_error: 27.1034 - val_mean_absolute_percentage_error: 19.8379 - val_mean_squared_logarithmic_error: 0.0563 - val_log_cosh: 26.4201
# Epoch 6/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 28.2268 - huber_loss: 28.2283 - mean_squared_error: 1452.6019 - mean_absolute_error: 28.7242 - mean_absolute_percentage_error: 19.2361 - mean_squared_logarithmic_error: 0.0641 - log_cosh: 28.0412 - val_loss: 25.9731 - val_huber_loss: 25.9738 - val_mean_squared_error: 1199.7822 - val_mean_absolute_error: 26.4699 - val_mean_absolute_percentage_error: 17.9866 - val_mean_squared_logarithmic_error: 0.0525 - val_log_cosh: 25.7866
# Epoch 7/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 28.0453 - huber_loss: 28.0479 - mean_squared_error: 1436.6575 - mean_absolute_error: 28.5435 - mean_absolute_percentage_error: 19.1331 - mean_squared_logarithmic_error: 0.0636 - log_cosh: 27.8612 - val_loss: 26.0523 - val_huber_loss: 26.0529 - val_mean_squared_error: 1223.6715 - val_mean_absolute_error: 26.5482 - val_mean_absolute_percentage_error: 17.5997 - val_mean_squared_logarithmic_error: 0.0531 - val_log_cosh: 25.8662
# Epoch 8/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 28.0221 - huber_loss: 28.0238 - mean_squared_error: 1432.1051 - mean_absolute_error: 28.5194 - mean_absolute_percentage_error: 19.1295 - mean_squared_logarithmic_error: 0.0632 - log_cosh: 27.8368 - val_loss: 25.8116 - val_huber_loss: 25.8123 - val_mean_squared_error: 1179.2441 - val_mean_absolute_error: 26.3080 - val_mean_absolute_percentage_error: 18.1366 - val_mean_squared_logarithmic_error: 0.0523 - val_log_cosh: 25.6252
# Epoch 9/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 28.0263 - huber_loss: 28.0290 - mean_squared_error: 1429.5308 - mean_absolute_error: 28.5247 - mean_absolute_percentage_error: 19.1408 - mean_squared_logarithmic_error: 0.0633 - log_cosh: 27.8420 - val_loss: 25.7023 - val_huber_loss: 25.7030 - val_mean_squared_error: 1169.3925 - val_mean_absolute_error: 26.1984 - val_mean_absolute_percentage_error: 18.2964 - val_mean_squared_logarithmic_error: 0.0525 - val_log_cosh: 25.5161
# Epoch 10/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 28.0011 - huber_loss: 28.0031 - mean_squared_error: 1433.3149 - mean_absolute_error: 28.4989 - mean_absolute_percentage_error: 19.1011 - mean_squared_logarithmic_error: 0.0634 - log_cosh: 27.8162 - val_loss: 26.2192 - val_huber_loss: 26.2199 - val_mean_squared_error: 1236.4496 - val_mean_absolute_error: 26.7154 - val_mean_absolute_percentage_error: 17.6055 - val_mean_squared_logarithmic_error: 0.0532 - val_log_cosh: 26.0335
# Epoch 11/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 27.9460 - huber_loss: 27.9487 - mean_squared_error: 1425.1162 - mean_absolute_error: 28.4445 - mean_absolute_percentage_error: 19.1172 - mean_squared_logarithmic_error: 0.0630 - log_cosh: 27.7617 - val_loss: 28.2310 - val_huber_loss: 28.2319 - val_mean_squared_error: 1422.6125 - val_mean_absolute_error: 28.7280 - val_mean_absolute_percentage_error: 18.0890 - val_mean_squared_logarithmic_error: 0.0591 - val_log_cosh: 28.0450
# Epoch 12/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 27.9163 - huber_loss: 27.9189 - mean_squared_error: 1418.0022 - mean_absolute_error: 28.4146 - mean_absolute_percentage_error: 19.0679 - mean_squared_logarithmic_error: 0.0626 - log_cosh: 27.7320 - val_loss: 25.9126 - val_huber_loss: 25.9133 - val_mean_squared_error: 1195.0104 - val_mean_absolute_error: 26.4095 - val_mean_absolute_percentage_error: 17.8871 - val_mean_squared_logarithmic_error: 0.0521 - val_log_cosh: 25.7260
# Epoch 13/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 27.9451 - huber_loss: 27.9474 - mean_squared_error: 1422.7839 - mean_absolute_error: 28.4433 - mean_absolute_percentage_error: 19.1149 - mean_squared_logarithmic_error: 0.0628 - log_cosh: 27.7604 - val_loss: 25.6059 - val_huber_loss: 25.6065 - val_mean_squared_error: 1161.1550 - val_mean_absolute_error: 26.1013 - val_mean_absolute_percentage_error: 18.1545 - val_mean_squared_logarithmic_error: 0.0520 - val_log_cosh: 25.4200
# Epoch 14/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 27.8461 - huber_loss: 27.8480 - mean_squared_error: 1413.3575 - mean_absolute_error: 28.3436 - mean_absolute_percentage_error: 19.0271 - mean_squared_logarithmic_error: 0.0623 - log_cosh: 27.6612 - val_loss: 25.7954 - val_huber_loss: 25.7960 - val_mean_squared_error: 1165.2599 - val_mean_absolute_error: 26.2917 - val_mean_absolute_percentage_error: 18.3485 - val_mean_squared_logarithmic_error: 0.0520 - val_log_cosh: 25.6093
# Epoch 15/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 27.8011 - huber_loss: 27.8037 - mean_squared_error: 1406.6162 - mean_absolute_error: 28.2994 - mean_absolute_percentage_error: 19.0067 - mean_squared_logarithmic_error: 0.0618 - log_cosh: 27.6168 - val_loss: 25.7604 - val_huber_loss: 25.7610 - val_mean_squared_error: 1175.3088 - val_mean_absolute_error: 26.2571 - val_mean_absolute_percentage_error: 17.9777 - val_mean_squared_logarithmic_error: 0.0517 - val_log_cosh: 25.5741
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2142/2142 [==============================] - 56s 21ms/step - loss: 33.0506 - huber_loss: 33.0515 - mean_squared_error: 1986.7958 - mean_absolute_error: 33.5477 - mean_absolute_percentage_error: 22.6849 - mean_squared_logarithmic_error: 0.1029 - log_cosh: 32.8637 - val_loss: 28.6254 - val_huber_loss: 28.6263 - val_mean_squared_error: 1452.3790 - val_mean_absolute_error: 29.1217 - val_mean_absolute_percentage_error: 20.7311 - val_mean_squared_logarithmic_error: 0.0652 - val_log_cosh: 28.4394
# Epoch 2/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 30.7962 - huber_loss: 30.7980 - mean_squared_error: 1719.5099 - mean_absolute_error: 31.2944 - mean_absolute_percentage_error: 21.0346 - mean_squared_logarithmic_error: 0.0768 - log_cosh: 30.6107 - val_loss: 28.3681 - val_huber_loss: 28.3690 - val_mean_squared_error: 1413.1115 - val_mean_absolute_error: 28.8653 - val_mean_absolute_percentage_error: 20.6109 - val_mean_squared_logarithmic_error: 0.0635 - val_log_cosh: 28.1818
# Epoch 3/15
# 2142/2142 [==============================] - 46s 21ms/step - loss: 30.1983 - huber_loss: 30.1995 - mean_squared_error: 1654.0020 - mean_absolute_error: 30.6956 - mean_absolute_percentage_error: 20.6259 - mean_squared_logarithmic_error: 0.0738 - log_cosh: 30.0121 - val_loss: 28.3974 - val_huber_loss: 28.3983 - val_mean_squared_error: 1396.0050 - val_mean_absolute_error: 28.8946 - val_mean_absolute_percentage_error: 20.9980 - val_mean_squared_logarithmic_error: 0.0631 - val_log_cosh: 28.2108
# Epoch 4/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 29.7506 - huber_loss: 29.7525 - mean_squared_error: 1612.7317 - mean_absolute_error: 30.2485 - mean_absolute_percentage_error: 20.2832 - mean_squared_logarithmic_error: 0.0719 - log_cosh: 29.5652 - val_loss: 27.1148 - val_huber_loss: 27.1155 - val_mean_squared_error: 1313.9308 - val_mean_absolute_error: 27.6102 - val_mean_absolute_percentage_error: 19.2009 - val_mean_squared_logarithmic_error: 0.0586 - val_log_cosh: 26.9293
# Epoch 5/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 29.5607 - huber_loss: 29.5633 - mean_squared_error: 1587.4299 - mean_absolute_error: 30.0596 - mean_absolute_percentage_error: 20.1489 - mean_squared_logarithmic_error: 0.0707 - log_cosh: 29.3760 - val_loss: 26.9658 - val_huber_loss: 26.9665 - val_mean_squared_error: 1292.6327 - val_mean_absolute_error: 27.4627 - val_mean_absolute_percentage_error: 19.0934 - val_mean_squared_logarithmic_error: 0.0576 - val_log_cosh: 26.7796
# Epoch 6/15
# 2142/2142 [==============================] - 44s 21ms/step - loss: 29.3105 - huber_loss: 29.3122 - mean_squared_error: 1563.0416 - mean_absolute_error: 29.8082 - mean_absolute_percentage_error: 19.9937 - mean_squared_logarithmic_error: 0.0699 - log_cosh: 29.1251 - val_loss: 26.8004 - val_huber_loss: 26.8011 - val_mean_squared_error: 1290.3126 - val_mean_absolute_error: 27.2964 - val_mean_absolute_percentage_error: 18.5014 - val_mean_squared_logarithmic_error: 0.0569 - val_log_cosh: 26.6147
# Epoch 7/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 28.9434 - huber_loss: 28.9447 - mean_squared_error: 1532.3473 - mean_absolute_error: 29.4406 - mean_absolute_percentage_error: 19.7586 - mean_squared_logarithmic_error: 0.0684 - log_cosh: 28.7577 - val_loss: 26.5921 - val_huber_loss: 26.5927 - val_mean_squared_error: 1254.7100 - val_mean_absolute_error: 27.0885 - val_mean_absolute_percentage_error: 19.0051 - val_mean_squared_logarithmic_error: 0.0564 - val_log_cosh: 26.4058
# Epoch 8/15
# 2142/2142 [==============================] - 43s 20ms/step - loss: 28.9105 - huber_loss: 28.9124 - mean_squared_error: 1526.4846 - mean_absolute_error: 29.4083 - mean_absolute_percentage_error: 19.7221 - mean_squared_logarithmic_error: 0.0678 - log_cosh: 28.7252 - val_loss: 26.4287 - val_huber_loss: 26.4294 - val_mean_squared_error: 1233.8541 - val_mean_absolute_error: 26.9249 - val_mean_absolute_percentage_error: 19.2186 - val_mean_squared_logarithmic_error: 0.0563 - val_log_cosh: 26.2426
# Epoch 9/15
# 2142/2142 [==============================] - 47s 22ms/step - loss: 28.7003 - huber_loss: 28.7027 - mean_squared_error: 1500.1383 - mean_absolute_error: 29.1985 - mean_absolute_percentage_error: 19.6157 - mean_squared_logarithmic_error: 0.0669 - log_cosh: 28.5156 - val_loss: 26.4120 - val_huber_loss: 26.4127 - val_mean_squared_error: 1236.0873 - val_mean_absolute_error: 26.9087 - val_mean_absolute_percentage_error: 18.7473 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 26.2255
# Epoch 10/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 28.5829 - huber_loss: 28.5849 - mean_squared_error: 1493.3303 - mean_absolute_error: 29.0806 - mean_absolute_percentage_error: 19.5236 - mean_squared_logarithmic_error: 0.0665 - log_cosh: 28.3978 - val_loss: 26.6305 - val_huber_loss: 26.6311 - val_mean_squared_error: 1235.4169 - val_mean_absolute_error: 27.1273 - val_mean_absolute_percentage_error: 19.6287 - val_mean_squared_logarithmic_error: 0.0567 - val_log_cosh: 26.4435
# Epoch 11/15
# 2142/2142 [==============================] - 44s 20ms/step - loss: 28.5753 - huber_loss: 28.5775 - mean_squared_error: 1491.8053 - mean_absolute_error: 29.0735 - mean_absolute_percentage_error: 19.4978 - mean_squared_logarithmic_error: 0.0660 - log_cosh: 28.3904 - val_loss: 26.1006 - val_huber_loss: 26.1013 - val_mean_squared_error: 1219.9940 - val_mean_absolute_error: 26.5974 - val_mean_absolute_percentage_error: 18.3034 - val_mean_squared_logarithmic_error: 0.0542 - val_log_cosh: 25.9143
# Epoch 12/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 28.4366 - huber_loss: 28.4392 - mean_squared_error: 1470.4146 - mean_absolute_error: 28.9351 - mean_absolute_percentage_error: 19.4186 - mean_squared_logarithmic_error: 0.0653 - log_cosh: 28.2520 - val_loss: 26.6341 - val_huber_loss: 26.6347 - val_mean_squared_error: 1234.0498 - val_mean_absolute_error: 27.1308 - val_mean_absolute_percentage_error: 19.7204 - val_mean_squared_logarithmic_error: 0.0569 - val_log_cosh: 26.4478
# Epoch 13/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 28.2400 - huber_loss: 28.2415 - mean_squared_error: 1454.7554 - mean_absolute_error: 28.7374 - mean_absolute_percentage_error: 19.3019 - mean_squared_logarithmic_error: 0.0646 - log_cosh: 28.0542 - val_loss: 26.4073 - val_huber_loss: 26.4079 - val_mean_squared_error: 1218.7053 - val_mean_absolute_error: 26.9038 - val_mean_absolute_percentage_error: 19.4760 - val_mean_squared_logarithmic_error: 0.0561 - val_log_cosh: 26.2209
# Epoch 14/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 28.2580 - huber_loss: 28.2601 - mean_squared_error: 1458.7346 - mean_absolute_error: 28.7560 - mean_absolute_percentage_error: 19.3008 - mean_squared_logarithmic_error: 0.0645 - log_cosh: 28.0731 - val_loss: 26.6779 - val_huber_loss: 26.6785 - val_mean_squared_error: 1228.7441 - val_mean_absolute_error: 27.1740 - val_mean_absolute_percentage_error: 19.9139 - val_mean_squared_logarithmic_error: 0.0570 - val_log_cosh: 26.4913
# Epoch 15/15
# 2142/2142 [==============================] - 45s 21ms/step - loss: 28.1675 - huber_loss: 28.1697 - mean_squared_error: 1448.7325 - mean_absolute_error: 28.6652 - mean_absolute_percentage_error: 19.2225 - mean_squared_logarithmic_error: 0.0639 - log_cosh: 27.9829 - val_loss: 26.5344 - val_huber_loss: 26.5351 - val_mean_squared_error: 1276.2701 - val_mean_absolute_error: 27.0307 - val_mean_absolute_percentage_error: 17.7700 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 26.3483
# 595/595 [==============================] - 4s 7ms/step - loss: 26.5997 - huber_loss: 26.5995 - mean_squared_error: 1211.3693 - mean_absolute_error: 27.0957 - mean_absolute_percentage_error: 16.9163 - mean_squared_logarithmic_error: 0.0463 - log_cosh: 26.4119
# 595/595 [==============================] - 3s 6ms/step - loss: 27.5057 - huber_loss: 27.5057 - mean_squared_error: 1324.2195 - mean_absolute_error: 28.0012 - mean_absolute_percentage_error: 16.7764 - mean_squared_logarithmic_error: 0.0499 - log_cosh: 27.3189
# 595/595 [==============================] - 3s 4ms/step
# 595/595 [==============================] - 3s 4ms/step
# -------------------------------------------------------
#
# 3-LIB193385
#
# PRETRAINED_MODEL
# Epoch 1/15
# ...
# -------------------------------------------------------
#
# 4-LIB193367
#
# PRETRAINED_MODEL
# Epoch 1/15
# 1601/1601 [==============================] - 45s 21ms/step - loss: 28.6793 - huber_loss: 28.6790 - mean_squared_error: 1505.0448 - mean_absolute_error: 29.1749 - mean_absolute_percentage_error: 19.4541 - mean_squared_logarithmic_error: 0.0660 - log_cosh: 28.4919 - val_loss: 36.8728 - val_huber_loss: 36.8807 - val_mean_squared_error: 2110.2612 - val_mean_absolute_error: 37.3787 - val_mean_absolute_percentage_error: 24.0452 - val_mean_squared_logarithmic_error: 0.1168 - val_log_cosh: 36.6903
# Epoch 2/15
# 1601/1601 [==============================] - 33s 20ms/step - loss: 28.7297 - huber_loss: 28.7337 - mean_squared_error: 1505.1967 - mean_absolute_error: 29.2298 - mean_absolute_percentage_error: 19.4040 - mean_squared_logarithmic_error: 0.0662 - log_cosh: 28.5467 - val_loss: 27.7324 - val_huber_loss: 27.7328 - val_mean_squared_error: 1394.6282 - val_mean_absolute_error: 28.2288 - val_mean_absolute_percentage_error: 18.1275 - val_mean_squared_logarithmic_error: 0.0683 - val_log_cosh: 27.5461
# Epoch 3/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 28.6048 - huber_loss: 28.6029 - mean_squared_error: 1495.3781 - mean_absolute_error: 29.0986 - mean_absolute_percentage_error: 19.3450 - mean_squared_logarithmic_error: 0.0655 - log_cosh: 28.4158 - val_loss: 33.4186 - val_huber_loss: 33.4238 - val_mean_squared_error: 1831.0685 - val_mean_absolute_error: 33.9208 - val_mean_absolute_percentage_error: 21.7228 - val_mean_squared_logarithmic_error: 0.0970 - val_log_cosh: 33.2347
# Epoch 4/15
# 1601/1601 [==============================] - 34s 22ms/step - loss: 28.4496 - huber_loss: 28.4619 - mean_squared_error: 1490.3115 - mean_absolute_error: 28.9577 - mean_absolute_percentage_error: 19.2337 - mean_squared_logarithmic_error: 0.0657 - log_cosh: 28.2749 - val_loss: 34.7004 - val_huber_loss: 34.7069 - val_mean_squared_error: 1936.2435 - val_mean_absolute_error: 35.2048 - val_mean_absolute_percentage_error: 22.4718 - val_mean_squared_logarithmic_error: 0.1023 - val_log_cosh: 34.5172
# Epoch 5/15
# 1601/1601 [==============================] - 32s 20ms/step - loss: 28.5164 - huber_loss: 28.5185 - mean_squared_error: 1491.0138 - mean_absolute_error: 29.0144 - mean_absolute_percentage_error: 19.2848 - mean_squared_logarithmic_error: 0.0653 - log_cosh: 28.3315 - val_loss: 31.9439 - val_huber_loss: 31.9488 - val_mean_squared_error: 1716.0127 - val_mean_absolute_error: 32.4461 - val_mean_absolute_percentage_error: 20.7269 - val_mean_squared_logarithmic_error: 0.0883 - val_log_cosh: 31.7598
# Epoch 6/15
# 1601/1601 [==============================] - 32s 20ms/step - loss: 28.4093 - huber_loss: 28.4155 - mean_squared_error: 1479.9016 - mean_absolute_error: 28.9113 - mean_absolute_percentage_error: 19.2530 - mean_squared_logarithmic_error: 0.0651 - log_cosh: 28.2286 - val_loss: 31.6727 - val_huber_loss: 31.6776 - val_mean_squared_error: 1697.1494 - val_mean_absolute_error: 32.1745 - val_mean_absolute_percentage_error: 20.4952 - val_mean_squared_logarithmic_error: 0.0861 - val_log_cosh: 31.4888
# Epoch 7/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 28.4828 - huber_loss: 28.4941 - mean_squared_error: 1484.6562 - mean_absolute_error: 28.9898 - mean_absolute_percentage_error: 19.3077 - mean_squared_logarithmic_error: 0.0651 - log_cosh: 28.3072 - val_loss: 30.3901 - val_huber_loss: 30.3942 - val_mean_squared_error: 1599.9937 - val_mean_absolute_error: 30.8909 - val_mean_absolute_percentage_error: 19.7590 - val_mean_squared_logarithmic_error: 0.0815 - val_log_cosh: 30.2065
# Epoch 8/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 28.4821 - huber_loss: 28.4945 - mean_squared_error: 1481.8429 - mean_absolute_error: 28.9904 - mean_absolute_percentage_error: 19.3292 - mean_squared_logarithmic_error: 0.0649 - log_cosh: 28.3075 - val_loss: 32.6409 - val_huber_loss: 32.6471 - val_mean_squared_error: 1773.6880 - val_mean_absolute_error: 33.1445 - val_mean_absolute_percentage_error: 21.1366 - val_mean_squared_logarithmic_error: 0.0915 - val_log_cosh: 32.4580
# Epoch 9/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 28.3329 - huber_loss: 28.3368 - mean_squared_error: 1467.0706 - mean_absolute_error: 28.8323 - mean_absolute_percentage_error: 19.2194 - mean_squared_logarithmic_error: 0.0644 - log_cosh: 28.1499 - val_loss: 30.1152 - val_huber_loss: 30.1196 - val_mean_squared_error: 1581.4170 - val_mean_absolute_error: 30.6155 - val_mean_absolute_percentage_error: 19.5335 - val_mean_squared_logarithmic_error: 0.0794 - val_log_cosh: 29.9322
# Epoch 10/15
# 1601/1601 [==============================] - 35s 22ms/step - loss: 28.2868 - huber_loss: 28.2927 - mean_squared_error: 1461.2599 - mean_absolute_error: 28.7886 - mean_absolute_percentage_error: 19.1645 - mean_squared_logarithmic_error: 0.0641 - log_cosh: 28.1057 - val_loss: 34.8448 - val_huber_loss: 34.8526 - val_mean_squared_error: 1954.8750 - val_mean_absolute_error: 35.3502 - val_mean_absolute_percentage_error: 22.3986 - val_mean_squared_logarithmic_error: 0.1000 - val_log_cosh: 34.6632
# Epoch 11/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 28.2751 - huber_loss: 28.2715 - mean_squared_error: 1456.3544 - mean_absolute_error: 28.7674 - mean_absolute_percentage_error: 19.1835 - mean_squared_logarithmic_error: 0.0640 - log_cosh: 28.0843 - val_loss: 30.4109 - val_huber_loss: 30.4157 - val_mean_squared_error: 1601.6387 - val_mean_absolute_error: 30.9121 - val_mean_absolute_percentage_error: 19.7070 - val_mean_squared_logarithmic_error: 0.0803 - val_log_cosh: 30.2279
# Epoch 12/15
# 1601/1601 [==============================] - 34s 21ms/step - loss: 28.2876 - huber_loss: 28.2924 - mean_squared_error: 1462.9664 - mean_absolute_error: 28.7881 - mean_absolute_percentage_error: 19.1494 - mean_squared_logarithmic_error: 0.0639 - log_cosh: 28.1056 - val_loss: 32.9383 - val_huber_loss: 32.9460 - val_mean_squared_error: 1798.9957 - val_mean_absolute_error: 33.4433 - val_mean_absolute_percentage_error: 21.2437 - val_mean_squared_logarithmic_error: 0.0914 - val_log_cosh: 32.7568
# Epoch 13/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 28.1834 - huber_loss: 28.1920 - mean_squared_error: 1449.7831 - mean_absolute_error: 28.6880 - mean_absolute_percentage_error: 19.1068 - mean_squared_logarithmic_error: 0.0633 - log_cosh: 28.0049 - val_loss: 30.6567 - val_huber_loss: 30.6620 - val_mean_squared_error: 1622.4178 - val_mean_absolute_error: 31.1577 - val_mean_absolute_percentage_error: 19.8026 - val_mean_squared_logarithmic_error: 0.0805 - val_log_cosh: 30.4745
# Epoch 14/15
# 1601/1601 [==============================] - 32s 20ms/step - loss: 28.1112 - huber_loss: 28.1153 - mean_squared_error: 1446.5488 - mean_absolute_error: 28.6111 - mean_absolute_percentage_error: 19.0866 - mean_squared_logarithmic_error: 0.0632 - log_cosh: 27.9283 - val_loss: 29.5298 - val_huber_loss: 29.5348 - val_mean_squared_error: 1536.7031 - val_mean_absolute_error: 30.0310 - val_mean_absolute_percentage_error: 19.1424 - val_mean_squared_logarithmic_error: 0.0760 - val_log_cosh: 29.3475
# Epoch 15/15
# 1601/1601 [==============================] - 33s 20ms/step - loss: 28.2067 - huber_loss: 28.2093 - mean_squared_error: 1457.9548 - mean_absolute_error: 28.7052 - mean_absolute_percentage_error: 19.0984 - mean_squared_logarithmic_error: 0.0635 - log_cosh: 28.0221 - val_loss: 26.4772 - val_huber_loss: 26.4792 - val_mean_squared_error: 1307.3906 - val_mean_absolute_error: 26.9739 - val_mean_absolute_percentage_error: 17.3311 - val_mean_squared_logarithmic_error: 0.0622 - val_log_cosh: 26.2931
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 1601/1601 [==============================] - 47s 22ms/step - loss: 36.6132 - huber_loss: 36.6163 - mean_squared_error: 2539.2537 - mean_absolute_error: 37.1131 - mean_absolute_percentage_error: 24.9578 - mean_squared_logarithmic_error: 0.1916 - log_cosh: 36.4281 - val_loss: 35.3898 - val_huber_loss: 35.3902 - val_mean_squared_error: 2011.0189 - val_mean_absolute_error: 35.8874 - val_mean_absolute_percentage_error: 23.2383 - val_mean_squared_logarithmic_error: 0.1073 - val_log_cosh: 35.2013
# Epoch 2/15
# 1601/1601 [==============================] - 36s 23ms/step - loss: 32.2785 - huber_loss: 32.2810 - mean_squared_error: 1874.1533 - mean_absolute_error: 32.7771 - mean_absolute_percentage_error: 21.9413 - mean_squared_logarithmic_error: 0.0832 - log_cosh: 32.0934 - val_loss: 33.5222 - val_huber_loss: 33.5217 - val_mean_squared_error: 1839.2614 - val_mean_absolute_error: 34.0191 - val_mean_absolute_percentage_error: 22.0087 - val_mean_squared_logarithmic_error: 0.0962 - val_log_cosh: 33.3321
# Epoch 3/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 31.3073 - huber_loss: 31.3059 - mean_squared_error: 1778.8804 - mean_absolute_error: 31.8019 - mean_absolute_percentage_error: 21.2288 - mean_squared_logarithmic_error: 0.0784 - log_cosh: 31.1185 - val_loss: 34.1890 - val_huber_loss: 34.1899 - val_mean_squared_error: 1889.2383 - val_mean_absolute_error: 34.6877 - val_mean_absolute_percentage_error: 22.4135 - val_mean_squared_logarithmic_error: 0.1001 - val_log_cosh: 34.0003
# Epoch 4/15
# 1601/1601 [==============================] - 34s 21ms/step - loss: 30.7941 - huber_loss: 30.7950 - mean_squared_error: 1712.7512 - mean_absolute_error: 31.2912 - mean_absolute_percentage_error: 20.8773 - mean_squared_logarithmic_error: 0.0758 - log_cosh: 30.6075 - val_loss: 34.5658 - val_huber_loss: 34.5675 - val_mean_squared_error: 1916.7421 - val_mean_absolute_error: 35.0653 - val_mean_absolute_percentage_error: 22.6317 - val_mean_squared_logarithmic_error: 0.1021 - val_log_cosh: 34.3778
# Epoch 5/15
# 1601/1601 [==============================] - 34s 22ms/step - loss: 30.5749 - huber_loss: 30.5720 - mean_squared_error: 1689.8904 - mean_absolute_error: 31.0682 - mean_absolute_percentage_error: 20.6687 - mean_squared_logarithmic_error: 0.0747 - log_cosh: 30.3845 - val_loss: 31.2619 - val_huber_loss: 31.2613 - val_mean_squared_error: 1653.9456 - val_mean_absolute_error: 31.7581 - val_mean_absolute_percentage_error: 20.5774 - val_mean_squared_logarithmic_error: 0.0859 - val_log_cosh: 31.0727
# Epoch 6/15
# 1601/1601 [==============================] - 34s 21ms/step - loss: 30.1576 - huber_loss: 30.1591 - mean_squared_error: 1648.9636 - mean_absolute_error: 30.6552 - mean_absolute_percentage_error: 20.4137 - mean_squared_logarithmic_error: 0.0733 - log_cosh: 29.9717 - val_loss: 32.4770 - val_huber_loss: 32.4778 - val_mean_squared_error: 1750.3370 - val_mean_absolute_error: 32.9748 - val_mean_absolute_percentage_error: 21.2728 - val_mean_squared_logarithmic_error: 0.0914 - val_log_cosh: 32.2888
# Epoch 7/15
# 1601/1601 [==============================] - 36s 22ms/step - loss: 30.0287 - huber_loss: 30.0421 - mean_squared_error: 1641.9435 - mean_absolute_error: 30.5382 - mean_absolute_percentage_error: 20.3518 - mean_squared_logarithmic_error: 0.0724 - log_cosh: 29.8549 - val_loss: 31.6611 - val_huber_loss: 31.6619 - val_mean_squared_error: 1683.9595 - val_mean_absolute_error: 32.1589 - val_mean_absolute_percentage_error: 20.7831 - val_mean_squared_logarithmic_error: 0.0877 - val_log_cosh: 31.4728
# Epoch 8/15
# 1601/1601 [==============================] - 34s 21ms/step - loss: 29.7849 - huber_loss: 29.7921 - mean_squared_error: 1623.1665 - mean_absolute_error: 30.2880 - mean_absolute_percentage_error: 20.1818 - mean_squared_logarithmic_error: 0.0716 - log_cosh: 29.6050 - val_loss: 35.4088 - val_huber_loss: 35.4126 - val_mean_squared_error: 1984.3357 - val_mean_absolute_error: 35.9103 - val_mean_absolute_percentage_error: 23.1190 - val_mean_squared_logarithmic_error: 0.1069 - val_log_cosh: 35.2228
# Epoch 9/15
# 1601/1601 [==============================] - 36s 23ms/step - loss: 29.6773 - huber_loss: 29.6775 - mean_squared_error: 1603.6888 - mean_absolute_error: 30.1731 - mean_absolute_percentage_error: 20.1162 - mean_squared_logarithmic_error: 0.0707 - log_cosh: 29.4905 - val_loss: 29.6222 - val_huber_loss: 29.6219 - val_mean_squared_error: 1530.1708 - val_mean_absolute_error: 30.1178 - val_mean_absolute_percentage_error: 19.4377 - val_mean_squared_logarithmic_error: 0.0772 - val_log_cosh: 29.4342
# Epoch 10/15
# 1601/1601 [==============================] - 35s 22ms/step - loss: 29.4841 - huber_loss: 29.4830 - mean_squared_error: 1588.2462 - mean_absolute_error: 29.9788 - mean_absolute_percentage_error: 19.9712 - mean_squared_logarithmic_error: 0.0701 - log_cosh: 29.2959 - val_loss: 35.3853 - val_huber_loss: 35.3913 - val_mean_squared_error: 1984.6935 - val_mean_absolute_error: 35.8888 - val_mean_absolute_percentage_error: 23.0898 - val_mean_squared_logarithmic_error: 0.1068 - val_log_cosh: 35.2016
# Epoch 11/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 29.4793 - huber_loss: 29.4752 - mean_squared_error: 1581.1005 - mean_absolute_error: 29.9707 - mean_absolute_percentage_error: 19.9990 - mean_squared_logarithmic_error: 0.0699 - log_cosh: 29.2882 - val_loss: 31.4090 - val_huber_loss: 31.4106 - val_mean_squared_error: 1669.0582 - val_mean_absolute_error: 31.9077 - val_mean_absolute_percentage_error: 20.4912 - val_mean_squared_logarithmic_error: 0.0853 - val_log_cosh: 31.2219
# Epoch 12/15
# 1601/1601 [==============================] - 33s 21ms/step - loss: 29.2926 - huber_loss: 29.2829 - mean_squared_error: 1567.1072 - mean_absolute_error: 29.7789 - mean_absolute_percentage_error: 19.8291 - mean_squared_logarithmic_error: 0.0692 - log_cosh: 29.0955 - val_loss: 23.0511 - val_huber_loss: 23.0429 - val_mean_squared_error: 1054.5752 - val_mean_absolute_error: 23.5373 - val_mean_absolute_percentage_error: 15.9005 - val_mean_squared_logarithmic_error: 0.0506 - val_log_cosh: 22.8583
# Epoch 13/15
# 1601/1601 [==============================] - 33s 20ms/step - loss: 29.2082 - huber_loss: 29.2091 - mean_squared_error: 1557.0731 - mean_absolute_error: 29.7048 - mean_absolute_percentage_error: 19.7534 - mean_squared_logarithmic_error: 0.0686 - log_cosh: 29.0221 - val_loss: 32.7978 - val_huber_loss: 32.8019 - val_mean_squared_error: 1777.0488 - val_mean_absolute_error: 33.2997 - val_mean_absolute_percentage_error: 21.3737 - val_mean_squared_logarithmic_error: 0.0924 - val_log_cosh: 32.6124
# Epoch 14/15
# 1601/1601 [==============================] - 36s 22ms/step - loss: 29.1560 - huber_loss: 29.1600 - mean_squared_error: 1551.1659 - mean_absolute_error: 29.6559 - mean_absolute_percentage_error: 19.7435 - mean_squared_logarithmic_error: 0.0684 - log_cosh: 28.9731 - val_loss: 31.4636 - val_huber_loss: 31.4664 - val_mean_squared_error: 1675.6361 - val_mean_absolute_error: 31.9631 - val_mean_absolute_percentage_error: 20.5057 - val_mean_squared_logarithmic_error: 0.0860 - val_log_cosh: 31.2778
# Epoch 15/15
# 1601/1601 [==============================] - 36s 23ms/step - loss: 29.0498 - huber_loss: 29.0416 - mean_squared_error: 1541.0977 - mean_absolute_error: 29.5373 - mean_absolute_percentage_error: 19.6631 - mean_squared_logarithmic_error: 0.0677 - log_cosh: 28.8545 - val_loss: 23.0570 - val_huber_loss: 23.0498 - val_mean_squared_error: 1051.3781 - val_mean_absolute_error: 23.5447 - val_mean_absolute_percentage_error: 15.8526 - val_mean_squared_logarithmic_error: 0.0497 - val_log_cosh: 22.8651
# 445/445 [==============================] - 3s 7ms/step - loss: 29.0804 - huber_loss: 29.0813 - mean_squared_error: 1488.7826 - mean_absolute_error: 29.5771 - mean_absolute_percentage_error: 18.4149 - mean_squared_logarithmic_error: 0.0687 - log_cosh: 28.8944
# 445/445 [==============================] - 3s 8ms/step - loss: 25.2470 - huber_loss: 25.2528 - mean_squared_error: 1201.1560 - mean_absolute_error: 25.7477 - mean_absolute_percentage_error: 16.8253 - mean_squared_logarithmic_error: 0.0552 - log_cosh: 25.0670
# 445/445 [==============================] - 2s 4ms/step
# 445/445 [==============================] - 2s 4ms/step
# -------------------------------------------------------

# %%
for ind in range(0,len(test_patients)):
  np.save(checkpoint_folder+'pretrained_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',pretrained_metrics[ind].history)
  np.save(checkpoint_folder+'fromthescratch_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',fromthescratch_metrics[ind].history)
  np.save(checkpoint_folder+'test_pretrained_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',np.array(test_pretrained_metrics[ind]))
  np.save(checkpoint_folder+'test_fromthescratch_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',np.array(test_fromthescratch_metrics[ind]))

# %%
notebook_endtime=time.time()
notebook_time=(notebook_endtime-notebook_startime)

print(notebook_time)
print(optimization_time)
print(pretraining_time)
print(training_time)
# Out:
# 21656.9884018898
# 4619.245965719223
# 5272.275526762009
# 6583.991371393204

# %%
print('Notebook Execution Time: '+str(round(notebook_time/3600,2))+' hours')
print('Hyperparameter Optimization Execution Time: '+str(round(optimization_time/3600,2))+' hours')
print('Pretraining Execution Time: '+str(round(pretraining_time/3600,2))+' hours')
print('Training Execution Time: '+str(round(training_time/3600,2))+' hours')
# Out:
# Notebook Execution Time: 6.02 hours
# Hyperparameter Optimization Execution Time: 1.28 hours
# Pretraining Execution Time: 1.46 hours
# Training Execution Time: 1.83 hours
