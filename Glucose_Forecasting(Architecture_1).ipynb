# %% [markdown]
# #Data

# %% [markdown]
# ##Exploration

# %% [markdown]
#   In this chapter, we are going to study the data that we are going to use to train and validate our models. We are going to preprocess the data too.
#
# First, we need to import our data from the drive:

# %%
import time

notebook_startime = time.time()
ARCHITECTURE_NUMBER=1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install --quiet hyperas

# %%
from google.colab import drive    #We first import the dataset from the drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
import random
import keras
import os

seed=0

def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(seed)

# %% [markdown]
# We need to import the dataset as a pandas dataframe

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/drive/MyDrive/Glucose_measurements_sample(1).csv')     #Import of the dataset as a pandas dataframe

# %% [markdown]
# Next, we need to join the Year/Month/Day column withe the Hour:Minute:Second column to create a single column with all the information of the dates tha we need

# %%
df['Measurement_date']=df['Measurement_date']+' '+df['Measurement_time']   #Joining of those two date columns in a single one
df=df.drop(columns=['Measurement_time'])         #Drop the Hour:Minute:Second column now that this information is contained in the 'Measurement_Date' column

# %%
df.head()      #Display of the whole dataframe
# Out:
#   Patient_ID     Measurement_date  Measurement
# 0  LIB193263  2020-06-09 19:08:00           99
# 1  LIB193263  2020-06-09 19:23:00           92
# 2  LIB193263  2020-06-09 19:38:00           86
# 3  LIB193263  2020-06-09 19:53:00           85
# 4  LIB193263  2020-06-09 20:08:00           85

# %%
df.describe()    #get some general statistics from the dataframe in question
# Out:
#         Measurement
# count  3.000000e+06
# mean   1.589509e+02
# std    6.543033e+01
# min    4.000000e+01
# 25%    1.100000e+02
# 50%    1.480000e+02
# 75%    1.970000e+02
# max    5.000000e+02

# %% [markdown]
# Each element of date column that we have just created next to be converted from string to TimeStamp

# %%
df['Measurement_date']=pd.to_datetime(df['Measurement_date'],format='%Y-%m-%d %H:%M:%S.%f')   #Conversion from string to timestamp

# %%
print(type(df['Measurement_date'][0]))                #Check if we have the 'Measurement_date' column in a timestamp format
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# Next, the date column that we just have converted to timestamp is going to be set as the index of our dataframe

# %%
df.set_index('Measurement_date', inplace = True)      #Making the whole date column the index of the dataframe

# %% [markdown]
# Making a simple visualization of the csv of the data

# %%
df.head()       #Visualization of the head of the dataframe
# Out:
#                     Patient_ID  Measurement
# Measurement_date
# 2020-06-09 19:08:00  LIB193263           99
# 2020-06-09 19:23:00  LIB193263           92
# 2020-06-09 19:38:00  LIB193263           86
# 2020-06-09 19:53:00  LIB193263           85
# 2020-06-09 20:08:00  LIB193263           85

# %% [markdown]
# Now, we can start playing with the dataframe to extract information. First, we are going to extract the number of different patients whose glucose time series are present in this dataframe by getting all the unique elements from the column 'Patient_ID', column that represents the patient to which the glucose measurement belongs to.

# %%
patients=df['Patient_ID'].unique()     #Getting the unique patients and putting them into a list of unique patients
print(len(patients))                   #Visualization of the number of unique patients of this dataset
# Out:
# 110

# %%
print(patients[0])                     #Print the first patient ID in the list
# Out:
# LIB193263

# %%
print(df.isnull().sum())               #Check the number of Nans that there are in the whole dataframe of patients. As we can see, we don't have to worry in Nan values.
# Out:
# Patient_ID     0
# Measurement    0
# dtype: int64

# %% [markdown]
# Now, we are going to take the glucose time series data related to the first patient of this list of unique patients. Next we are going to plot this timeseries with different frequencies, just so we can visualize the data which we are working with.

# %%
patient1 = df[df['Patient_ID'] == 'LIB193263']      #the glucose time series dataframe related to the first patient of the list of unique patients

# %% [markdown]
# We first make a visualization of the data in a little timespam, like a few hours

# %%
import matplotlib.pyplot as plt        #Simple matplotlib visualization of a patient levels of glucose time series in a relatively small time range
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
original_data=patient1['Measurement'][400:430]
ax.plot(patient1['Measurement'][400:430])
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 30]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.grid()
plt.show()

# %% [markdown]
# And them we are going to make a visualization of the data in a larger timespam, like a few days

# %%
import matplotlib.pyplot as plt       #Simple matplotlib visualization of a patient levels of glucose time series in a wider time range
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
ax.plot(patient1['Measurement'][:3000])
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.DayLocator(interval=3))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.grid()
plt.show()

# %% [markdown]
# And them, we need to append in a list the different timeseries related to every patient each one as a element of a list that will contain the dataframes of all patients differentiated

# %%
time_series_per_patient=[]     #List in which we are going to store the part of the dataframe related to each patient each one as a different element of this list

for patient in patients:
  time_series_per_patient.append(df[df['Patient_ID'] == patient])     #Appending the information related to each patient each one as a different element of this list

# %%
time_series_per_patient[0].head()              #check the time series correspondent to the first patient in the list
# Out:
#                     Patient_ID  Measurement
# Measurement_date
# 2020-06-09 19:08:00  LIB193263           99
# 2020-06-09 19:23:00  LIB193263           92
# 2020-06-09 19:38:00  LIB193263           86
# 2020-06-09 19:53:00  LIB193263           85
# 2020-06-09 20:08:00  LIB193263           85

# %% [markdown]
# ##Resampling

# %% [markdown]
# Now, we are going to measure the elements of every time series that are oversampled or undersampled, under and over 15 min, timestamp that have to be the sampling frequency of every time series. For those elements that are undersampled, we are going to take the missing values until the next value of glucose, because maybe if we miss one or two ticks of glucose measurement in a gap, we can interpolate this gap. For more ticks of missing values, we could treat this gap of missing values as a real gap that will not be interpolated, because if we interpolate two days of missing values of glucose, the dataset will change a lot in terms of reality, which is something that we dont want at all.

# %%
oversamples=[]              #list which contains a counter of oversample values for every patient
undersamples=[]             #list which contains a counter of undersample values for every patient
undersample_freq=[]         #list which contains the number of missing values in an undersampled gap

for time_series in time_series_per_patient:
  time_diff = time_series.index.to_series().diff()[1:]                              #list of sampling frequencies
  morethan15min_positions = time_diff[time_diff > pd.Timedelta(minutes=15)].index   #+1 index of those positions with a sampling frequency with more than 15 minutes of value
  lessthan15min_positions = time_diff[time_diff < pd.Timedelta(minutes=15)].index   #+1 index of those positions with a sampling frequency with less than 15 minutes of value
  oversamples.append(len(lessthan15min_positions))                                  #list of number of samples  with less than 15 minutes of sampling frequency from every every patient
  undersamples.append(len(morethan15min_positions))                                 #list of number of samples  with more than 15 minutes of sampling frequency from every every patient
  undersample_freq+=list(time_diff[time_diff > pd.Timedelta(minutes=15)])           #list of sampling frequency values that are over 15 minutes from every patient

# %%
print(np.sum(oversamples))        #Number of oversample values in the whole dataframe
print(np.sum(undersamples))       #Number of undersample values in the whole dataframe
# Out:
# 136533
# 167091

# %%
print(np.sum(pd.Series(undersample_freq) > pd.Timedelta(minutes=45)))     #If the gap of missing values is equal or less than 30 minutes, we are going to interpolate that gap
# Out:
# 16345

# %% [markdown]
# Then, we check the date of beginning and end of some time series correspondent to the first 5 patients in the list, the length of every time series and the length that every time series from every patient must have to obey an uniform sampling frequency. The uniform length is the length that the time series must have to achieve sampling every 15 minutes form start date to end date of the time series.
#
# Of course, with the resampling of these time series, we will do various things:
#
# 1- First, we are going to determine where the gaps with more that 45 minutes are, i.e. those gaps where more two values of glucose are missing, those gaps are going to be untouched. But next to finding where this gaps are, we are going to locate those gaps that are less or equal to 45 minutes, i.e. those gaps where there are two or one values missing and we are going to interpolate this gaps.
#
# 2- Next, we are going to correct uneven sampling frequencies. You see, the mayority of the samples of the time series are separated by 15 minutes, but some values are separated 16 minutes or 14 minutes or even less or more. We are going to make this values be separated by 15 minutes only with interpolating tools.
#
# by doing these steps in the resample phase of this work, we are most likely not to achieve this Uniform Length mencioned earlier, because, we are going to leave these more than 45 minutes gaps untouched, so at the end, the actual length of the time series of every patient will be most likely different to its uniform length.

# %%
for time_series in time_series_per_patient[:5]:
  print('Patient_ID:',time_series['Patient_ID'][0])
  print('Beggining datetime:',time_series.index[0])
  print('Ending datetime:',time_series.index[-1])
  print('Actual Length:',len(time_series))
  print('Uniform Length:',int((time_series.index[-1]-time_series.index[0])/pd.Timedelta(minutes=15)))
  print('TimeDelta:',(time_series.index[-1]-time_series.index[0]))
  print('--------------------------------\n')
# Out:
# Patient_ID: LIB193263
# Beggining datetime: 2020-06-09 19:08:00
# Ending datetime: 2022-03-19 07:32:00
# Actual Length: 60098
# Uniform Length: 62161
# TimeDelta: 647 days 12:24:00
# --------------------------------
#
# Patient_ID: LIB193264
# Beggining datetime: 2020-06-10 00:54:00
# Ending datetime: 2022-03-19 11:56:00
# Actual Length: 26787
# Uniform Length: 62156
# TimeDelta: 647 days 11:02:00
# --------------------------------
#
# Patient_ID: LIB193265
# Beggining datetime: 2019-01-27 10:52:00
# Ending datetime: 2022-03-19 22:04:00
# Actual Length: 46576
# Uniform Length: 110156
# TimeDelta: 1147 days 11:12:00
# --------------------------------
#
# Patient_ID: LIB193266
# Beggining datetime: 2020-10-08 18:03:00
# Ending datetime: 2022-03-21 12:09:00
# Actual Length: 55308
# Uniform Length: 50760
# TimeDelta: 528 days 18:06:00
# --------------------------------
#
# Patient_ID: LIB193267
# Beggining datetime: 2020-06-09 19:07:00
# Ending datetime: 2022-03-17 20:15:00
# Actual Length: 55501
# Uniform Length: 62020
# TimeDelta: 646 days 01:08:00
# --------------------------------

# %% [markdown]
# Next cell is to delete rare cases of duplicate values from every patient, i.e. timestamps where there are more than one glucose measurements in one patient. We are going to drop the column 'patient_ID' that we don't need because we have stored the patient's ID index and location in the 'patients' list.

# %%
#print(time_series_per_patient[0].loc['2020-06-10 09:20:00':])

for i in range(0,len(time_series_per_patient)):
  time_series_per_patient[i]= time_series_per_patient[i][~time_series_per_patient[i].index.duplicated(keep='first')]         #We are going to delete rare cases of duplicates from every patient's time series and we are going to keep the first value of the duplicate. For duplicate, we mean, various glucose measurements for one timestamp
  time_series_per_patient[i]=time_series_per_patient[i].drop(columns=['Patient_ID'])                                         #Drop the Patient_ID column, because the location of the patients_IDs are located in the 'patients' list

# %% [markdown]
# Next, we are going to reindex and resample between every gap of more than 45 minutes (leaving those gaps untouched) to have a uniform sampling frequency for every patient between those gaps.

# %%
for index,time_series in enumerate(time_series_per_patient):                                       #Loop from every patient's glucose time series
  time_diffs = time_series.index.to_series().diff()                                                #List of sampling frequencies from the current time series' iteration
  time_diffs=time_diffs.shift(periods=-1)                                                          #Shift this list so that value and sampling frequency correspond to each other
  morethan15min_positions = time_diffs[time_diffs > pd.Timedelta(minutes=45)].index                #Index of those positions where the gaps of missing data is more than 45 minutes

  last_datetime=time_series.index[0]                                                               #These two values are the last datetime index and the 'total_slice' parameter is where we are going to store current slices in the next loop
  total_slice=None

  for datetime in morethan15min_positions:                                                         #Loop through every gap of more that 45 minutes
    current_slice=time_series[last_datetime:datetime]                                              #This is the dataframe slice between gaps of more than 45 values of the current iteration
    #https://stackoverflow.com/questions/47148446/pandas-resample-interpolate-is-producing-nans
    oidx = current_slice.index                                                                     #Parameter where we are going to store the current slice index (old index)
    nidx = pd.date_range(oidx.min(), oidx[-1], freq='15T')                                         #Parameter where we are going to store the current slice index is there were a uniform sampling frequency of 15 minutes (new index)
    current_slice = current_slice.reindex(oidx.union(nidx)).interpolate('index').reindex(nidx)     #Current slice with the new index values interpolated from the values of the old index
    total_slice=pd.concat([total_slice, current_slice], axis=0)                                    #Store this resampled slice in the 'total_slice' parameter
    last_datetime=datetime+pd.Timedelta(seconds=1)                                                 #Update the 'last_datetime' parameter so the next current slice (in the next iteration) is located correctly

  time_series_per_patient[index]=total_slice                                                       #We are going to store the resampled and reindexed time series from every patient in the 'time_series_per_patient' list

# %%
import matplotlib.pyplot as plt        #Simple matplotlib visualization of the graph that we plotted earlier to check whether if the data keeps the coherence after getting resampled. We can see that the two graphs matches
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
ax.plot(time_series_per_patient[0]['Measurement'][400:430],label='Datos remuestreados')
ax.plot(original_data,label='Datos originales')
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 30]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# We check wether if we have created nans in the process of resampling, we can see in the next code cell that we haven created such nan values.

# %%
sumatory=0

for time_series in time_series_per_patient:
  sumatory+=int(time_series.isnull().sum())

print(sumatory)
# Out:
# 0

# %% [markdown]
# In the next code cell, we are going to check if we have values that are sampled over and less than 15 minutes.

# %%
oversamples=[]              #list which contains a counter of oversample values for every patient
undersamples=[]             #list which contains a counter of undersample values for every patient
undersample_freq=[]         #list which contains the number of missing values in an undersampled gap

for time_series in time_series_per_patient:
  time_diff = time_series.index.to_series().diff()[1:]
  morethan15min_positions = time_diff[time_diff > pd.Timedelta(minutes=15)].index
  lessthan15min_positions = time_diff[time_diff < pd.Timedelta(minutes=15)].index
  oversamples.append(len(lessthan15min_positions))
  undersamples.append(len(morethan15min_positions))
  undersample_freq+=list(time_diff[time_diff > pd.Timedelta(minutes=15)])

print(np.sum(oversamples))        #Number of oversample values in the whole dataframe
print(np.sum(undersamples))       #Number of undersample values in the whole dataframe
print(np.sum(pd.Series(undersample_freq) > pd.Timedelta(minutes=45)))     #If the gap of missing values is equal or less than 30 minutes, we are going to interpolate that gap
# Out:
# 0
# 16235
# 16235

# %% [markdown]
# We can observe that there are not values with less sampling frequency than 15 minutes, with only have samples over that value, other than the elements that are separated by a uniform 15 minutes, we only have elements which sampling frequency is over 15 minutes, and those gaps correspond to over 45 minutes gaps, i.e. more than two missing vale gaps. That is correct, because, as we said earlier we will only have one uniform sampling frequency other than the gaps over 45 minutes that will be untouched.

# %%
for index,time_series in enumerate(time_series_per_patient[:5]):
  print('Patient_ID:',patients[index])
  print('Beggining datetime:',time_series.index[0])
  print('Ending datetime:',time_series.index[-1])
  print('Actual Length:',len(time_series))
  print('Uniform Length:',int((time_series.index[-1]-time_series.index[0])/pd.Timedelta(minutes=15)))
  print('TimeDelta:',(time_series.index[-1]-time_series.index[0]))
  print('--------------------------------\n')
# Out:
# Patient_ID: LIB193263
# Beggining datetime: 2020-06-09 19:08:00
# Ending datetime: 2022-03-18 23:00:00
# Actual Length: 60157
# Uniform Length: 62127
# TimeDelta: 647 days 03:52:00
# --------------------------------
#
# Patient_ID: LIB193264
# Beggining datetime: 2020-06-10 00:54:00
# Ending datetime: 2022-03-18 20:16:00
# Actual Length: 26797
# Uniform Length: 62093
# TimeDelta: 646 days 19:22:00
# --------------------------------
#
# Patient_ID: LIB193265
# Beggining datetime: 2019-01-27 10:52:00
# Ending datetime: 2022-03-16 21:29:00
# Actual Length: 46381
# Uniform Length: 109866
# TimeDelta: 1144 days 10:37:00
# --------------------------------
#
# Patient_ID: LIB193266
# Beggining datetime: 2020-10-08 18:03:00
# Ending datetime: 2022-03-17 18:22:00
# Actual Length: 44514
# Uniform Length: 50401
# TimeDelta: 525 days 00:19:00
# --------------------------------
#
# Patient_ID: LIB193267
# Beggining datetime: 2020-06-09 19:07:00
# Ending datetime: 2022-03-17 07:43:00
# Actual Length: 54693
# Uniform Length: 61970
# TimeDelta: 645 days 12:36:00
# --------------------------------

# %% [markdown]
# We can observe that the actual length is not equal to the desired length (the length that the time series would have if we had measurements every 15 minutes non stop from start date to end date from the time series) because we have left the gaps over 45 minutes untouched.

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# The plan for the work is that the neural network uses a fit_generator function, so that we can utilize the GPU in the training of our neural network without running out of GPU memory in the way.
#
# To do that, we are going to take the time series of every patient, we are going to window every time series, and we are going to store within the folder 'src_folder' the windowed time series of every patient in a npy file (every patient will have a npy file named after its own patient_ID), this windowed time series must be of shape (len(time_series)-WINDOW_LENGTH+1,WINDOW_LENGTH, NUM_FEATURES), because we are working with an unidimensional time series, NUM_FEATURES must be equal to one.

# %%
import os

src_folder = "/content/windowed_dataset/"                                                   #The name of the folder where we are going to store the windowed time series of each patient

def create_folder(folder_name):                                                             #Function to create a directory only if that directory doesn't exist
  if not os.path.exists(folder_name):
      os.makedirs(folder_name)

create_folder(src_folder)                                                                   #Creation of the folder mentioned earlier
AHEAD_STEPS_PREDICTION=4                                                                    #Number of steps to predict ahead. In the case that we want to predict 1 hour ahead, AHEAD_STEPS_PREDICTION must be 4, because every value corresponds to the sampling frequency separation (15 minutes), 4 values ahead correspond to one hour ahead
WINDOW_STEPS=6                                                                              #Number of steps before the actual step we are going to take to input a window for the model to predict
PREDICTION_WINDOW=AHEAD_STEPS_PREDICTION+WINDOW_STEPS                                       #Add of these two parameters mentioned earlier                                                                         #Maybe we could take a normalization parameter to normalize those values that we are going to input our model
window_count=0

for patient_index,time_series in enumerate(time_series_per_patient):                        #Loop though every patient's glucose time series
  time_diffs = time_series.index.to_series().diff()                                         #Parameter where we are going to store the sampling frequency between every element of the current time series
  time_diffs=time_diffs.shift(periods=-1)                                                   #Shift of this parameter to make it correspong to every element of the current time series
  morethan15min_positions = time_diffs[time_diffs > pd.Timedelta(minutes=45)].index         #Those index position where there is a gap of data (over 45 minutes)
  last_datetime=time_series.index[0]                                                        #We set the last datetime of the slice to be the first index of the slice in the next loop's iterations

  for iter,datetime in enumerate(morethan15min_positions):                                  #Loop trough every gap of missing data (over 45 minutes)
    current_slice=time_series[last_datetime:datetime]                                       #Slice of time series between gaps of missing data (over 45 minutes)
    if len(current_slice)>=PREDICTION_WINDOW:                                               #If the current_slice of time series is bigger that the PREDICTION_WINDOW parameter, we can window this slice, so we keep ourselves in the loop
      windows=np.zeros((len(current_slice)-PREDICTION_WINDOW+1,PREDICTION_WINDOW,1))        #Array of zeros where we are going to store the current_slice of time series after being windowed
      for ind in range(0,len(current_slice)-PREDICTION_WINDOW+1):                           #Loop through the range of number of windows that we can create as from the current slice of time series
        windows[ind,:,:]=current_slice[ind:ind + PREDICTION_WINDOW]                         #We store the current window in the array of zeros mentioned earlier
      if iter==0:                                                                           #The general_windows parameter if where we are going to store all windows from all slices of data of the current patient. At the first slice, we initialize it as the windowed time_series of the current_slice of the current_slice
        general_windows=windows
      else:                                                                                 #But in the next slices we store the windowed current_slice with the last iteration general window with the numpy command 'concat' which allow us to update the 'general_windows' parameter without losing information at every iteration
        general_windows=np.concatenate((general_windows,windows),axis=0)
    last_datetime=datetime+pd.Timedelta(seconds=1)                                          #We update the next first datetime to index the next current_slice iteration

  np.save(src_folder+patients[patient_index],general_windows,allow_pickle=True)             #Next, we store the windowed time series of all of the current slices between gaps of missing data of each patient as a npy file named after the Patient's ID
  window_count+=np.shape(general_windows)[0]

print(np.shape(general_windows))                                                            #In order to check if everything is in order, we check the shape of the last windowed time series of the last patient of the iteration to check if the shape matches (n,PREDICTION_WINDOW,1), being n a parameter that changes in terms of the time series' length
print(window_count)                                                                         #Check number of windows
# Out:
# (5915, 10, 1)
# 2832381

# %% [markdown]
# ##Train/Test Data Split

# %% [markdown]
# The development of this Master's Thesis involves choosing a sample group of patients (between 5 and 10 patients), we are going to call this group of patients 'control group'.We need to train our 'from the scratch' model individually in the control group. Next we are going to take a pretrained model, pretrained with the rest odf the patients, when it is pretrained, we are going to train this pretrained model in the every patient of the control group individually.
#
# Finally, we are going to compare the performance of this 'from the scratch' model to the pretrained one, using different metrics.
# Ideally, the time series of the patients from  the control group must be long time series, to have a good portion of time range of the time series to test the performance of our models, for that, for the control group, we should take patients with time series with good length.

# %%
from sklearn.model_selection import train_test_split

CONTROL_GROUP_SIZE=5                                                                                               #Number of patients that will be in the control group

lengths=[]
for patient in patients:                                                                                           #A loop trough every filenames patient
  array=np.load(os.path.join(src_folder,patient)+'.npy',allow_pickle=True)                                         #Load its correspondent windowed dataset
  lengths.append(len(array))                                                                                       #Store its length in the self.lengths list

# Use sorted() to get a sorted version of the list along with their indices
sorted_numbers = sorted(enumerate(lengths), key=lambda x: x[1], reverse=True)

# Get the indices of the 5 highest values
highest_length_indices = [index for index, _ in sorted_numbers[:5]]

test_patients=[patients[index] for index in highest_length_indices]                                               #The test patients are those who have the five time series with more legth within all the patients
other_patients=[patients[index] for index in range(0,len(patients)) if index not in highest_length_indices]       #The train patients are the rest of the patients
train_patients,validation_patients=train_test_split(other_patients,test_size=0.2,random_state=0)
print(len(test_patients)+len(validation_patients)+len(train_patients))                                                                     #Check if the number of total patients is correct (It's correct, 110 patients, same as before)
# Out:
# 110

# %%
timestamps_test=[]
partial_timestamps=[]

for patient_index,patient in enumerate(test_patients):
  partial_timestamp=np.array(time_series_per_patient)[patients==patient]
  partial_timestamp=partial_timestamp[0].index
  partial_timestamps.append(partial_timestamp)
  timestamps_test+=list(partial_timestamp)

# %%
from keras.utils import Sequence

class Custom_Generator(Sequence) :

  def __init__(self, filenames, batch_size) :
    self.filenames = filenames                                                                             #The list of patients that we are going to take in our fit_generator
    self.lengths=[]                                                                                        #A list where the legths of every windowed time series of each filenames patient will be stored
    self.indexes=[0]                                                                                       # The indexes where the windowed time series of every each filenames patients end

    for filename in self.filenames:                                                                        #A loop trough every filenames patient
        array=np.load(os.path.join(src_folder,filename)+'.npy',allow_pickle=True)                          #Load its correspondent windowed dataset
        self.lengths.append(len(array))                                                                    #Store its length in the self.lengths list
        self.indexes.append(np.sum(self.lengths))                                                          #And store its ending index in the self.indexes list

    self.n_frames=np.sum(self.lengths)                                                                     #self.n_frames will be the number of windows that we are going to have in this fit_generator
    self.batch_size = batch_size                                                                           #Specification of the batch size as an argument of the class
    self.current_filename=self.filenames[0]                                                                #Specification of the name of the first patient windowed time series that we are going to feed to the neural network
    self.last_iter_index=0                                                                                 #Parameter which is going to tell us if we have reached the end of a windowed file initializated to zero
    self.windowed_file=np.load(os.path.join(src_folder,self.filenames[0])+'.npy',allow_pickle=True)        #the first patient windowed file that we are going to feed to the neural network

  def __len__(self) :                                                                                      #Method which simply returns the number of steps per epoch that we need to run through an epoch of data in this fit_generator
    return (np.floor(self.n_frames / float(self.batch_size))).astype(np.int)                               #The number of steps per epoch is going to be defined as the floor of the total number of windows that we have in this fit generator divided by its batch size

  def __getitem__(self, idx) :                                                                             #Method with give us batch in terms of the input parameter idx, in the training of a model, the range of values of idx should go from zero to the number of steps per epoch
    first_batch_index=idx * self.batch_size                                                                #These two parameters combined with the self.indexes and self.lengths can give us the correspondent batches from every time series
    second_batch_index=(idx+1) * self.batch_size

    first_index=np.sum(np.array(self.indexes)<=first_batch_index)-1                                        #Indexes that specify us where the first and last window of the batch is in terms of self.filenames index positions
    last_index=np.sum(np.array(self.indexes)<=second_batch_index)-1

    beginning_filename=self.filenames[first_index]                                                         #first and windowed time series name files where the first and last windows of time series belongs to in this current batch of data
    ending_filename=self.filenames[last_index]

    series_first_index=np.abs(self.indexes[first_index]-first_batch_index)                                 #indexes wich will help us locate the windows that we want to add in the current batch of windows
    series_last_index=np.abs(self.indexes[last_index]-second_batch_index)

    batch_x=np.zeros((self.batch_size,WINDOW_STEPS,1))                                                     #arrays of zeros where we are going to store our x and y values to feed batches to the model in which the fit generator is hooked on
    batch_y=np.zeros((self.batch_size,1))

    if first_index==0 and self.last_iter_index!=0:                                                         #When we are at the first patient windowed dataset but the last iteration was not the first windowed dataset, i.e. when idx have reached the value of steps per epoch and is reseting again from zero
      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[0])+'.npy',allow_pickle=True)      #We just set the first windowed dataset as the first patient windowed dataset without taking into account that the last windowed dataset was different

    if first_index!=0:                                                                                     #Explaining this later
      if self.last_iter_index!=first_index:
        self.windowed_file=np.load(os.path.join(src_folder,self.filenames[first_index])+'.npy',allow_pickle=True)

    if first_index==last_index:
      batch_x[:,:,:]=self.windowed_file[series_first_index:series_last_index,:WINDOW_STEPS,:]
      batch_y[:,:]=self.windowed_file[series_first_index:series_last_index,-1,:]
    elif np.abs(last_index-first_index)==1:
      len_first_slice=self.indexes[last_index]-first_batch_index
      batch_x[:len_first_slice,:,:]=self.windowed_file[series_first_index:,:WINDOW_STEPS,:]
      batch_y[:len_first_slice,:]=self.windowed_file[series_first_index:,-1,:]

      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[last_index])+'.npy',allow_pickle=True)

      batch_x[len_first_slice:,:,:]=self.windowed_file[:series_last_index,:WINDOW_STEPS,:]
      batch_y[len_first_slice:,:]=self.windowed_file[:series_last_index,-1,:]
    else:
      len_first_slice=self.indexes[first_index+1]-first_batch_index
      batch_x[:len_first_slice,:,:]=self.windowed_file[series_first_index:,:WINDOW_STEPS,:]
      batch_y[:len_first_slice,:]=self.windowed_file[series_first_index:,-1,:]
      last_slice=len_first_slice

      for i in range(first_index+1,last_index):
        self.windowed_file=np.load(os.path.join(src_folder,self.filenames[i])+'.npy',allow_pickle=True)
        #print(i)
        intermediate_array=self.windowed_file[:,:,:]
        batch_x[last_slice:last_slice+len(intermediate_array),:,:]=intermediate_array[:,:WINDOW_STEPS,:]
        batch_y[last_slice:last_slice+len(intermediate_array),:]=intermediate_array[:,-1,:]
        last_slice+=len(intermediate_array)

      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[last_index])+'.npy',allow_pickle=True)
      batch_x[last_slice:,:,:]=self.windowed_file[:series_last_index,:WINDOW_STEPS,:]
      batch_y[last_slice:,:]=self.windowed_file[:series_last_index,-1,:]

    #batch_x=batch_x
    #batch_y=denormalize(batch_y)
    batch=(batch_x,batch_y)
    self.last_iter_index=last_index
    return batch                                                                                                       #Returning the correspondent batch to the parameter idx

# %% [markdown]
# #Training

# %% [markdown]
# ##Neural Network Arquitecture

# %% [markdown]
# Next, It's the phase related to designing the model, training it, and extracting the correspondent results of metrics. First, the presentation of the design of the model that we have proposed for the development of this Master's Thesis.

# %%
import keras
import tensorflow as tf

TOTAL_EPOCHS=15

def create_model():                         #Function to create a recurrent neural network with a conv1d layers, a encoder LSTM, a decoder LSTM and fully connected layers at the end, this is known in the literature as an encoder-decoder recurrent neural network architecture.
  model=keras.models.Sequential()

  #model.add(keras.layers.Lambda(lambda x: x / 400))
  model.add(keras.layers.Conv1D(60,5,strides=1,padding='causal',activation='relu',input_shape=(None,1)))
  model.add(keras.layers.LSTM(64,return_sequences=True))
  model.add(keras.layers.LSTM(64,return_sequences=False))
  model.add(keras.layers.Dense(30))
  model.add(keras.layers.Dense(10))
  model.add(keras.layers.Dense(1))
  #model.add(keras.layers.Lambda(lambda x: x * 300))
  return model

model=create_model()                        #Then, we just call this function to create the correspondent model and plot it for visualization
keras.utils.vis_utils.plot_model(model, show_shapes=False, show_layer_names=False)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, None, 60)          360
#
#  lstm_10 (LSTM)              (None, None, 64)          32000
#
#  lstm_11 (LSTM)              (None, 64)                33024
#
#  dense_15 (Dense)            (None, 30)                1950
#
#  dense_16 (Dense)            (None, 10)                310
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 67,655
# Trainable params: 67,655
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Hyperparameter Optimization

# %% [markdown]
# Next, It's the time to optimize the parameters that are involved in the compile of the model, like learning rate, optimizer and loss. It's just like doing a random walk to find this parameters, but instead, we are going to use an especialized library for optimization of parameters (hyperas library). We first create the fit_generators that we are going to use for this hyperparameter optimization.

# %%
train_generator=Custom_Generator(train_patients,128)    #Instantiation of Custon Generator mentioned earlier
validation_generator=Custom_Generator(validation_patients,128)
test_generator=Custom_Generator(test_patients,128)

# %% [markdown]
# Next, we perform hyperparameters oiptimization with the library that we mantioned earlier within the range that we set for every hyperparameter, for exple, for loss, we are only going to search in the space of 4 losses: msle, mse, mae and Huber.

# %%
from hyperas.distributions import choice,loguniform,uniform
from hyperopt import Trials, STATUS_OK, tpe
from keras import backend as K
from keras.backend import clear_session
from tqdm.notebook import tqdm

optimization_startime=time.time()

losses=['mse','mae','huber_loss','msle','mean_absolute_percentage_error']                              #We first define the search space to optimize parameters
optimizers=['SGD','RMSprop','Adam','Adagrad']
space_tf = {'loss': choice('loss',losses),'optimizer': choice('optimizer',optimizers),'learning_rate':loguniform('learning_rate',np.log(1e-8),np.log(0.6))}
#space_tf = {'dense_depth':uniform('dense_depth',5,20),'n_hidden_neurons': uniform('n_hidden_neurons',1000,3000),'loss': choice('loss',losses),'optimizer': choice('optimizer',optimizers),'learning_rate':loguniform('learning_rate',np.log(1e-6),np.log(0.6))}

max_evals=15                                                     #Max of evaluations over the parameters that we want to optimize
epochs_per_eval=1                                                #number of epoch that our neural network will perform in each evaluation of the optimization of the parameters
pbar = tqdm(total=max_evals*epochs_per_eval, desc="Hyperopt")    #Custom loading bar to visualize the progress of the optimization algorithm

def create_optimized_model(space_sample):                        #Function to evaluate the performance of the algorithm with a set of hyperparameters to optimize. In this case, those parameters are the optimizer, the loos and the learning rate
    global pbar                                                  #This function just creates a model and lets it run truogh one epoch of out fit generator with with different hyperparameter combinations, those hyperparameters are in fact, the ones that we want to optimize
    clear_session()
    tf.random.set_seed(0)

    #dense_depth=int(space_sample['dense_depth'])
    #n_hidden_neurons=int(space_sample['n_hidden_neurons'])
    loss=space_sample['loss']
    optimizer=space_sample['optimizer']
    learning_rate=space_sample['learning_rate']

    model=create_model()     #n_hidden_neurons,dense_depth)
    model.compile(loss=loss,optimizer=optimizer,metrics=['mse'])
    K.set_value(model.optimizer.learning_rate, learning_rate)

    history=model.fit_generator(train_generator,epochs=epochs_per_eval,steps_per_epoch=int(train_generator.__len__()),verbose=0,shuffle=False)
    acc=np.amin(history.history['mse'])
    pbar.update()
    return acc                                                  #This function just returns the minimum loss reached trough one epoch

from hyperopt import tpe, fmin

best_classifier = fmin(create_optimized_model, space_tf, algo=tpe.suggest, max_evals=max_evals)    #function to return the best combination of hyperparameters that the earlier algorithm has reached
pbar.close()                                                                                       #Closes the progress bar

print('_________________________')

print(best_classifier)
print('Loss:',losses[best_classifier['loss']])
print('Optimizer:',optimizers[best_classifier['optimizer']])                                                                          #Print of the best combination of hyperparameters that we have reached in this cell of code
print('Learning Rate:',float(best_classifier['learning_rate']))

optimization_endtime=time.time()
optimization_time=(optimization_endtime-optimization_startime)
# Out:
# Hyperopt:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
#   7%|▋         | 1/15 [01:34<21:57, 94.13s/trial, best loss: 4515.966796875]
#  13%|█▎        | 2/15 [03:59<26:58, 124.52s/trial, best loss: 1593.7962646484375]
#  20%|██        | 3/15 [05:33<22:03, 110.29s/trial, best loss: 1593.7962646484375]
#  27%|██▋       | 4/15 [07:04<18:49, 102.70s/trial, best loss: 1593.7962646484375]
#  33%|███▎      | 5/15 [08:37<16:32, 99.30s/trial, best loss: 1422.5037841796875]
#  40%|████      | 6/15 [11:03<17:17, 115.27s/trial, best loss: 1422.5037841796875]
#  47%|████▋     | 7/15 [12:37<14:25, 108.20s/trial, best loss: 1266.2474365234375]
#  53%|█████▎    | 8/15 [14:08<11:59, 102.84s/trial, best loss: 1266.2474365234375]
#  60%|██████    | 9/15 [15:46<10:07, 101.28s/trial, best loss: 1266.2474365234375]
#  67%|██████▋   | 10/15 [17:18<08:12, 98.41s/trial, best loss: 1266.2474365234375]
#  73%|███████▎  | 11/15 [18:52<06:27, 96.86s/trial, best loss: 1266.2474365234375]
#  80%|████████  | 12/15 [20:28<04:50, 96.84s/trial, best loss: 1266.2474365234375]
#  87%|████████▋ | 13/15 [22:03<03:12, 96.22s/trial, best loss: 1266.2474365234375]
#  93%|█████████▎| 14/15 [24:28<01:51, 111.02s/trial, best loss: 1266.2474365234375]
# 100%|██████████| 15/15 [26:00<00:00, 104.04s/trial, best loss: 1266.2474365234375]
# _________________________
# {'learning_rate': 0.008532495211677144, 'loss': 2, 'optimizer': 3}
# Loss: huber_loss
# Optimizer: Adagrad
# Learning Rate: 0.008532495211677144

# %% [markdown]
# ##Pretraining Phase

# %% [markdown]
# In this part of the notebook, we are going to pretrain a model with the optimized combination of hyperparameters that we have searched earlier with the time series data of the patients not belonging to the control group.

# %%
pretraining_startime=time.time()
loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
optimizer=optimizers[best_classifier['optimizer']]
learning_rate=float(best_classifier['learning_rate'])
EPOCHS=TOTAL_EPOCHS                                                     #define the number of epochs in which we want to pretrain the model for the next individual trainings in the patients of the control group

metrics=[tf.keras.losses.Huber(),tf.keras.losses.MeanSquaredError(),tf.keras.losses.MeanAbsoluteError(),tf.keras.losses.MeanAbsolutePercentageError(),
         tf.keras.losses.MeanSquaredLogarithmicError(),tf.keras.losses.LogCosh()]        #Define of some metrics that we could use to evaluate our models

tf.random.set_seed(0)                                         #set random set of tensorflow
model=create_model()                                          #create one neural network from scratch with our function 'create_model()'
model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
K.set_value(model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

checkpoint_folder='/content/drive/MyDrive/Checkpoint/'        #drive folder name where we are going to save our pretrained model, and to prevent executing this pretraining every time we want to execute this notebook
create_folder(checkpoint_folder)                              #create folder
model_checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_folder+'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',save_best_only=True,monitor='val_loss',mode='auto')  #save model callback in such folder mentioned in the above lines

history=model.fit_generator(train_generator,shuffle=False,epochs=EPOCHS,steps_per_epoch=int(train_generator.__len__()),validation_data=validation_generator,validation_steps=int(validation_generator.__len__()),verbose=1,callbacks=[model_checkpoint_callback])     #pretrain this model with that callback
pretraining_endtime=time.time()
pretraining_time=(pretraining_endtime-pretraining_startime)
# Out:
# Epoch 1/15
# 14722/14722 [==============================] - 144s 10ms/step - loss: 24.2274 - huber_loss: 24.2274 - mean_squared_error: 1194.4131 - mean_absolute_error: 24.7220 - mean_absolute_percentage_error: 16.5103 - mean_squared_logarithmic_error: 0.0610 - log_cosh: 24.0423 - val_loss: 23.8695 - val_huber_loss: 23.8695 - val_mean_squared_error: 1182.7794 - val_mean_absolute_error: 24.3639 - val_mean_absolute_percentage_error: 17.8880 - val_mean_squared_logarithmic_error: 0.0560 - val_log_cosh: 23.6846
# Epoch 2/15
# 14722/14722 [==============================] - 139s 9ms/step - loss: 22.3390 - huber_loss: 22.3390 - mean_squared_error: 1014.7172 - mean_absolute_error: 22.8331 - mean_absolute_percentage_error: 15.3491 - mean_squared_logarithmic_error: 0.0442 - log_cosh: 22.1545 - val_loss: 23.7567 - val_huber_loss: 23.7567 - val_mean_squared_error: 1177.1384 - val_mean_absolute_error: 24.2510 - val_mean_absolute_percentage_error: 17.7566 - val_mean_squared_logarithmic_error: 0.0556 - val_log_cosh: 23.5719
# Epoch 3/15
# 14722/14722 [==============================] - 146s 10ms/step - loss: 22.2589 - huber_loss: 22.2589 - mean_squared_error: 1009.3339 - mean_absolute_error: 22.7529 - mean_absolute_percentage_error: 15.3120 - mean_squared_logarithmic_error: 0.0441 - log_cosh: 22.0745 - val_loss: 23.7142 - val_huber_loss: 23.7142 - val_mean_squared_error: 1175.7551 - val_mean_absolute_error: 24.2086 - val_mean_absolute_percentage_error: 17.7042 - val_mean_squared_logarithmic_error: 0.0556 - val_log_cosh: 23.5295
# Epoch 4/15
# 14722/14722 [==============================] - 138s 9ms/step - loss: 22.2288 - huber_loss: 22.2288 - mean_squared_error: 1007.6392 - mean_absolute_error: 22.7228 - mean_absolute_percentage_error: 15.2956 - mean_squared_logarithmic_error: 0.0440 - log_cosh: 22.0444 - val_loss: 23.6842 - val_huber_loss: 23.6842 - val_mean_squared_error: 1174.5112 - val_mean_absolute_error: 24.1785 - val_mean_absolute_percentage_error: 17.6666 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 23.4993
# Epoch 5/15
# 14722/14722 [==============================] - 145s 10ms/step - loss: 22.2114 - huber_loss: 22.2114 - mean_squared_error: 1006.6127 - mean_absolute_error: 22.7055 - mean_absolute_percentage_error: 15.2866 - mean_squared_logarithmic_error: 0.0440 - log_cosh: 22.0270 - val_loss: 23.6751 - val_huber_loss: 23.6751 - val_mean_squared_error: 1174.8605 - val_mean_absolute_error: 24.1694 - val_mean_absolute_percentage_error: 17.6449 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 23.4903
# Epoch 6/15
# 14722/14722 [==============================] - 139s 9ms/step - loss: 22.2000 - huber_loss: 22.2000 - mean_squared_error: 1006.0157 - mean_absolute_error: 22.6940 - mean_absolute_percentage_error: 15.2805 - mean_squared_logarithmic_error: 0.0440 - log_cosh: 22.0158 - val_loss: 23.6696 - val_huber_loss: 23.6696 - val_mean_squared_error: 1175.1824 - val_mean_absolute_error: 24.1639 - val_mean_absolute_percentage_error: 17.6383 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 23.4849
# Epoch 7/15
# 14722/14722 [==============================] - 140s 10ms/step - loss: 22.1901 - huber_loss: 22.1901 - mean_squared_error: 1005.4688 - mean_absolute_error: 22.6841 - mean_absolute_percentage_error: 15.2735 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 22.0058 - val_loss: 23.6643 - val_huber_loss: 23.6643 - val_mean_squared_error: 1173.7887 - val_mean_absolute_error: 24.1587 - val_mean_absolute_percentage_error: 17.6486 - val_mean_squared_logarithmic_error: 0.0553 - val_log_cosh: 23.4795
# Epoch 8/15
# 14722/14722 [==============================] - 140s 9ms/step - loss: 22.1789 - huber_loss: 22.1789 - mean_squared_error: 1004.8768 - mean_absolute_error: 22.6729 - mean_absolute_percentage_error: 15.2654 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 21.9946 - val_loss: 23.6569 - val_huber_loss: 23.6569 - val_mean_squared_error: 1173.7065 - val_mean_absolute_error: 24.1513 - val_mean_absolute_percentage_error: 17.6355 - val_mean_squared_logarithmic_error: 0.0553 - val_log_cosh: 23.4721
# Epoch 9/15
# 14722/14722 [==============================] - 141s 10ms/step - loss: 22.1730 - huber_loss: 22.1730 - mean_squared_error: 1004.4916 - mean_absolute_error: 22.6669 - mean_absolute_percentage_error: 15.2622 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 21.9887 - val_loss: 23.6503 - val_huber_loss: 23.6503 - val_mean_squared_error: 1173.4617 - val_mean_absolute_error: 24.1446 - val_mean_absolute_percentage_error: 17.6231 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4654
# Epoch 10/15
# 14722/14722 [==============================] - 145s 10ms/step - loss: 22.1673 - huber_loss: 22.1673 - mean_squared_error: 1004.0991 - mean_absolute_error: 22.6613 - mean_absolute_percentage_error: 15.2590 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 21.9831 - val_loss: 23.6458 - val_huber_loss: 23.6458 - val_mean_squared_error: 1173.1475 - val_mean_absolute_error: 24.1401 - val_mean_absolute_percentage_error: 17.6169 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4610
# Epoch 11/15
# 14722/14722 [==============================] - 140s 9ms/step - loss: 22.1628 - huber_loss: 22.1628 - mean_squared_error: 1003.7852 - mean_absolute_error: 22.6568 - mean_absolute_percentage_error: 15.2560 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9786 - val_loss: 23.6415 - val_huber_loss: 23.6415 - val_mean_squared_error: 1172.6138 - val_mean_absolute_error: 24.1358 - val_mean_absolute_percentage_error: 17.6151 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4567
# Epoch 12/15
# 14722/14722 [==============================] - 147s 10ms/step - loss: 22.1588 - huber_loss: 22.1588 - mean_squared_error: 1003.5038 - mean_absolute_error: 22.6527 - mean_absolute_percentage_error: 15.2535 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9745 - val_loss: 23.6389 - val_huber_loss: 23.6389 - val_mean_squared_error: 1172.3324 - val_mean_absolute_error: 24.1332 - val_mean_absolute_percentage_error: 17.6128 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4540
# Epoch 13/15
# 14722/14722 [==============================] - 141s 10ms/step - loss: 22.1551 - huber_loss: 22.1551 - mean_squared_error: 1003.2657 - mean_absolute_error: 22.6491 - mean_absolute_percentage_error: 15.2512 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9709 - val_loss: 23.6384 - val_huber_loss: 23.6384 - val_mean_squared_error: 1172.1410 - val_mean_absolute_error: 24.1327 - val_mean_absolute_percentage_error: 17.6163 - val_mean_squared_logarithmic_error: 0.0551 - val_log_cosh: 23.4535
# Epoch 14/15
# 14722/14722 [==============================] - 140s 10ms/step - loss: 22.1516 - huber_loss: 22.1516 - mean_squared_error: 1003.0250 - mean_absolute_error: 22.6456 - mean_absolute_percentage_error: 15.2492 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9674 - val_loss: 23.6312 - val_huber_loss: 23.6312 - val_mean_squared_error: 1171.6025 - val_mean_absolute_error: 24.1255 - val_mean_absolute_percentage_error: 17.6099 - val_mean_squared_logarithmic_error: 0.0551 - val_log_cosh: 23.4464
# Epoch 15/15
# 14722/14722 [==============================] - 141s 10ms/step - loss: 22.1477 - huber_loss: 22.1477 - mean_squared_error: 1002.7573 - mean_absolute_error: 22.6417 - mean_absolute_percentage_error: 15.2464 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9635 - val_loss: 23.6297 - val_huber_loss: 23.6297 - val_mean_squared_error: 1171.0441 - val_mean_absolute_error: 24.1241 - val_mean_absolute_percentage_error: 17.6143 - val_mean_squared_logarithmic_error: 0.0550 - val_log_cosh: 23.4449

# %%
print(list(history.history.keys()))
print(list(history.history.keys())[1:7])
# Out:
# ['loss', 'huber_loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'log_cosh', 'val_loss', 'val_huber_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_mean_absolute_percentage_error', 'val_mean_squared_logarithmic_error', 'val_log_cosh']
# ['huber_loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'log_cosh']

# %% [markdown]
# This is not relevant for the Master's Thesis, but we can check out some metrics in the pretraining phase, to check wether if our model is learning while in the pretraining phase

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

keys=list(history.history.keys())[1:7]

plt.style.use("ggplot")
fig, axs = plt.subplots(3, 2, sharex=True, sharey=False, figsize=(10, 15))
fig.suptitle(t='Arquitectura '+str(ARCHITECTURE_NUMBER),y=1)
fig.supxlabel('Episodios de Entrenamiento')
fig.tight_layout()

for key_index,key in enumerate(keys):
  column=key_index%2
  row=int(key_index/2)

  axs[row,column].plot(np.arange(1,EPOCHS+1),history.history[key],label='Preentrenamiento')
  axs[row,column].plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='Validación')
  axs[row,column].grid(which='major', color='white', linewidth=1.2)
  axs[row,column].set_ylabel(key.replace("_", " " ).title())
  axs[row,column].ticklabel_format(axis="y", style="sci", scilimits=(0,0))

  if column==1:
    axs[row,column].yaxis.set_label_coords(-0.07,0.5)

  if row==0 and column==0:
    axs[row,column].legend(loc='upper center', bbox_to_anchor=(0.2, 1.20), fancybox=True, shadow=True)

plt.show()

'''
for key_index,key in list(history.history.keys())[1:7]:
  fig, ax = plt.subplots()                               #simple matplotlib visualization of the performance in training loss of the model over the training epochs
  ax.plot(np.arange(1,EPOCHS+1),history.history[key],label=key)
  ax.plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='val_'+key)
  ax.xaxis.set_major_locator(MaxNLocator(integer=True))
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid()
  plt.show()
  print('------------------------')
'''
# Out:
# "\nfor key_index,key in list(history.history.keys())[1:7]:\n  fig, ax = plt.subplots()                               #simple matplotlib visualization of the performance in training loss of the model over the training epochs\n  ax.plot(np.arange(1,EPOCHS+1),history.history[key],label=key)\n  ax.plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='val_'+key)\n  ax.xaxis.set_major_locator(MaxNLocator(integer=True))\n  plt.xlabel('Epochs')\n  plt.ylabel('Loss')\n  plt.legend()\n  plt.grid()\n  plt.show()\n  print('------------------------')\n"

# %%
test_history=model.evaluate_generator(test_generator,steps=int(test_generator.__len__()))

# %%
print(test_history)
# Out:
# [20.23409080505371, 20.23409080505371, 814.1527709960938, 20.72784423828125, 16.054691314697266, 0.043404243886470795, 20.04987144470215]

# %% [markdown]
# And yet, in this situation, we can visualize the predictions of the model over the patients in the control group, patients that our model have not yet seen. We can check visually with a simple matplotlib graph wether this predictions have some coherence comparing with the ground truth of the data over some patients in the control group.

# %%
pretrained_model = keras.models.load_model(checkpoint_folder + 'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',compile=False)

loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
optimizer=optimizers[best_classifier['optimizer']]
learning_rate=float(best_classifier['learning_rate'])

pretrained_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
K.set_value(pretrained_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

# %%
test_generator=Custom_Generator([test_patients[0]],1)     #create a fit generator over patients in the control group with batch size equal to 1

# %%
import matplotlib.pyplot as plt

X_test=np.array([np.squeeze(test_generator.__getitem__(i)[0]) for i in range(0,int(test_generator.__len__()-1))])   #we first extract the X data and the ground truth from the test generator
Y_test=np.array([np.squeeze(test_generator.__getitem__(i)[1]) for i in range(0,int(test_generator.__len__()-1))])
#X_test=denormalize(X_test)
#Y_test=denormalize(Y_test)

print(np.shape(X_test))   #Check those shapes to observe if it have coherence over the sahpe that it have to have (number of windows,WINDOW_LENGTH,1)
print(np.shape(Y_test))   #(number of windows,1)
# Out:
# (109175, 6)
# (109175,)

# %%
predictions=model.predict(X_test[:80])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()
ax.plot(timestamps_test[:80],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[:80],Y_test[:80],label='Datos Reales',color='orange')

#ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 20]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 2s 8ms/step

# %%
predictions=model.predict(X_test[100:180])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()

ax.plot(timestamps_test[100:180],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[100:180],Y_test[100:180],label='Datos Reales',color='orange')

ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %%
predictions=model.predict(X_test[300:380])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()

ax.plot(timestamps_test[300:380],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[300:380],Y_test[300:380],label='Datos Reales',color='orange')

ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %% [markdown]
# ##Pretrained Model vs From the Scratch Model

# %% [markdown]
# Now, we are going to try to train individually in each patient from the control group. We are going o try to do that without fit generator, fit generator was aahelpful tool to train the neural network trough all the patients with a single call and without having to worry about GPU memory, now, we are going to try to work with this data without fit generator, which is more helpful for individually training.

# %%
training_startime=time.time()
pretrained_metrics=[]                                                                             #Lists where we are going to store the control group patients metrics for the pretrained and the 'from the scratch' model
fromthescratch_metrics=[]
test_pretrained_metrics=[]                                                                             #Lists where we are going to store the control group patients metrics for the pretrained and the 'from the scratch' model
test_fromthescratch_metrics=[]

for ind,patient in enumerate(test_patients):                                                                      #A loop trough every filenames patient
  print(str(ind)+'-'+(patient)+'\n')

  pretrained_model = keras.models.load_model(checkpoint_folder + 'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',compile=False)#custom_objects={"Huber": tf.keras.losses.Huber() })    #Load the pretrained model and create a 'from the scratch' model

  fromthescratch_model=create_model()
  loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
  optimizer=optimizers[best_classifier['optimizer']]
  learning_rate=float(best_classifier['learning_rate'])

  fromthescratch_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
  K.set_value(fromthescratch_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier
  pretrained_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
  K.set_value(pretrained_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

  windowed_data=np.load(os.path.join(src_folder,patient)+'.npy',allow_pickle=True)                          #Load its correspondent windowed dataset
  X=np.array([window[:WINDOW_STEPS,:] for window in windowed_data])
  Y=np.array([window[-1,:] for window in windowed_data])

  X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False, random_state=42)

  print('PRETRAINED_MODEL')
  pretrained_history=pretrained_model.fit(x=X_train,y=y_train,shuffle=False,epochs=TOTAL_EPOCHS,batch_size=32,validation_split=0.1,verbose=1)
  print('\nFROMTHESCRATCH_MODEL')
  fromthescratch_history=fromthescratch_model.fit(x=X_train,y=y_train,shuffle=False,epochs=TOTAL_EPOCHS,batch_size=32,validation_split=0.1,verbose=1)

  test_pretrained_history=pretrained_model.evaluate(x=X_test,y=y_test,batch_size=32)
  test_fromthescratch_history=fromthescratch_model.evaluate(x=X_test,y=y_test,batch_size=32)

  pretrained_metrics.append(pretrained_history)
  fromthescratch_metrics.append(fromthescratch_history)
  test_pretrained_metrics.append(test_pretrained_history)
  test_fromthescratch_metrics.append(test_fromthescratch_history)

  print('\n-------------------------------------------------------\n')
  #print(np.shape(X))
  #print(np.shape(Y))

training_endtime=time.time()
training_time=(training_endtime-training_startime)
# Out:
# 0-LIB193277
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2457/2457 [==============================] - 27s 9ms/step - loss: 17.9043 - huber_loss: 17.9049 - mean_squared_error: 617.0674 - mean_absolute_error: 18.3981 - mean_absolute_percentage_error: 15.8656 - mean_squared_logarithmic_error: 0.0422 - log_cosh: 17.7215 - val_loss: 15.4718 - val_huber_loss: 15.4715 - val_mean_squared_error: 476.5948 - val_mean_absolute_error: 15.9640 - val_mean_absolute_percentage_error: 14.3207 - val_mean_squared_logarithmic_error: 0.0358 - val_log_cosh: 15.2893
# Epoch 2/15
# 2457/2457 [==============================] - 20s 8ms/step - loss: 17.0342 - huber_loss: 17.0351 - mean_squared_error: 566.1123 - mean_absolute_error: 17.5282 - mean_absolute_percentage_error: 15.0981 - mean_squared_logarithmic_error: 0.0391 - log_cosh: 16.8523 - val_loss: 15.4157 - val_huber_loss: 15.4155 - val_mean_squared_error: 473.2665 - val_mean_absolute_error: 15.9080 - val_mean_absolute_percentage_error: 14.2625 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2338
# Epoch 3/15
# 2457/2457 [==============================] - 21s 9ms/step - loss: 16.9304 - huber_loss: 16.9314 - mean_squared_error: 561.6055 - mean_absolute_error: 17.4245 - mean_absolute_percentage_error: 15.0059 - mean_squared_logarithmic_error: 0.0389 - log_cosh: 16.7487 - val_loss: 15.4054 - val_huber_loss: 15.4052 - val_mean_squared_error: 472.5787 - val_mean_absolute_error: 15.8975 - val_mean_absolute_percentage_error: 14.2515 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2236
# Epoch 4/15
# 2457/2457 [==============================] - 20s 8ms/step - loss: 16.8746 - huber_loss: 16.8755 - mean_squared_error: 559.1205 - mean_absolute_error: 17.3684 - mean_absolute_percentage_error: 14.9575 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6929 - val_loss: 15.3968 - val_huber_loss: 15.3966 - val_mean_squared_error: 472.4722 - val_mean_absolute_error: 15.8885 - val_mean_absolute_percentage_error: 14.2413 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2149
# Epoch 5/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.8350 - huber_loss: 16.8360 - mean_squared_error: 557.5114 - mean_absolute_error: 17.3286 - mean_absolute_percentage_error: 14.9203 - mean_squared_logarithmic_error: 0.0387 - log_cosh: 16.6535 - val_loss: 15.3875 - val_huber_loss: 15.3873 - val_mean_squared_error: 472.2102 - val_mean_absolute_error: 15.8793 - val_mean_absolute_percentage_error: 14.2311 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2056
# Epoch 6/15
# 2457/2457 [==============================] - 20s 8ms/step - loss: 16.8092 - huber_loss: 16.8101 - mean_squared_error: 556.4991 - mean_absolute_error: 17.3029 - mean_absolute_percentage_error: 14.8965 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.6276 - val_loss: 15.3776 - val_huber_loss: 15.3773 - val_mean_squared_error: 472.2463 - val_mean_absolute_error: 15.8690 - val_mean_absolute_percentage_error: 14.2094 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1956
# Epoch 7/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.7882 - huber_loss: 16.7891 - mean_squared_error: 555.7151 - mean_absolute_error: 17.2818 - mean_absolute_percentage_error: 14.8758 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.6066 - val_loss: 15.3708 - val_huber_loss: 15.3706 - val_mean_squared_error: 472.1009 - val_mean_absolute_error: 15.8622 - val_mean_absolute_percentage_error: 14.1994 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1889
# Epoch 8/15
# 2457/2457 [==============================] - 20s 8ms/step - loss: 16.7714 - huber_loss: 16.7724 - mean_squared_error: 555.0977 - mean_absolute_error: 17.2650 - mean_absolute_percentage_error: 14.8599 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.5899 - val_loss: 15.3666 - val_huber_loss: 15.3664 - val_mean_squared_error: 471.7871 - val_mean_absolute_error: 15.8582 - val_mean_absolute_percentage_error: 14.1964 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1847
# Epoch 9/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.7582 - huber_loss: 16.7591 - mean_squared_error: 554.6140 - mean_absolute_error: 17.2517 - mean_absolute_percentage_error: 14.8470 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.5767 - val_loss: 15.3627 - val_huber_loss: 15.3625 - val_mean_squared_error: 471.5599 - val_mean_absolute_error: 15.8545 - val_mean_absolute_percentage_error: 14.1925 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1808
# Epoch 10/15
# 2457/2457 [==============================] - 21s 8ms/step - loss: 16.7476 - huber_loss: 16.7485 - mean_squared_error: 554.2420 - mean_absolute_error: 17.2411 - mean_absolute_percentage_error: 14.8367 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5662 - val_loss: 15.3589 - val_huber_loss: 15.3587 - val_mean_squared_error: 471.2153 - val_mean_absolute_error: 15.8509 - val_mean_absolute_percentage_error: 14.1914 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1769
# Epoch 11/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.7381 - huber_loss: 16.7390 - mean_squared_error: 553.9174 - mean_absolute_error: 17.2317 - mean_absolute_percentage_error: 14.8275 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5567 - val_loss: 15.3542 - val_huber_loss: 15.3540 - val_mean_squared_error: 470.9771 - val_mean_absolute_error: 15.8463 - val_mean_absolute_percentage_error: 14.1881 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1722
# Epoch 12/15
# 2457/2457 [==============================] - 21s 8ms/step - loss: 16.7295 - huber_loss: 16.7303 - mean_squared_error: 553.6028 - mean_absolute_error: 17.2230 - mean_absolute_percentage_error: 14.8190 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5480 - val_loss: 15.3502 - val_huber_loss: 15.3500 - val_mean_squared_error: 470.7783 - val_mean_absolute_error: 15.8423 - val_mean_absolute_percentage_error: 14.1853 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1681
# Epoch 13/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.7218 - huber_loss: 16.7227 - mean_squared_error: 553.3163 - mean_absolute_error: 17.2152 - mean_absolute_percentage_error: 14.8118 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5404 - val_loss: 15.3477 - val_huber_loss: 15.3475 - val_mean_squared_error: 470.6230 - val_mean_absolute_error: 15.8399 - val_mean_absolute_percentage_error: 14.1842 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1656
# Epoch 14/15
# 2457/2457 [==============================] - 21s 8ms/step - loss: 16.7144 - huber_loss: 16.7152 - mean_squared_error: 553.0403 - mean_absolute_error: 17.2078 - mean_absolute_percentage_error: 14.8046 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5329 - val_loss: 15.3458 - val_huber_loss: 15.3456 - val_mean_squared_error: 470.5836 - val_mean_absolute_error: 15.8380 - val_mean_absolute_percentage_error: 14.1813 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1637
# Epoch 15/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.7080 - huber_loss: 16.7088 - mean_squared_error: 552.8073 - mean_absolute_error: 17.2014 - mean_absolute_percentage_error: 14.7984 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5265 - val_loss: 15.3430 - val_huber_loss: 15.3428 - val_mean_squared_error: 470.5455 - val_mean_absolute_error: 15.8352 - val_mean_absolute_percentage_error: 14.1777 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1609
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2457/2457 [==============================] - 27s 9ms/step - loss: 22.9499 - huber_loss: 22.9491 - mean_squared_error: 1013.2449 - mean_absolute_error: 23.4439 - mean_absolute_percentage_error: 20.2631 - mean_squared_logarithmic_error: 0.0965 - log_cosh: 22.7635 - val_loss: 17.0239 - val_huber_loss: 17.0246 - val_mean_squared_error: 567.1499 - val_mean_absolute_error: 17.5183 - val_mean_absolute_percentage_error: 15.3230 - val_mean_squared_logarithmic_error: 0.0411 - val_log_cosh: 16.8416
# Epoch 2/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 18.3911 - huber_loss: 18.3910 - mean_squared_error: 646.0668 - mean_absolute_error: 18.8848 - mean_absolute_percentage_error: 16.2145 - mean_squared_logarithmic_error: 0.0435 - log_cosh: 18.2068 - val_loss: 15.9554 - val_huber_loss: 15.9558 - val_mean_squared_error: 509.1628 - val_mean_absolute_error: 16.4487 - val_mean_absolute_percentage_error: 14.4598 - val_mean_squared_logarithmic_error: 0.0376 - val_log_cosh: 15.7741
# Epoch 3/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 17.5553 - huber_loss: 17.5555 - mean_squared_error: 596.1373 - mean_absolute_error: 18.0488 - mean_absolute_percentage_error: 15.5118 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 17.3722 - val_loss: 15.6892 - val_huber_loss: 15.6894 - val_mean_squared_error: 493.9087 - val_mean_absolute_error: 16.1815 - val_mean_absolute_percentage_error: 14.2953 - val_mean_squared_logarithmic_error: 0.0369 - val_log_cosh: 15.5078
# Epoch 4/15
# 2457/2457 [==============================] - 20s 8ms/step - loss: 17.2994 - huber_loss: 17.2996 - mean_squared_error: 581.8290 - mean_absolute_error: 17.7930 - mean_absolute_percentage_error: 15.3026 - mean_squared_logarithmic_error: 0.0400 - log_cosh: 17.1165 - val_loss: 15.5750 - val_huber_loss: 15.5751 - val_mean_squared_error: 487.0660 - val_mean_absolute_error: 16.0663 - val_mean_absolute_percentage_error: 14.2581 - val_mean_squared_logarithmic_error: 0.0365 - val_log_cosh: 15.3939
# Epoch 5/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 17.1676 - huber_loss: 17.1678 - mean_squared_error: 574.9528 - mean_absolute_error: 17.6607 - mean_absolute_percentage_error: 15.1938 - mean_squared_logarithmic_error: 0.0397 - log_cosh: 16.9850 - val_loss: 15.5396 - val_huber_loss: 15.5397 - val_mean_squared_error: 487.5807 - val_mean_absolute_error: 16.0317 - val_mean_absolute_percentage_error: 14.1493 - val_mean_squared_logarithmic_error: 0.0365 - val_log_cosh: 15.3586
# Epoch 6/15
# 2457/2457 [==============================] - 21s 9ms/step - loss: 17.0830 - huber_loss: 17.0832 - mean_squared_error: 570.2908 - mean_absolute_error: 17.5760 - mean_absolute_percentage_error: 15.1313 - mean_squared_logarithmic_error: 0.0394 - log_cosh: 16.9005 - val_loss: 15.4877 - val_huber_loss: 15.4878 - val_mean_squared_error: 484.7279 - val_mean_absolute_error: 15.9797 - val_mean_absolute_percentage_error: 14.1163 - val_mean_squared_logarithmic_error: 0.0363 - val_log_cosh: 15.3066
# Epoch 7/15
# 2457/2457 [==============================] - 30s 12ms/step - loss: 17.0251 - huber_loss: 17.0255 - mean_squared_error: 567.2164 - mean_absolute_error: 17.5182 - mean_absolute_percentage_error: 15.0874 - mean_squared_logarithmic_error: 0.0392 - log_cosh: 16.8428 - val_loss: 15.4521 - val_huber_loss: 15.4521 - val_mean_squared_error: 482.6330 - val_mean_absolute_error: 15.9442 - val_mean_absolute_percentage_error: 14.0923 - val_mean_squared_logarithmic_error: 0.0362 - val_log_cosh: 15.2709
# Epoch 8/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.9823 - huber_loss: 16.9827 - mean_squared_error: 564.9753 - mean_absolute_error: 17.4754 - mean_absolute_percentage_error: 15.0536 - mean_squared_logarithmic_error: 0.0391 - log_cosh: 16.8001 - val_loss: 15.4217 - val_huber_loss: 15.4217 - val_mean_squared_error: 480.1922 - val_mean_absolute_error: 15.9136 - val_mean_absolute_percentage_error: 14.0908 - val_mean_squared_logarithmic_error: 0.0360 - val_log_cosh: 15.2402
# Epoch 9/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.9493 - huber_loss: 16.9497 - mean_squared_error: 563.3812 - mean_absolute_error: 17.4426 - mean_absolute_percentage_error: 15.0254 - mean_squared_logarithmic_error: 0.0390 - log_cosh: 16.7671 - val_loss: 15.4036 - val_huber_loss: 15.4035 - val_mean_squared_error: 478.5728 - val_mean_absolute_error: 15.8952 - val_mean_absolute_percentage_error: 14.0851 - val_mean_squared_logarithmic_error: 0.0359 - val_log_cosh: 15.2219
# Epoch 10/15
# 2457/2457 [==============================] - 21s 8ms/step - loss: 16.9232 - huber_loss: 16.9236 - mean_squared_error: 562.1624 - mean_absolute_error: 17.4165 - mean_absolute_percentage_error: 15.0009 - mean_squared_logarithmic_error: 0.0389 - log_cosh: 16.7410 - val_loss: 15.3871 - val_huber_loss: 15.3871 - val_mean_squared_error: 477.3154 - val_mean_absolute_error: 15.8787 - val_mean_absolute_percentage_error: 14.0779 - val_mean_squared_logarithmic_error: 0.0358 - val_log_cosh: 15.2054
# Epoch 11/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.8999 - huber_loss: 16.9004 - mean_squared_error: 561.0665 - mean_absolute_error: 17.3933 - mean_absolute_percentage_error: 14.9797 - mean_squared_logarithmic_error: 0.0389 - log_cosh: 16.7177 - val_loss: 15.3706 - val_huber_loss: 15.3706 - val_mean_squared_error: 476.0851 - val_mean_absolute_error: 15.8625 - val_mean_absolute_percentage_error: 14.0763 - val_mean_squared_logarithmic_error: 0.0357 - val_log_cosh: 15.1888
# Epoch 12/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.8795 - huber_loss: 16.8800 - mean_squared_error: 560.0815 - mean_absolute_error: 17.3729 - mean_absolute_percentage_error: 14.9618 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6973 - val_loss: 15.3590 - val_huber_loss: 15.3588 - val_mean_squared_error: 475.2592 - val_mean_absolute_error: 15.8510 - val_mean_absolute_percentage_error: 14.0721 - val_mean_squared_logarithmic_error: 0.0357 - val_log_cosh: 15.1771
# Epoch 13/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.8621 - huber_loss: 16.8626 - mean_squared_error: 559.2426 - mean_absolute_error: 17.3556 - mean_absolute_percentage_error: 14.9459 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6800 - val_loss: 15.3485 - val_huber_loss: 15.3484 - val_mean_squared_error: 474.5810 - val_mean_absolute_error: 15.8407 - val_mean_absolute_percentage_error: 14.0692 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1665
# Epoch 14/15
# 2457/2457 [==============================] - 21s 9ms/step - loss: 16.8467 - huber_loss: 16.8472 - mean_squared_error: 558.5326 - mean_absolute_error: 17.3403 - mean_absolute_percentage_error: 14.9318 - mean_squared_logarithmic_error: 0.0387 - log_cosh: 16.6646 - val_loss: 15.3397 - val_huber_loss: 15.3396 - val_mean_squared_error: 473.8836 - val_mean_absolute_error: 15.8322 - val_mean_absolute_percentage_error: 14.0703 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1578
# Epoch 15/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.8328 - huber_loss: 16.8334 - mean_squared_error: 557.8881 - mean_absolute_error: 17.3263 - mean_absolute_percentage_error: 14.9198 - mean_squared_logarithmic_error: 0.0387 - log_cosh: 16.6507 - val_loss: 15.3332 - val_huber_loss: 15.3330 - val_mean_squared_error: 473.4905 - val_mean_absolute_error: 15.8258 - val_mean_absolute_percentage_error: 14.0702 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1512
# 683/683 [==============================] - 3s 5ms/step - loss: 14.4814 - huber_loss: 14.4784 - mean_squared_error: 417.1348 - mean_absolute_error: 14.9705 - mean_absolute_percentage_error: 12.9516 - mean_squared_logarithmic_error: 0.0296 - log_cosh: 14.2973
# 683/683 [==============================] - 3s 4ms/step - loss: 14.5891 - huber_loss: 14.5857 - mean_squared_error: 423.8596 - mean_absolute_error: 15.0775 - mean_absolute_percentage_error: 12.9459 - mean_squared_logarithmic_error: 0.0299 - log_cosh: 14.4049
#
# -------------------------------------------------------
#
# 1-LIB193307
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2264/2264 [==============================] - 26s 9ms/step - loss: 23.4861 - huber_loss: 23.4849 - mean_squared_error: 1082.6073 - mean_absolute_error: 23.9799 - mean_absolute_percentage_error: 16.8595 - mean_squared_logarithmic_error: 0.0531 - log_cosh: 23.2993 - val_loss: 21.4310 - val_huber_loss: 21.4551 - val_mean_squared_error: 869.1837 - val_mean_absolute_error: 21.9496 - val_mean_absolute_percentage_error: 15.3062 - val_mean_squared_logarithmic_error: 0.0396 - val_log_cosh: 21.2699
# Epoch 2/15
# 2264/2264 [==============================] - 19s 9ms/step - loss: 21.5624 - huber_loss: 21.5614 - mean_squared_error: 897.8812 - mean_absolute_error: 22.0559 - mean_absolute_percentage_error: 15.5128 - mean_squared_logarithmic_error: 0.0427 - log_cosh: 21.3764 - val_loss: 21.2847 - val_huber_loss: 21.3085 - val_mean_squared_error: 852.9969 - val_mean_absolute_error: 21.8030 - val_mean_absolute_percentage_error: 15.1643 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 21.1236
# Epoch 3/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 21.3161 - huber_loss: 21.3149 - mean_squared_error: 878.8493 - mean_absolute_error: 21.8095 - mean_absolute_percentage_error: 15.3295 - mean_squared_logarithmic_error: 0.0419 - log_cosh: 21.1300 - val_loss: 21.1742 - val_huber_loss: 21.1953 - val_mean_squared_error: 847.5229 - val_mean_absolute_error: 21.6901 - val_mean_absolute_percentage_error: 15.0242 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 21.0102
# Epoch 4/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 21.1911 - huber_loss: 21.1900 - mean_squared_error: 870.2734 - mean_absolute_error: 21.6844 - mean_absolute_percentage_error: 15.2436 - mean_squared_logarithmic_error: 0.0416 - log_cosh: 21.0051 - val_loss: 21.1669 - val_huber_loss: 21.1880 - val_mean_squared_error: 850.2768 - val_mean_absolute_error: 21.6822 - val_mean_absolute_percentage_error: 14.9097 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 21.0033
# Epoch 5/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.1040 - huber_loss: 21.1029 - mean_squared_error: 864.1932 - mean_absolute_error: 21.5972 - mean_absolute_percentage_error: 15.1859 - mean_squared_logarithmic_error: 0.0413 - log_cosh: 20.9180 - val_loss: 21.1099 - val_huber_loss: 21.1280 - val_mean_squared_error: 845.5405 - val_mean_absolute_error: 21.6226 - val_mean_absolute_percentage_error: 14.8595 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.9432
# Epoch 6/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.0482 - huber_loss: 21.0471 - mean_squared_error: 860.2672 - mean_absolute_error: 21.5414 - mean_absolute_percentage_error: 15.1467 - mean_squared_logarithmic_error: 0.0412 - log_cosh: 20.8623 - val_loss: 21.0889 - val_huber_loss: 21.1053 - val_mean_squared_error: 845.2523 - val_mean_absolute_error: 21.5998 - val_mean_absolute_percentage_error: 14.8055 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.9205
# Epoch 7/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.0061 - huber_loss: 21.0050 - mean_squared_error: 857.4989 - mean_absolute_error: 21.4992 - mean_absolute_percentage_error: 15.1156 - mean_squared_logarithmic_error: 0.0411 - log_cosh: 20.8203 - val_loss: 21.0635 - val_huber_loss: 21.0765 - val_mean_squared_error: 843.6996 - val_mean_absolute_error: 21.5710 - val_mean_absolute_percentage_error: 14.7725 - val_mean_squared_logarithmic_error: 0.0388 - val_log_cosh: 20.8915
# Epoch 8/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 20.9713 - huber_loss: 20.9701 - mean_squared_error: 855.1547 - mean_absolute_error: 21.4644 - mean_absolute_percentage_error: 15.0920 - mean_squared_logarithmic_error: 0.0410 - log_cosh: 20.7855 - val_loss: 21.0532 - val_huber_loss: 21.0641 - val_mean_squared_error: 844.3536 - val_mean_absolute_error: 21.5586 - val_mean_absolute_percentage_error: 14.7210 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.8792
# Epoch 9/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 20.9453 - huber_loss: 20.9442 - mean_squared_error: 853.4604 - mean_absolute_error: 21.4384 - mean_absolute_percentage_error: 15.0751 - mean_squared_logarithmic_error: 0.0409 - log_cosh: 20.7594 - val_loss: 21.0410 - val_huber_loss: 21.0502 - val_mean_squared_error: 844.4366 - val_mean_absolute_error: 21.5442 - val_mean_absolute_percentage_error: 14.6820 - val_mean_squared_logarithmic_error: 0.0388 - val_log_cosh: 20.8654
# Epoch 10/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 20.9220 - huber_loss: 20.9208 - mean_squared_error: 851.8827 - mean_absolute_error: 21.4150 - mean_absolute_percentage_error: 15.0594 - mean_squared_logarithmic_error: 0.0409 - log_cosh: 20.7361 - val_loss: 21.0261 - val_huber_loss: 21.0336 - val_mean_squared_error: 844.5342 - val_mean_absolute_error: 21.5271 - val_mean_absolute_percentage_error: 14.6425 - val_mean_squared_logarithmic_error: 0.0388 - val_log_cosh: 20.8491
# Epoch 11/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 20.9018 - huber_loss: 20.9007 - mean_squared_error: 850.5245 - mean_absolute_error: 21.3949 - mean_absolute_percentage_error: 15.0452 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 20.7160 - val_loss: 21.0262 - val_huber_loss: 21.0317 - val_mean_squared_error: 845.0699 - val_mean_absolute_error: 21.5255 - val_mean_absolute_percentage_error: 14.6274 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.8472
# Epoch 12/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 20.8858 - huber_loss: 20.8846 - mean_squared_error: 849.5342 - mean_absolute_error: 21.3789 - mean_absolute_percentage_error: 15.0315 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 20.6999 - val_loss: 21.0062 - val_huber_loss: 21.0095 - val_mean_squared_error: 843.6094 - val_mean_absolute_error: 21.5037 - val_mean_absolute_percentage_error: 14.6182 - val_mean_squared_logarithmic_error: 0.0388 - val_log_cosh: 20.8249
# Epoch 13/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 20.8696 - huber_loss: 20.8684 - mean_squared_error: 848.4237 - mean_absolute_error: 21.3626 - mean_absolute_percentage_error: 15.0208 - mean_squared_logarithmic_error: 0.0407 - log_cosh: 20.6837 - val_loss: 21.0093 - val_huber_loss: 21.0116 - val_mean_squared_error: 843.7892 - val_mean_absolute_error: 21.5060 - val_mean_absolute_percentage_error: 14.6195 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.8270
# Epoch 14/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 20.8559 - huber_loss: 20.8547 - mean_squared_error: 847.5643 - mean_absolute_error: 21.3490 - mean_absolute_percentage_error: 15.0110 - mean_squared_logarithmic_error: 0.0407 - log_cosh: 20.6701 - val_loss: 21.0092 - val_huber_loss: 21.0113 - val_mean_squared_error: 844.0910 - val_mean_absolute_error: 21.5058 - val_mean_absolute_percentage_error: 14.6153 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.8266
# Epoch 15/15
# 2264/2264 [==============================] - 19s 9ms/step - loss: 20.8443 - huber_loss: 20.8431 - mean_squared_error: 846.8533 - mean_absolute_error: 21.3372 - mean_absolute_percentage_error: 15.0026 - mean_squared_logarithmic_error: 0.0407 - log_cosh: 20.6585 - val_loss: 21.0147 - val_huber_loss: 21.0165 - val_mean_squared_error: 844.5002 - val_mean_absolute_error: 21.5112 - val_mean_absolute_percentage_error: 14.6178 - val_mean_squared_logarithmic_error: 0.0389 - val_log_cosh: 20.8318
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2264/2264 [==============================] - 25s 9ms/step - loss: 32.8739 - huber_loss: 32.8716 - mean_squared_error: 2170.9573 - mean_absolute_error: 33.3676 - mean_absolute_percentage_error: 23.5666 - mean_squared_logarithmic_error: 0.1315 - log_cosh: 32.6842 - val_loss: 23.9915 - val_huber_loss: 24.0501 - val_mean_squared_error: 1070.8512 - val_mean_absolute_error: 24.5452 - val_mean_absolute_percentage_error: 17.5009 - val_mean_squared_logarithmic_error: 0.0474 - val_log_cosh: 23.8643
# Epoch 2/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 23.5408 - huber_loss: 23.5394 - mean_squared_error: 1062.9821 - mean_absolute_error: 24.0346 - mean_absolute_percentage_error: 16.8413 - mean_squared_logarithmic_error: 0.0485 - log_cosh: 23.3538 - val_loss: 22.2321 - val_huber_loss: 22.2671 - val_mean_squared_error: 934.8597 - val_mean_absolute_error: 22.7620 - val_mean_absolute_percentage_error: 16.0609 - val_mean_squared_logarithmic_error: 0.0424 - val_log_cosh: 22.0819
# Epoch 3/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 22.4186 - huber_loss: 22.4174 - mean_squared_error: 968.0209 - mean_absolute_error: 22.9121 - mean_absolute_percentage_error: 16.0729 - mean_squared_logarithmic_error: 0.0451 - log_cosh: 22.2320 - val_loss: 21.7175 - val_huber_loss: 21.7510 - val_mean_squared_error: 893.3030 - val_mean_absolute_error: 22.2458 - val_mean_absolute_percentage_error: 15.5972 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 21.5657
# Epoch 4/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.9731 - huber_loss: 21.9721 - mean_squared_error: 930.1213 - mean_absolute_error: 22.4667 - mean_absolute_percentage_error: 15.7813 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.7867 - val_loss: 21.4729 - val_huber_loss: 21.5104 - val_mean_squared_error: 877.8890 - val_mean_absolute_error: 22.0049 - val_mean_absolute_percentage_error: 15.1747 - val_mean_squared_logarithmic_error: 0.0399 - val_log_cosh: 21.3255
# Epoch 5/15
# 2264/2264 [==============================] - 19s 8ms/step - loss: 21.7297 - huber_loss: 21.7287 - mean_squared_error: 910.8181 - mean_absolute_error: 22.2233 - mean_absolute_percentage_error: 15.6169 - mean_squared_logarithmic_error: 0.0431 - log_cosh: 21.5435 - val_loss: 21.3903 - val_huber_loss: 21.4259 - val_mean_squared_error: 872.9650 - val_mean_absolute_error: 21.9198 - val_mean_absolute_percentage_error: 15.0056 - val_mean_squared_logarithmic_error: 0.0396 - val_log_cosh: 21.2414
# Epoch 6/15
# 2264/2264 [==============================] - 19s 9ms/step - loss: 21.5660 - huber_loss: 21.5649 - mean_squared_error: 898.5134 - mean_absolute_error: 22.0593 - mean_absolute_percentage_error: 15.5016 - mean_squared_logarithmic_error: 0.0426 - log_cosh: 21.3800 - val_loss: 21.2676 - val_huber_loss: 21.2992 - val_mean_squared_error: 860.7990 - val_mean_absolute_error: 21.7932 - val_mean_absolute_percentage_error: 15.0181 - val_mean_squared_logarithmic_error: 0.0393 - val_log_cosh: 21.1148
# Epoch 7/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.4554 - huber_loss: 21.4544 - mean_squared_error: 890.4509 - mean_absolute_error: 21.9488 - mean_absolute_percentage_error: 15.4231 - mean_squared_logarithmic_error: 0.0423 - log_cosh: 21.2695 - val_loss: 21.2412 - val_huber_loss: 21.2722 - val_mean_squared_error: 861.1279 - val_mean_absolute_error: 21.7661 - val_mean_absolute_percentage_error: 14.9227 - val_mean_squared_logarithmic_error: 0.0393 - val_log_cosh: 21.0879
# Epoch 8/15
# 2264/2264 [==============================] - 19s 9ms/step - loss: 21.3771 - huber_loss: 21.3760 - mean_squared_error: 884.5353 - mean_absolute_error: 21.8704 - mean_absolute_percentage_error: 15.3668 - mean_squared_logarithmic_error: 0.0421 - log_cosh: 21.1911 - val_loss: 21.2184 - val_huber_loss: 21.2483 - val_mean_squared_error: 860.0466 - val_mean_absolute_error: 21.7428 - val_mean_absolute_percentage_error: 14.8798 - val_mean_squared_logarithmic_error: 0.0393 - val_log_cosh: 21.0639
# Epoch 9/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.3126 - huber_loss: 21.3115 - mean_squared_error: 879.8220 - mean_absolute_error: 21.8058 - mean_absolute_percentage_error: 15.3219 - mean_squared_logarithmic_error: 0.0419 - log_cosh: 21.1266 - val_loss: 21.1666 - val_huber_loss: 21.1951 - val_mean_squared_error: 855.6971 - val_mean_absolute_error: 21.6892 - val_mean_absolute_percentage_error: 14.8499 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 21.0108
# Epoch 10/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 21.2574 - huber_loss: 21.2563 - mean_squared_error: 875.8145 - mean_absolute_error: 21.7506 - mean_absolute_percentage_error: 15.2820 - mean_squared_logarithmic_error: 0.0418 - log_cosh: 21.0715 - val_loss: 21.1341 - val_huber_loss: 21.1609 - val_mean_squared_error: 853.1941 - val_mean_absolute_error: 21.6553 - val_mean_absolute_percentage_error: 14.8277 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9766
# Epoch 11/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 21.2130 - huber_loss: 21.2119 - mean_squared_error: 872.7068 - mean_absolute_error: 21.7063 - mean_absolute_percentage_error: 15.2531 - mean_squared_logarithmic_error: 0.0417 - log_cosh: 21.0272 - val_loss: 21.1300 - val_huber_loss: 21.1568 - val_mean_squared_error: 853.2452 - val_mean_absolute_error: 21.6508 - val_mean_absolute_percentage_error: 14.7909 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9723
# Epoch 12/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.1739 - huber_loss: 21.1728 - mean_squared_error: 869.9551 - mean_absolute_error: 21.6671 - mean_absolute_percentage_error: 15.2240 - mean_squared_logarithmic_error: 0.0416 - log_cosh: 20.9880 - val_loss: 21.1511 - val_huber_loss: 21.1803 - val_mean_squared_error: 855.0964 - val_mean_absolute_error: 21.6742 - val_mean_absolute_percentage_error: 14.7471 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9957
# Epoch 13/15
# 2264/2264 [==============================] - 20s 9ms/step - loss: 21.1386 - huber_loss: 21.1375 - mean_squared_error: 867.5618 - mean_absolute_error: 21.6317 - mean_absolute_percentage_error: 15.1996 - mean_squared_logarithmic_error: 0.0415 - log_cosh: 20.9527 - val_loss: 21.1452 - val_huber_loss: 21.1732 - val_mean_squared_error: 854.4572 - val_mean_absolute_error: 21.6672 - val_mean_absolute_percentage_error: 14.7334 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9886
# Epoch 14/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 21.1109 - huber_loss: 21.1098 - mean_squared_error: 865.7087 - mean_absolute_error: 21.6040 - mean_absolute_percentage_error: 15.1791 - mean_squared_logarithmic_error: 0.0414 - log_cosh: 20.9250 - val_loss: 21.1509 - val_huber_loss: 21.1780 - val_mean_squared_error: 854.9100 - val_mean_absolute_error: 21.6723 - val_mean_absolute_percentage_error: 14.7239 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9935
# Epoch 15/15
# 2264/2264 [==============================] - 19s 9ms/step - loss: 21.0871 - huber_loss: 21.0860 - mean_squared_error: 863.8550 - mean_absolute_error: 21.5803 - mean_absolute_percentage_error: 15.1664 - mean_squared_logarithmic_error: 0.0413 - log_cosh: 20.9012 - val_loss: 21.1308 - val_huber_loss: 21.1563 - val_mean_squared_error: 852.6782 - val_mean_absolute_error: 21.6506 - val_mean_absolute_percentage_error: 14.7200 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9717
# 629/629 [==============================] - 4s 6ms/step - loss: 21.3223 - huber_loss: 21.3218 - mean_squared_error: 859.9486 - mean_absolute_error: 21.8166 - mean_absolute_percentage_error: 14.5708 - mean_squared_logarithmic_error: 0.0391 - log_cosh: 21.1369
# 629/629 [==============================] - 3s 5ms/step - loss: 21.4152 - huber_loss: 21.4147 - mean_squared_error: 866.4831 - mean_absolute_error: 21.9093 - mean_absolute_percentage_error: 14.6646 - mean_squared_logarithmic_error: 0.0393 - log_cosh: 21.2297
#
# -------------------------------------------------------
#
# 2-LIB193385
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2043/2043 [==============================] - 23s 9ms/step - loss: 16.0847 - huber_loss: 16.0842 - mean_squared_error: 545.5031 - mean_absolute_error: 16.5759 - mean_absolute_percentage_error: 13.6853 - mean_squared_logarithmic_error: 0.0347 - log_cosh: 15.9031 - val_loss: 15.3559 - val_huber_loss: 15.3570 - val_mean_squared_error: 435.4115 - val_mean_absolute_error: 15.8496 - val_mean_absolute_percentage_error: 13.6075 - val_mean_squared_logarithmic_error: 0.0288 - val_log_cosh: 15.1745
# Epoch 2/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.2183 - huber_loss: 15.2180 - mean_squared_error: 501.2854 - mean_absolute_error: 15.7094 - mean_absolute_percentage_error: 12.8754 - mean_squared_logarithmic_error: 0.0317 - log_cosh: 15.0377 - val_loss: 15.1156 - val_huber_loss: 15.1168 - val_mean_squared_error: 429.8251 - val_mean_absolute_error: 15.6097 - val_mean_absolute_percentage_error: 13.2626 - val_mean_squared_logarithmic_error: 0.0282 - val_log_cosh: 14.9347
# Epoch 3/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.1139 - huber_loss: 15.1137 - mean_squared_error: 497.4269 - mean_absolute_error: 15.6047 - mean_absolute_percentage_error: 12.7885 - mean_squared_logarithmic_error: 0.0315 - log_cosh: 14.9338 - val_loss: 14.9766 - val_huber_loss: 14.9778 - val_mean_squared_error: 427.4397 - val_mean_absolute_error: 15.4698 - val_mean_absolute_percentage_error: 13.0484 - val_mean_squared_logarithmic_error: 0.0278 - val_log_cosh: 14.7960
# Epoch 4/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.0682 - huber_loss: 15.0680 - mean_squared_error: 495.7646 - mean_absolute_error: 15.5586 - mean_absolute_percentage_error: 12.7483 - mean_squared_logarithmic_error: 0.0314 - log_cosh: 14.8883 - val_loss: 14.9403 - val_huber_loss: 14.9416 - val_mean_squared_error: 427.1310 - val_mean_absolute_error: 15.4334 - val_mean_absolute_percentage_error: 13.0001 - val_mean_squared_logarithmic_error: 0.0278 - val_log_cosh: 14.7601
# Epoch 5/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 15.0391 - huber_loss: 15.0389 - mean_squared_error: 494.5641 - mean_absolute_error: 15.5298 - mean_absolute_percentage_error: 12.7246 - mean_squared_logarithmic_error: 0.0314 - log_cosh: 14.8593 - val_loss: 14.9051 - val_huber_loss: 14.9064 - val_mean_squared_error: 426.6994 - val_mean_absolute_error: 15.3981 - val_mean_absolute_percentage_error: 12.9499 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.7249
# Epoch 6/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.0208 - huber_loss: 15.0206 - mean_squared_error: 493.9845 - mean_absolute_error: 15.5116 - mean_absolute_percentage_error: 12.7098 - mean_squared_logarithmic_error: 0.0313 - log_cosh: 14.8409 - val_loss: 14.8755 - val_huber_loss: 14.8768 - val_mean_squared_error: 426.5417 - val_mean_absolute_error: 15.3685 - val_mean_absolute_percentage_error: 12.9040 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6952
# Epoch 7/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.0051 - huber_loss: 15.0049 - mean_squared_error: 493.3540 - mean_absolute_error: 15.4960 - mean_absolute_percentage_error: 12.6974 - mean_squared_logarithmic_error: 0.0313 - log_cosh: 14.8252 - val_loss: 14.8535 - val_huber_loss: 14.8547 - val_mean_squared_error: 426.4103 - val_mean_absolute_error: 15.3467 - val_mean_absolute_percentage_error: 12.8679 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6732
# Epoch 8/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 14.9907 - huber_loss: 14.9905 - mean_squared_error: 492.7689 - mean_absolute_error: 15.4815 - mean_absolute_percentage_error: 12.6852 - mean_squared_logarithmic_error: 0.0313 - log_cosh: 14.8108 - val_loss: 14.8355 - val_huber_loss: 14.8368 - val_mean_squared_error: 426.5139 - val_mean_absolute_error: 15.3288 - val_mean_absolute_percentage_error: 12.8327 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.6553
# Epoch 9/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 14.9802 - huber_loss: 14.9801 - mean_squared_error: 492.4213 - mean_absolute_error: 15.4708 - mean_absolute_percentage_error: 12.6756 - mean_squared_logarithmic_error: 0.0313 - log_cosh: 14.8005 - val_loss: 14.8151 - val_huber_loss: 14.8164 - val_mean_squared_error: 426.4712 - val_mean_absolute_error: 15.3082 - val_mean_absolute_percentage_error: 12.8025 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.6349
# Epoch 10/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 14.9708 - huber_loss: 14.9706 - mean_squared_error: 492.1650 - mean_absolute_error: 15.4614 - mean_absolute_percentage_error: 12.6665 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7911 - val_loss: 14.7988 - val_huber_loss: 14.8001 - val_mean_squared_error: 426.1374 - val_mean_absolute_error: 15.2914 - val_mean_absolute_percentage_error: 12.7845 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.6187
# Epoch 11/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 14.9629 - huber_loss: 14.9627 - mean_squared_error: 491.8875 - mean_absolute_error: 15.4536 - mean_absolute_percentage_error: 12.6593 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7832 - val_loss: 14.7739 - val_huber_loss: 14.7752 - val_mean_squared_error: 425.7835 - val_mean_absolute_error: 15.2669 - val_mean_absolute_percentage_error: 12.7532 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5939
# Epoch 12/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 14.9547 - huber_loss: 14.9545 - mean_squared_error: 491.6404 - mean_absolute_error: 15.4453 - mean_absolute_percentage_error: 12.6527 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7751 - val_loss: 14.7627 - val_huber_loss: 14.7640 - val_mean_squared_error: 425.8483 - val_mean_absolute_error: 15.2559 - val_mean_absolute_percentage_error: 12.7353 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5828
# Epoch 13/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 14.9484 - huber_loss: 14.9483 - mean_squared_error: 491.5164 - mean_absolute_error: 15.4389 - mean_absolute_percentage_error: 12.6478 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7688 - val_loss: 14.7594 - val_huber_loss: 14.7607 - val_mean_squared_error: 425.8561 - val_mean_absolute_error: 15.2526 - val_mean_absolute_percentage_error: 12.7325 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5795
# Epoch 14/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 14.9429 - huber_loss: 14.9428 - mean_squared_error: 491.4093 - mean_absolute_error: 15.4335 - mean_absolute_percentage_error: 12.6429 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7634 - val_loss: 14.7536 - val_huber_loss: 14.7549 - val_mean_squared_error: 425.9565 - val_mean_absolute_error: 15.2468 - val_mean_absolute_percentage_error: 12.7215 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5737
# Epoch 15/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 14.9374 - huber_loss: 14.9372 - mean_squared_error: 491.2786 - mean_absolute_error: 15.4280 - mean_absolute_percentage_error: 12.6386 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7579 - val_loss: 14.7381 - val_huber_loss: 14.7394 - val_mean_squared_error: 425.7991 - val_mean_absolute_error: 15.2312 - val_mean_absolute_percentage_error: 12.6980 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5582
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2043/2043 [==============================] - 25s 10ms/step - loss: 20.4240 - huber_loss: 20.4227 - mean_squared_error: 854.4478 - mean_absolute_error: 20.9167 - mean_absolute_percentage_error: 17.3906 - mean_squared_logarithmic_error: 0.1261 - log_cosh: 20.2383 - val_loss: 16.9788 - val_huber_loss: 16.9799 - val_mean_squared_error: 523.2208 - val_mean_absolute_error: 17.4732 - val_mean_absolute_percentage_error: 14.6584 - val_mean_squared_logarithmic_error: 0.0334 - val_log_cosh: 16.7962
# Epoch 2/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 16.4909 - huber_loss: 16.4903 - mean_squared_error: 573.0425 - mean_absolute_error: 16.9826 - mean_absolute_percentage_error: 13.8699 - mean_squared_logarithmic_error: 0.0356 - log_cosh: 16.3086 - val_loss: 15.8812 - val_huber_loss: 15.8824 - val_mean_squared_error: 465.7053 - val_mean_absolute_error: 16.3748 - val_mean_absolute_percentage_error: 13.9049 - val_mean_squared_logarithmic_error: 0.0303 - val_log_cosh: 15.6997
# Epoch 3/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.8166 - huber_loss: 15.8162 - mean_squared_error: 540.8707 - mean_absolute_error: 16.3077 - mean_absolute_percentage_error: 13.2972 - mean_squared_logarithmic_error: 0.0338 - log_cosh: 15.6356 - val_loss: 15.4595 - val_huber_loss: 15.4607 - val_mean_squared_error: 449.7331 - val_mean_absolute_error: 15.9532 - val_mean_absolute_percentage_error: 13.5000 - val_mean_squared_logarithmic_error: 0.0292 - val_log_cosh: 15.2783
# Epoch 4/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 15.5425 - huber_loss: 15.5421 - mean_squared_error: 525.8922 - mean_absolute_error: 16.0332 - mean_absolute_percentage_error: 13.0808 - mean_squared_logarithmic_error: 0.0329 - log_cosh: 15.3620 - val_loss: 15.2393 - val_huber_loss: 15.2405 - val_mean_squared_error: 441.9279 - val_mean_absolute_error: 15.7330 - val_mean_absolute_percentage_error: 13.2589 - val_mean_squared_logarithmic_error: 0.0287 - val_log_cosh: 15.0585
# Epoch 5/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.3815 - huber_loss: 15.3812 - mean_squared_error: 516.9991 - mean_absolute_error: 15.8721 - mean_absolute_percentage_error: 12.9572 - mean_squared_logarithmic_error: 0.0325 - log_cosh: 15.2013 - val_loss: 15.1054 - val_huber_loss: 15.1066 - val_mean_squared_error: 437.5499 - val_mean_absolute_error: 15.5986 - val_mean_absolute_percentage_error: 13.1220 - val_mean_squared_logarithmic_error: 0.0284 - val_log_cosh: 14.9250
# Epoch 6/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.2885 - huber_loss: 15.2883 - mean_squared_error: 511.7112 - mean_absolute_error: 15.7790 - mean_absolute_percentage_error: 12.8921 - mean_squared_logarithmic_error: 0.0322 - log_cosh: 15.1086 - val_loss: 15.0558 - val_huber_loss: 15.0570 - val_mean_squared_error: 435.3613 - val_mean_absolute_error: 15.5489 - val_mean_absolute_percentage_error: 13.0851 - val_mean_squared_logarithmic_error: 0.0283 - val_log_cosh: 14.8756
# Epoch 7/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 15.2285 - huber_loss: 15.2282 - mean_squared_error: 508.1099 - mean_absolute_error: 15.7190 - mean_absolute_percentage_error: 12.8482 - mean_squared_logarithmic_error: 0.0320 - log_cosh: 15.0486 - val_loss: 15.0123 - val_huber_loss: 15.0135 - val_mean_squared_error: 434.0840 - val_mean_absolute_error: 15.5053 - val_mean_absolute_percentage_error: 13.0386 - val_mean_squared_logarithmic_error: 0.0282 - val_log_cosh: 14.8324
# Epoch 8/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.1877 - huber_loss: 15.1875 - mean_squared_error: 505.9695 - mean_absolute_error: 15.6782 - mean_absolute_percentage_error: 12.8196 - mean_squared_logarithmic_error: 0.0319 - log_cosh: 15.0079 - val_loss: 14.9344 - val_huber_loss: 14.9357 - val_mean_squared_error: 430.8013 - val_mean_absolute_error: 15.4272 - val_mean_absolute_percentage_error: 12.9792 - val_mean_squared_logarithmic_error: 0.0280 - val_log_cosh: 14.7546
# Epoch 9/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.1514 - huber_loss: 15.1512 - mean_squared_error: 503.9326 - mean_absolute_error: 15.6420 - mean_absolute_percentage_error: 12.7923 - mean_squared_logarithmic_error: 0.0318 - log_cosh: 14.9716 - val_loss: 14.8819 - val_huber_loss: 14.8831 - val_mean_squared_error: 429.1007 - val_mean_absolute_error: 15.3746 - val_mean_absolute_percentage_error: 12.9190 - val_mean_squared_logarithmic_error: 0.0279 - val_log_cosh: 14.7020
# Epoch 10/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.1245 - huber_loss: 15.1243 - mean_squared_error: 502.4524 - mean_absolute_error: 15.6149 - mean_absolute_percentage_error: 12.7729 - mean_squared_logarithmic_error: 0.0317 - log_cosh: 14.9447 - val_loss: 14.8484 - val_huber_loss: 14.8496 - val_mean_squared_error: 428.2283 - val_mean_absolute_error: 15.3413 - val_mean_absolute_percentage_error: 12.8747 - val_mean_squared_logarithmic_error: 0.0278 - val_log_cosh: 14.6686
# Epoch 11/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.1037 - huber_loss: 15.1034 - mean_squared_error: 501.3583 - mean_absolute_error: 15.5940 - mean_absolute_percentage_error: 12.7580 - mean_squared_logarithmic_error: 0.0317 - log_cosh: 14.9240 - val_loss: 14.8240 - val_huber_loss: 14.8252 - val_mean_squared_error: 427.7851 - val_mean_absolute_error: 15.3169 - val_mean_absolute_percentage_error: 12.8355 - val_mean_squared_logarithmic_error: 0.0278 - val_log_cosh: 14.6441
# Epoch 12/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 15.0891 - huber_loss: 15.0889 - mean_squared_error: 500.6462 - mean_absolute_error: 15.5794 - mean_absolute_percentage_error: 12.7468 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.9094 - val_loss: 14.8055 - val_huber_loss: 14.8068 - val_mean_squared_error: 427.4727 - val_mean_absolute_error: 15.2984 - val_mean_absolute_percentage_error: 12.8063 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6257
# Epoch 13/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 15.0770 - huber_loss: 15.0768 - mean_squared_error: 500.1370 - mean_absolute_error: 15.5674 - mean_absolute_percentage_error: 12.7378 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.8974 - val_loss: 14.7886 - val_huber_loss: 14.7898 - val_mean_squared_error: 427.2415 - val_mean_absolute_error: 15.2813 - val_mean_absolute_percentage_error: 12.7785 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6087
# Epoch 14/15
# 2043/2043 [==============================] - 19s 9ms/step - loss: 15.0662 - huber_loss: 15.0659 - mean_squared_error: 499.6492 - mean_absolute_error: 15.5566 - mean_absolute_percentage_error: 12.7292 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.8865 - val_loss: 14.7762 - val_huber_loss: 14.7775 - val_mean_squared_error: 427.1264 - val_mean_absolute_error: 15.2688 - val_mean_absolute_percentage_error: 12.7569 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.5965
# Epoch 15/15
# 2043/2043 [==============================] - 18s 9ms/step - loss: 15.0571 - huber_loss: 15.0568 - mean_squared_error: 499.2269 - mean_absolute_error: 15.5475 - mean_absolute_percentage_error: 12.7219 - mean_squared_logarithmic_error: 0.0315 - log_cosh: 14.8775 - val_loss: 14.7648 - val_huber_loss: 14.7661 - val_mean_squared_error: 427.0435 - val_mean_absolute_error: 15.2573 - val_mean_absolute_percentage_error: 12.7370 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.5851
# 568/568 [==============================] - 3s 5ms/step - loss: 14.8729 - huber_loss: 14.8815 - mean_squared_error: 469.9342 - mean_absolute_error: 15.3723 - mean_absolute_percentage_error: 12.0054 - mean_squared_logarithmic_error: 0.0273 - log_cosh: 14.7018
# 568/568 [==============================] - 3s 6ms/step - loss: 14.8613 - huber_loss: 14.8701 - mean_squared_error: 469.4790 - mean_absolute_error: 15.3608 - mean_absolute_percentage_error: 12.0121 - mean_squared_logarithmic_error: 0.0273 - log_cosh: 14.6904
#
# -------------------------------------------------------
#
# 3-LIB193367
#
# PRETRAINED_MODEL
# Epoch 1/15
# 1626/1626 [==============================] - 21s 10ms/step - loss: 24.3584 - huber_loss: 24.3604 - mean_squared_error: 1164.0192 - mean_absolute_error: 24.8553 - mean_absolute_percentage_error: 16.8830 - mean_squared_logarithmic_error: 0.0503 - log_cosh: 24.1745 - val_loss: 22.2672 - val_huber_loss: 22.2514 - val_mean_squared_error: 1001.8652 - val_mean_absolute_error: 22.7447 - val_mean_absolute_percentage_error: 15.3550 - val_mean_squared_logarithmic_error: 0.0462 - val_log_cosh: 22.0674
# Epoch 2/15
# ...
#
# -------------------------------------------------------
#
# 4-LIB193310
#
# PRETRAINED_MODEL
# Epoch 1/15
# 1580/1580 [==============================] - 20s 10ms/step - loss: 23.3887 - huber_loss: 23.3885 - mean_squared_error: 1089.8888 - mean_absolute_error: 23.8828 - mean_absolute_percentage_error: 16.9946 - mean_squared_logarithmic_error: 0.0645 - log_cosh: 23.2033 - val_loss: 21.4586 - val_huber_loss: 21.4516 - val_mean_squared_error: 784.7119 - val_mean_absolute_error: 21.9471 - val_mean_absolute_percentage_error: 18.0813 - val_mean_squared_logarithmic_error: 0.0459 - val_log_cosh: 21.2648
# Epoch 2/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.5924 - huber_loss: 21.5934 - mean_squared_error: 945.2725 - mean_absolute_error: 22.0875 - mean_absolute_percentage_error: 15.7802 - mean_squared_logarithmic_error: 0.0461 - log_cosh: 21.4090 - val_loss: 20.4218 - val_huber_loss: 20.4141 - val_mean_squared_error: 745.4092 - val_mean_absolute_error: 20.9104 - val_mean_absolute_percentage_error: 16.9150 - val_mean_squared_logarithmic_error: 0.0433 - val_log_cosh: 20.2272
# Epoch 3/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.3475 - huber_loss: 21.3487 - mean_squared_error: 931.2266 - mean_absolute_error: 21.8424 - mean_absolute_percentage_error: 15.6052 - mean_squared_logarithmic_error: 0.0456 - log_cosh: 21.1646 - val_loss: 19.9385 - val_huber_loss: 19.9307 - val_mean_squared_error: 730.0513 - val_mean_absolute_error: 20.4255 - val_mean_absolute_percentage_error: 16.3527 - val_mean_squared_logarithmic_error: 0.0422 - val_log_cosh: 19.7446
# Epoch 4/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.2299 - huber_loss: 21.2311 - mean_squared_error: 924.2426 - mean_absolute_error: 21.7247 - mean_absolute_percentage_error: 15.5229 - mean_squared_logarithmic_error: 0.0453 - log_cosh: 21.0471 - val_loss: 19.7089 - val_huber_loss: 19.7011 - val_mean_squared_error: 724.2924 - val_mean_absolute_error: 20.1961 - val_mean_absolute_percentage_error: 16.0715 - val_mean_squared_logarithmic_error: 0.0417 - val_log_cosh: 19.5154
# Epoch 5/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.1597 - huber_loss: 21.1607 - mean_squared_error: 920.3011 - mean_absolute_error: 21.6543 - mean_absolute_percentage_error: 15.4725 - mean_squared_logarithmic_error: 0.0452 - log_cosh: 20.9770 - val_loss: 19.6412 - val_huber_loss: 19.6333 - val_mean_squared_error: 723.3857 - val_mean_absolute_error: 20.1277 - val_mean_absolute_percentage_error: 15.9787 - val_mean_squared_logarithmic_error: 0.0417 - val_log_cosh: 19.4477
# Epoch 6/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.1168 - huber_loss: 21.1178 - mean_squared_error: 917.9297 - mean_absolute_error: 21.6113 - mean_absolute_percentage_error: 15.4429 - mean_squared_logarithmic_error: 0.0451 - log_cosh: 20.9342 - val_loss: 19.5150 - val_huber_loss: 19.5070 - val_mean_squared_error: 720.6552 - val_mean_absolute_error: 20.0013 - val_mean_absolute_percentage_error: 15.8204 - val_mean_squared_logarithmic_error: 0.0414 - val_log_cosh: 19.3219
# Epoch 7/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.0845 - huber_loss: 21.0855 - mean_squared_error: 916.4185 - mean_absolute_error: 21.5790 - mean_absolute_percentage_error: 15.4188 - mean_squared_logarithmic_error: 0.0450 - log_cosh: 20.9018 - val_loss: 19.4182 - val_huber_loss: 19.4101 - val_mean_squared_error: 718.6654 - val_mean_absolute_error: 19.9044 - val_mean_absolute_percentage_error: 15.6981 - val_mean_squared_logarithmic_error: 0.0413 - val_log_cosh: 19.2253
# Epoch 8/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.0582 - huber_loss: 21.0593 - mean_squared_error: 914.8991 - mean_absolute_error: 21.5528 - mean_absolute_percentage_error: 15.3997 - mean_squared_logarithmic_error: 0.0449 - log_cosh: 20.8757 - val_loss: 19.3206 - val_huber_loss: 19.3124 - val_mean_squared_error: 716.5637 - val_mean_absolute_error: 19.8071 - val_mean_absolute_percentage_error: 15.5736 - val_mean_squared_logarithmic_error: 0.0411 - val_log_cosh: 19.1280
# Epoch 9/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.0353 - huber_loss: 21.0363 - mean_squared_error: 913.9059 - mean_absolute_error: 21.5298 - mean_absolute_percentage_error: 15.3831 - mean_squared_logarithmic_error: 0.0449 - log_cosh: 20.8527 - val_loss: 19.2584 - val_huber_loss: 19.2501 - val_mean_squared_error: 715.6255 - val_mean_absolute_error: 19.7443 - val_mean_absolute_percentage_error: 15.4878 - val_mean_squared_logarithmic_error: 0.0410 - val_log_cosh: 19.0658
# Epoch 10/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.0170 - huber_loss: 21.0180 - mean_squared_error: 913.1423 - mean_absolute_error: 21.5114 - mean_absolute_percentage_error: 15.3683 - mean_squared_logarithmic_error: 0.0449 - log_cosh: 20.8345 - val_loss: 19.2140 - val_huber_loss: 19.2056 - val_mean_squared_error: 715.1033 - val_mean_absolute_error: 19.6993 - val_mean_absolute_percentage_error: 15.4243 - val_mean_squared_logarithmic_error: 0.0409 - val_log_cosh: 19.0214
# Epoch 11/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 20.9997 - huber_loss: 21.0007 - mean_squared_error: 912.3550 - mean_absolute_error: 21.4940 - mean_absolute_percentage_error: 15.3557 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.8172 - val_loss: 19.1775 - val_huber_loss: 19.1690 - val_mean_squared_error: 714.9769 - val_mean_absolute_error: 19.6624 - val_mean_absolute_percentage_error: 15.3686 - val_mean_squared_logarithmic_error: 0.0409 - val_log_cosh: 18.9849
# Epoch 12/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 20.9840 - huber_loss: 20.9850 - mean_squared_error: 911.7083 - mean_absolute_error: 21.4783 - mean_absolute_percentage_error: 15.3436 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.8015 - val_loss: 19.1354 - val_huber_loss: 19.1269 - val_mean_squared_error: 714.5266 - val_mean_absolute_error: 19.6199 - val_mean_absolute_percentage_error: 15.3093 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 18.9430
# Epoch 13/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 20.9718 - huber_loss: 20.9728 - mean_squared_error: 911.1190 - mean_absolute_error: 21.4661 - mean_absolute_percentage_error: 15.3350 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.7894 - val_loss: 19.1047 - val_huber_loss: 19.0961 - val_mean_squared_error: 714.3300 - val_mean_absolute_error: 19.5890 - val_mean_absolute_percentage_error: 15.2633 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 18.9124
# Epoch 14/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 20.9609 - huber_loss: 20.9620 - mean_squared_error: 910.5970 - mean_absolute_error: 21.4552 - mean_absolute_percentage_error: 15.3266 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.7785 - val_loss: 19.0769 - val_huber_loss: 19.0683 - val_mean_squared_error: 714.0594 - val_mean_absolute_error: 19.5614 - val_mean_absolute_percentage_error: 15.2231 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 18.8847
# Epoch 15/15
# 1580/1580 [==============================] - 15s 10ms/step - loss: 20.9500 - huber_loss: 20.9511 - mean_squared_error: 909.9404 - mean_absolute_error: 21.4445 - mean_absolute_percentage_error: 15.3201 - mean_squared_logarithmic_error: 0.0447 - log_cosh: 20.7677 - val_loss: 19.0402 - val_huber_loss: 19.0321 - val_mean_squared_error: 713.6455 - val_mean_absolute_error: 19.5256 - val_mean_absolute_percentage_error: 15.1687 - val_mean_squared_logarithmic_error: 0.0407 - val_log_cosh: 18.8486
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 1580/1580 [==============================] - 20s 10ms/step - loss: 34.6354 - huber_loss: 34.6316 - mean_squared_error: 2243.6504 - mean_absolute_error: 35.1280 - mean_absolute_percentage_error: 25.4062 - mean_squared_logarithmic_error: 0.1755 - log_cosh: 34.4438 - val_loss: 27.9512 - val_huber_loss: 27.9552 - val_mean_squared_error: 1163.3303 - val_mean_absolute_error: 28.4526 - val_mean_absolute_percentage_error: 24.7022 - val_mean_squared_logarithmic_error: 0.0700 - val_log_cosh: 27.7661
# Epoch 2/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 25.3267 - huber_loss: 25.3266 - mean_squared_error: 1226.1559 - mean_absolute_error: 25.8217 - mean_absolute_percentage_error: 18.4093 - mean_squared_logarithmic_error: 0.0574 - log_cosh: 25.1407 - val_loss: 24.6018 - val_huber_loss: 24.5924 - val_mean_squared_error: 953.4628 - val_mean_absolute_error: 25.0890 - val_mean_absolute_percentage_error: 21.0957 - val_mean_squared_logarithmic_error: 0.0562 - val_log_cosh: 24.4040
# Epoch 3/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 23.8696 - huber_loss: 23.8697 - mean_squared_error: 1113.9354 - mean_absolute_error: 24.3646 - mean_absolute_percentage_error: 17.3982 - mean_squared_logarithmic_error: 0.0529 - log_cosh: 23.6840 - val_loss: 23.2336 - val_huber_loss: 23.2248 - val_mean_squared_error: 882.4269 - val_mean_absolute_error: 23.7216 - val_mean_absolute_percentage_error: 19.7808 - val_mean_squared_logarithmic_error: 0.0519 - val_log_cosh: 23.0368
# Epoch 4/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 23.1601 - huber_loss: 23.1606 - mean_squared_error: 1060.2496 - mean_absolute_error: 23.6553 - mean_absolute_percentage_error: 16.9068 - mean_squared_logarithmic_error: 0.0508 - log_cosh: 22.9754 - val_loss: 22.0081 - val_huber_loss: 21.9999 - val_mean_squared_error: 826.5821 - val_mean_absolute_error: 22.4961 - val_mean_absolute_percentage_error: 18.5311 - val_mean_squared_logarithmic_error: 0.0484 - val_log_cosh: 21.8126
# Epoch 5/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 22.7037 - huber_loss: 22.7046 - mean_squared_error: 1027.4796 - mean_absolute_error: 23.1991 - mean_absolute_percentage_error: 16.5849 - mean_squared_logarithmic_error: 0.0495 - log_cosh: 22.5196 - val_loss: 21.2655 - val_huber_loss: 21.2568 - val_mean_squared_error: 795.4649 - val_mean_absolute_error: 21.7518 - val_mean_absolute_percentage_error: 17.7737 - val_mean_squared_logarithmic_error: 0.0464 - val_log_cosh: 21.0700
# Epoch 6/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 22.3839 - huber_loss: 22.3848 - mean_squared_error: 1005.8392 - mean_absolute_error: 22.8792 - mean_absolute_percentage_error: 16.3623 - mean_squared_logarithmic_error: 0.0487 - log_cosh: 22.2000 - val_loss: 20.8505 - val_huber_loss: 20.8420 - val_mean_squared_error: 780.5635 - val_mean_absolute_error: 21.3369 - val_mean_absolute_percentage_error: 17.3340 - val_mean_squared_logarithmic_error: 0.0454 - val_log_cosh: 20.6558
# Epoch 7/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 22.1694 - huber_loss: 22.1705 - mean_squared_error: 991.1068 - mean_absolute_error: 22.6644 - mean_absolute_percentage_error: 16.2097 - mean_squared_logarithmic_error: 0.0481 - log_cosh: 21.9859 - val_loss: 20.5412 - val_huber_loss: 20.5328 - val_mean_squared_error: 768.1553 - val_mean_absolute_error: 21.0272 - val_mean_absolute_percentage_error: 17.0111 - val_mean_squared_logarithmic_error: 0.0447 - val_log_cosh: 20.3472
# Epoch 8/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 22.0645 - huber_loss: 22.0656 - mean_squared_error: 980.3921 - mean_absolute_error: 22.5594 - mean_absolute_percentage_error: 16.1687 - mean_squared_logarithmic_error: 0.0476 - log_cosh: 21.8812 - val_loss: 20.5531 - val_huber_loss: 20.5440 - val_mean_squared_error: 767.1114 - val_mean_absolute_error: 21.0381 - val_mean_absolute_percentage_error: 17.0481 - val_mean_squared_logarithmic_error: 0.0446 - val_log_cosh: 20.3585
# Epoch 9/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.9681 - huber_loss: 21.9691 - mean_squared_error: 976.4882 - mean_absolute_error: 22.4630 - mean_absolute_percentage_error: 16.0680 - mean_squared_logarithmic_error: 0.0475 - log_cosh: 21.7848 - val_loss: 20.1472 - val_huber_loss: 20.1382 - val_mean_squared_error: 752.4249 - val_mean_absolute_error: 20.6328 - val_mean_absolute_percentage_error: 16.5821 - val_mean_squared_logarithmic_error: 0.0437 - val_log_cosh: 19.9530
# Epoch 10/15
# 1580/1580 [==============================] - 17s 11ms/step - loss: 21.8429 - huber_loss: 21.8440 - mean_squared_error: 967.9445 - mean_absolute_error: 22.3381 - mean_absolute_percentage_error: 15.9746 - mean_squared_logarithmic_error: 0.0471 - log_cosh: 21.6598 - val_loss: 19.9889 - val_huber_loss: 19.9795 - val_mean_squared_error: 745.9999 - val_mean_absolute_error: 20.4737 - val_mean_absolute_percentage_error: 16.3942 - val_mean_squared_logarithmic_error: 0.0432 - val_log_cosh: 19.7944
# Epoch 11/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.7483 - huber_loss: 21.7494 - mean_squared_error: 961.1119 - mean_absolute_error: 22.2433 - mean_absolute_percentage_error: 15.9025 - mean_squared_logarithmic_error: 0.0469 - log_cosh: 21.5651 - val_loss: 19.8723 - val_huber_loss: 19.8627 - val_mean_squared_error: 741.1414 - val_mean_absolute_error: 20.3575 - val_mean_absolute_percentage_error: 16.2591 - val_mean_squared_logarithmic_error: 0.0429 - val_log_cosh: 19.6775
# Epoch 12/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.6709 - huber_loss: 21.6719 - mean_squared_error: 955.9711 - mean_absolute_error: 22.1658 - mean_absolute_percentage_error: 15.8447 - mean_squared_logarithmic_error: 0.0467 - log_cosh: 21.4878 - val_loss: 19.7978 - val_huber_loss: 19.7881 - val_mean_squared_error: 738.1773 - val_mean_absolute_error: 20.2823 - val_mean_absolute_percentage_error: 16.1721 - val_mean_squared_logarithmic_error: 0.0427 - val_log_cosh: 19.6030
# Epoch 13/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.6065 - huber_loss: 21.6076 - mean_squared_error: 951.4617 - mean_absolute_error: 22.1014 - mean_absolute_percentage_error: 15.7996 - mean_squared_logarithmic_error: 0.0465 - log_cosh: 21.4235 - val_loss: 19.7101 - val_huber_loss: 19.7002 - val_mean_squared_error: 735.0536 - val_mean_absolute_error: 20.1946 - val_mean_absolute_percentage_error: 16.0649 - val_mean_squared_logarithmic_error: 0.0425 - val_log_cosh: 19.5152
# Epoch 14/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.5500 - huber_loss: 21.5511 - mean_squared_error: 947.5432 - mean_absolute_error: 22.0449 - mean_absolute_percentage_error: 15.7599 - mean_squared_logarithmic_error: 0.0463 - log_cosh: 21.3671 - val_loss: 19.6464 - val_huber_loss: 19.6365 - val_mean_squared_error: 732.7798 - val_mean_absolute_error: 20.1309 - val_mean_absolute_percentage_error: 15.9961 - val_mean_squared_logarithmic_error: 0.0423 - val_log_cosh: 19.4514
# Epoch 15/15
# 1580/1580 [==============================] - 15s 9ms/step - loss: 21.4976 - huber_loss: 21.4986 - mean_squared_error: 943.7973 - mean_absolute_error: 21.9922 - mean_absolute_percentage_error: 15.7211 - mean_squared_logarithmic_error: 0.0462 - log_cosh: 21.3147 - val_loss: 19.5879 - val_huber_loss: 19.5778 - val_mean_squared_error: 730.1870 - val_mean_absolute_error: 20.0723 - val_mean_absolute_percentage_error: 15.9244 - val_mean_squared_logarithmic_error: 0.0421 - val_log_cosh: 19.3926
# 439/439 [==============================] - 2s 5ms/step - loss: 18.2869 - huber_loss: 18.2809 - mean_squared_error: 655.7912 - mean_absolute_error: 18.7747 - mean_absolute_percentage_error: 14.6299 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 18.0973
# 439/439 [==============================] - 2s 5ms/step - loss: 18.8098 - huber_loss: 18.8029 - mean_squared_error: 662.7547 - mean_absolute_error: 19.2966 - mean_absolute_percentage_error: 15.3905 - mean_squared_logarithmic_error: 0.0397 - log_cosh: 18.6182
#
# -------------------------------------------------------

# %%
for ind in range(0,len(test_patients)):
  np.save(checkpoint_folder+'pretrained_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',pretrained_metrics[ind].history)
  np.save(checkpoint_folder+'fromthescratch_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',fromthescratch_metrics[ind].history)
  np.save(checkpoint_folder+'test_pretrained_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',np.array(test_pretrained_metrics[ind]))
  np.save(checkpoint_folder+'test_fromthescratch_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',np.array(test_fromthescratch_metrics[ind]))

# %%
notebook_endtime=time.time()
notebook_time=(notebook_endtime-notebook_startime)

print(notebook_time)
print(optimization_time)
print(pretraining_time)
print(training_time)
# Out:
# 7038.705477952957
# 1560.7023618221283
# 2132.518099784851
# 3089.8946018218994

# %%
print('Notebook Execution Time: '+str(round(notebook_time/3600,2))+' hours')
print('Hyperparameter Optimization Execution Time: '+str(round(optimization_time/3600,2))+' hours')
print('Pretraining Execution Time: '+str(round(pretraining_time/3600,2))+' hours')
print('Training Execution Time: '+str(round(training_time/3600,2))+' hours')
# Out:
# Notebook Execution Time: 1.96 hours
# Hyperparameter Optimization Execution Time: 0.43 hours
# Pretraining Execution Time: 0.59 hours
# Training Execution Time: 0.86 hours
