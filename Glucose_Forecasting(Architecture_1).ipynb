# %% [markdown]
# #Data

# %% [markdown]
# ##Exploration

# %% [markdown]
#   In this chapter, we are going to study the data that we are going to use to train and validate our models. We are going to preprocess the data too.
#
# First, we need to import our data from the drive:

# %%
import time

notebook_startime = time.time()
ARCHITECTURE_NUMBER=1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install --quiet hyperas

# %%
from google.colab import drive    #We first import the dataset from the drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
import random
import keras
import os

seed=0

def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(seed)

# %% [markdown]
# We need to import the dataset as a pandas dataframe

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/drive/MyDrive/Glucose_measurements_sample(1).csv')     #Import of the dataset as a pandas dataframe

# %% [markdown]
# Next, we need to join the Year/Month/Day column withe the Hour:Minute:Second column to create a single column with all the information of the dates tha we need

# %%
df['Measurement_date']=df['Measurement_date']+' '+df['Measurement_time']   #Joining of those two date columns in a single one
df=df.drop(columns=['Measurement_time'])         #Drop the Hour:Minute:Second column now that this information is contained in the 'Measurement_Date' column

# %%
df.head()      #Display of the whole dataframe
# Out:
#   Patient_ID     Measurement_date  Measurement
# 0  LIB193263  2020-06-09 19:08:00           99
# 1  LIB193263  2020-06-09 19:23:00           92
# 2  LIB193263  2020-06-09 19:38:00           86
# 3  LIB193263  2020-06-09 19:53:00           85
# 4  LIB193263  2020-06-09 20:08:00           85

# %%
df.describe()    #get some general statistics from the dataframe in question
# Out:
#         Measurement
# count  3.000000e+06
# mean   1.589509e+02
# std    6.543033e+01
# min    4.000000e+01
# 25%    1.100000e+02
# 50%    1.480000e+02
# 75%    1.970000e+02
# max    5.000000e+02

# %% [markdown]
# Each element of date column that we have just created next to be converted from string to TimeStamp

# %%
df['Measurement_date']=pd.to_datetime(df['Measurement_date'],format='%Y-%m-%d %H:%M:%S.%f')   #Conversion from string to timestamp

# %%
print(type(df['Measurement_date'][0]))                #Check if we have the 'Measurement_date' column in a timestamp format
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# Next, the date column that we just have converted to timestamp is going to be set as the index of our dataframe

# %%
df.set_index('Measurement_date', inplace = True)      #Making the whole date column the index of the dataframe

# %% [markdown]
# Making a simple visualization of the csv of the data

# %%
df.head()       #Visualization of the head of the dataframe
# Out:
#                     Patient_ID  Measurement
# Measurement_date
# 2020-06-09 19:08:00  LIB193263           99
# 2020-06-09 19:23:00  LIB193263           92
# 2020-06-09 19:38:00  LIB193263           86
# 2020-06-09 19:53:00  LIB193263           85
# 2020-06-09 20:08:00  LIB193263           85

# %% [markdown]
# Now, we can start playing with the dataframe to extract information. First, we are going to extract the number of different patients whose glucose time series are present in this dataframe by getting all the unique elements from the column 'Patient_ID', column that represents the patient to which the glucose measurement belongs to.

# %%
patients=df['Patient_ID'].unique()     #Getting the unique patients and putting them into a list of unique patients
print(len(patients))                   #Visualization of the number of unique patients of this dataset
# Out:
# 110

# %%
print(patients[0])                     #Print the first patient ID in the list
# Out:
# LIB193263

# %%
print(df.isnull().sum())               #Check the number of Nans that there are in the whole dataframe of patients. As we can see, we don't have to worry in Nan values.
# Out:
# Patient_ID     0
# Measurement    0
# dtype: int64

# %% [markdown]
# Now, we are going to take the glucose time series data related to the first patient of this list of unique patients. Next we are going to plot this timeseries with different frequencies, just so we can visualize the data which we are working with.

# %%
patient1 = df[df['Patient_ID'] == 'LIB193263']      #the glucose time series dataframe related to the first patient of the list of unique patients

# %% [markdown]
# We first make a visualization of the data in a little timespam, like a few hours

# %%
import matplotlib.pyplot as plt        #Simple matplotlib visualization of a patient levels of glucose time series in a relatively small time range
import matplotlib.dates as md

plt.style.use("ggplot")
fig, ax = plt.subplots(figsize = (12, 8))
original_data=patient1['Measurement'][400:430]
ax.plot(patient1['Measurement'][400:430])
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 30]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.grid(which='major', color='white', linewidth=1.2)
plt.show()

# %% [markdown]
# And them we are going to make a visualization of the data in a larger timespam, like a few days

# %%
import matplotlib.pyplot as plt       #Simple matplotlib visualization of a patient levels of glucose time series in a wider time range
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
ax.plot(patient1['Measurement'][:3000])
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.DayLocator(interval=3))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.grid(which='major', color='white', linewidth=1.2)
plt.show()

# %% [markdown]
# And them, we need to append in a list the different timeseries related to every patient each one as a element of a list that will contain the dataframes of all patients differentiated

# %%
time_series_per_patient=[]     #List in which we are going to store the part of the dataframe related to each patient each one as a different element of this list

for patient in patients:
  time_series_per_patient.append(df[df['Patient_ID'] == patient])     #Appending the information related to each patient each one as a different element of this list

# %%
time_series_per_patient[0].head()              #check the time series correspondent to the first patient in the list
# Out:
#                     Patient_ID  Measurement
# Measurement_date
# 2020-06-09 19:08:00  LIB193263           99
# 2020-06-09 19:23:00  LIB193263           92
# 2020-06-09 19:38:00  LIB193263           86
# 2020-06-09 19:53:00  LIB193263           85
# 2020-06-09 20:08:00  LIB193263           85

# %% [markdown]
# ##Resampling

# %% [markdown]
# Now, we are going to measure the elements of every time series that are oversampled or undersampled, under and over 15 min, timestamp that have to be the sampling frequency of every time series. For those elements that are undersampled, we are going to take the missing values until the next value of glucose, because maybe if we miss one or two ticks of glucose measurement in a gap, we can interpolate this gap. For more ticks of missing values, we could treat this gap of missing values as a real gap that will not be interpolated, because if we interpolate two days of missing values of glucose, the dataset will change a lot in terms of reality, which is something that we dont want at all.

# %%
oversamples=[]              #list which contains a counter of oversample values for every patient
undersamples=[]             #list which contains a counter of undersample values for every patient
undersample_freq=[]         #list which contains the number of missing values in an undersampled gap

for time_series in time_series_per_patient:
  time_diff = time_series.index.to_series().diff()[1:]                              #list of sampling frequencies
  morethan15min_positions = time_diff[time_diff > pd.Timedelta(minutes=15)].index   #+1 index of those positions with a sampling frequency with more than 15 minutes of value
  lessthan15min_positions = time_diff[time_diff < pd.Timedelta(minutes=15)].index   #+1 index of those positions with a sampling frequency with less than 15 minutes of value
  oversamples.append(len(lessthan15min_positions))                                  #list of number of samples  with less than 15 minutes of sampling frequency from every every patient
  undersamples.append(len(morethan15min_positions))                                 #list of number of samples  with more than 15 minutes of sampling frequency from every every patient
  undersample_freq+=list(time_diff[time_diff > pd.Timedelta(minutes=15)])           #list of sampling frequency values that are over 15 minutes from every patient

# %%
print(np.sum(oversamples))        #Number of oversample values in the whole dataframe
print(np.sum(undersamples))       #Number of undersample values in the whole dataframe
# Out:
# 136533
# 167091

# %%
print(np.sum(pd.Series(undersample_freq) > pd.Timedelta(minutes=45)))     #If the gap of missing values is equal or less than 30 minutes, we are going to interpolate that gap
# Out:
# 16345

# %% [markdown]
# Then, we check the date of beginning and end of some time series correspondent to the first 5 patients in the list, the length of every time series and the length that every time series from every patient must have to obey an uniform sampling frequency. The uniform length is the length that the time series must have to achieve sampling every 15 minutes form start date to end date of the time series.
#
# Of course, with the resampling of these time series, we will do various things:
#
# 1- First, we are going to determine where the gaps with more that 45 minutes are, i.e. those gaps where more two values of glucose are missing, those gaps are going to be untouched. But next to finding where this gaps are, we are going to locate those gaps that are less or equal to 45 minutes, i.e. those gaps where there are two or one values missing and we are going to interpolate this gaps.
#
# 2- Next, we are going to correct uneven sampling frequencies. You see, the mayority of the samples of the time series are separated by 15 minutes, but some values are separated 16 minutes or 14 minutes or even less or more. We are going to make this values be separated by 15 minutes only with interpolating tools.
#
# by doing these steps in the resample phase of this work, we are most likely not to achieve this Uniform Length mencioned earlier, because, we are going to leave these more than 45 minutes gaps untouched, so at the end, the actual length of the time series of every patient will be most likely different to its uniform length.

# %%
for time_series in time_series_per_patient[:5]:
  print('Patient_ID:',time_series['Patient_ID'][0])
  print('Beggining datetime:',time_series.index[0])
  print('Ending datetime:',time_series.index[-1])
  print('Actual Length:',len(time_series))
  print('Uniform Length:',int((time_series.index[-1]-time_series.index[0])/pd.Timedelta(minutes=15)))
  print('TimeDelta:',(time_series.index[-1]-time_series.index[0]))
  print('--------------------------------\n')
# Out:
# Patient_ID: LIB193263
# Beggining datetime: 2020-06-09 19:08:00
# Ending datetime: 2022-03-19 07:32:00
# Actual Length: 60098
# Uniform Length: 62161
# TimeDelta: 647 days 12:24:00
# --------------------------------
#
# Patient_ID: LIB193264
# Beggining datetime: 2020-06-10 00:54:00
# Ending datetime: 2022-03-19 11:56:00
# Actual Length: 26787
# Uniform Length: 62156
# TimeDelta: 647 days 11:02:00
# --------------------------------
#
# Patient_ID: LIB193265
# Beggining datetime: 2019-01-27 10:52:00
# Ending datetime: 2022-03-19 22:04:00
# Actual Length: 46576
# Uniform Length: 110156
# TimeDelta: 1147 days 11:12:00
# --------------------------------
#
# Patient_ID: LIB193266
# Beggining datetime: 2020-10-08 18:03:00
# Ending datetime: 2022-03-21 12:09:00
# Actual Length: 55308
# Uniform Length: 50760
# TimeDelta: 528 days 18:06:00
# --------------------------------
#
# Patient_ID: LIB193267
# Beggining datetime: 2020-06-09 19:07:00
# Ending datetime: 2022-03-17 20:15:00
# Actual Length: 55501
# Uniform Length: 62020
# TimeDelta: 646 days 01:08:00
# --------------------------------

# %% [markdown]
# Next cell is to delete rare cases of duplicate values from every patient, i.e. timestamps where there are more than one glucose measurements in one patient. We are going to drop the column 'patient_ID' that we don't need because we have stored the patient's ID index and location in the 'patients' list.

# %%
#print(time_series_per_patient[0].loc['2020-06-10 09:20:00':])

for i in range(0,len(time_series_per_patient)):
  time_series_per_patient[i]= time_series_per_patient[i][~time_series_per_patient[i].index.duplicated(keep='first')]         #We are going to delete rare cases of duplicates from every patient's time series and we are going to keep the first value of the duplicate. For duplicate, we mean, various glucose measurements for one timestamp
  time_series_per_patient[i]=time_series_per_patient[i].drop(columns=['Patient_ID'])                                         #Drop the Patient_ID column, because the location of the patients_IDs are located in the 'patients' list

# %% [markdown]
# Next, we are going to reindex and resample between every gap of more than 45 minutes (leaving those gaps untouched) to have a uniform sampling frequency for every patient between those gaps.

# %%
for index,time_series in enumerate(time_series_per_patient):                                       #Loop from every patient's glucose time series
  time_diffs = time_series.index.to_series().diff()                                                #List of sampling frequencies from the current time series' iteration
  time_diffs=time_diffs.shift(periods=-1)                                                          #Shift this list so that value and sampling frequency correspond to each other
  morethan15min_positions = time_diffs[time_diffs > pd.Timedelta(minutes=45)].index                #Index of those positions where the gaps of missing data is more than 45 minutes

  last_datetime=time_series.index[0]                                                               #These two values are the last datetime index and the 'total_slice' parameter is where we are going to store current slices in the next loop
  total_slice=None

  for datetime in morethan15min_positions:                                                         #Loop through every gap of more that 45 minutes
    current_slice=time_series[last_datetime:datetime]                                              #This is the dataframe slice between gaps of more than 45 values of the current iteration
    #https://stackoverflow.com/questions/47148446/pandas-resample-interpolate-is-producing-nans
    oidx = current_slice.index                                                                     #Parameter where we are going to store the current slice index (old index)
    nidx = pd.date_range(oidx.min(), oidx[-1], freq='15T')                                         #Parameter where we are going to store the current slice index is there were a uniform sampling frequency of 15 minutes (new index)
    current_slice = current_slice.reindex(oidx.union(nidx)).interpolate('index').reindex(nidx)     #Current slice with the new index values interpolated from the values of the old index
    total_slice=pd.concat([total_slice, current_slice], axis=0)                                    #Store this resampled slice in the 'total_slice' parameter
    last_datetime=datetime+pd.Timedelta(seconds=1)                                                 #Update the 'last_datetime' parameter so the next current slice (in the next iteration) is located correctly

  time_series_per_patient[index]=total_slice                                                       #We are going to store the resampled and reindexed time series from every patient in the 'time_series_per_patient' list

# %%
import matplotlib.pyplot as plt        #Simple matplotlib visualization of the graph that we plotted earlier to check whether if the data keeps the coherence after getting resampled. We can see that the two graphs matches
import matplotlib.dates as md

fig, ax = plt.subplots(figsize = (12, 8))
ax.plot(time_series_per_patient[0]['Measurement'][400:430],label='Datos remuestreados')
ax.plot(original_data,label='Datos originales')
plt.xlabel('Tiempo')
plt.ylabel('Nivel de Glucosa [mg/dL]')

ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 30]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()

# %% [markdown]
# We check wether if we have created nans in the process of resampling, we can see in the next code cell that we haven created such nan values.

# %%
sumatory=0

for time_series in time_series_per_patient:
  sumatory+=int(time_series.isnull().sum())

print(sumatory)
# Out:
# 0

# %% [markdown]
# In the next code cell, we are going to check if we have values that are sampled over and less than 15 minutes.

# %%
oversamples=[]              #list which contains a counter of oversample values for every patient
undersamples=[]             #list which contains a counter of undersample values for every patient
undersample_freq=[]         #list which contains the number of missing values in an undersampled gap

for time_series in time_series_per_patient:
  time_diff = time_series.index.to_series().diff()[1:]
  morethan15min_positions = time_diff[time_diff > pd.Timedelta(minutes=15)].index
  lessthan15min_positions = time_diff[time_diff < pd.Timedelta(minutes=15)].index
  oversamples.append(len(lessthan15min_positions))
  undersamples.append(len(morethan15min_positions))
  undersample_freq+=list(time_diff[time_diff > pd.Timedelta(minutes=15)])

print(np.sum(oversamples))        #Number of oversample values in the whole dataframe
print(np.sum(undersamples))       #Number of undersample values in the whole dataframe
print(np.sum(pd.Series(undersample_freq) > pd.Timedelta(minutes=45)))     #If the gap of missing values is equal or less than 30 minutes, we are going to interpolate that gap
# Out:
# 0
# 16235
# 16235

# %% [markdown]
# We can observe that there are not values with less sampling frequency than 15 minutes, with only have samples over that value, other than the elements that are separated by a uniform 15 minutes, we only have elements which sampling frequency is over 15 minutes, and those gaps correspond to over 45 minutes gaps, i.e. more than two missing vale gaps. That is correct, because, as we said earlier we will only have one uniform sampling frequency other than the gaps over 45 minutes that will be untouched.

# %%
for index,time_series in enumerate(time_series_per_patient[:5]):
  print('Patient_ID:',patients[index])
  print('Beggining datetime:',time_series.index[0])
  print('Ending datetime:',time_series.index[-1])
  print('Actual Length:',len(time_series))
  print('Uniform Length:',int((time_series.index[-1]-time_series.index[0])/pd.Timedelta(minutes=15)))
  print('TimeDelta:',(time_series.index[-1]-time_series.index[0]))
  print('--------------------------------\n')
# Out:
# Patient_ID: LIB193263
# Beggining datetime: 2020-06-09 19:08:00
# Ending datetime: 2022-03-18 23:00:00
# Actual Length: 60157
# Uniform Length: 62127
# TimeDelta: 647 days 03:52:00
# --------------------------------
#
# Patient_ID: LIB193264
# Beggining datetime: 2020-06-10 00:54:00
# Ending datetime: 2022-03-18 20:16:00
# Actual Length: 26797
# Uniform Length: 62093
# TimeDelta: 646 days 19:22:00
# --------------------------------
#
# Patient_ID: LIB193265
# Beggining datetime: 2019-01-27 10:52:00
# Ending datetime: 2022-03-16 21:29:00
# Actual Length: 46381
# Uniform Length: 109866
# TimeDelta: 1144 days 10:37:00
# --------------------------------
#
# Patient_ID: LIB193266
# Beggining datetime: 2020-10-08 18:03:00
# Ending datetime: 2022-03-17 18:22:00
# Actual Length: 44514
# Uniform Length: 50401
# TimeDelta: 525 days 00:19:00
# --------------------------------
#
# Patient_ID: LIB193267
# Beggining datetime: 2020-06-09 19:07:00
# Ending datetime: 2022-03-17 07:43:00
# Actual Length: 54693
# Uniform Length: 61970
# TimeDelta: 645 days 12:36:00
# --------------------------------

# %% [markdown]
# We can observe that the actual length is not equal to the desired length (the length that the time series would have if we had measurements every 15 minutes non stop from start date to end date from the time series) because we have left the gaps over 45 minutes untouched.

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# The plan for the work is that the neural network uses a fit_generator function, so that we can utilize the GPU in the training of our neural network without running out of GPU memory in the way.
#
# To do that, we are going to take the time series of every patient, we are going to window every time series, and we are going to store within the folder 'src_folder' the windowed time series of every patient in a npy file (every patient will have a npy file named after its own patient_ID), this windowed time series must be of shape (len(time_series)-WINDOW_LENGTH+1,WINDOW_LENGTH, NUM_FEATURES), because we are working with an unidimensional time series, NUM_FEATURES must be equal to one.

# %%
import os

src_folder = "/content/windowed_dataset/"                                                   #The name of the folder where we are going to store the windowed time series of each patient

def create_folder(folder_name):                                                             #Function to create a directory only if that directory doesn't exist
  if not os.path.exists(folder_name):
      os.makedirs(folder_name)

create_folder(src_folder)                                                                   #Creation of the folder mentioned earlier
AHEAD_STEPS_PREDICTION=4                                                                    #Number of steps to predict ahead. In the case that we want to predict 1 hour ahead, AHEAD_STEPS_PREDICTION must be 4, because every value corresponds to the sampling frequency separation (15 minutes), 4 values ahead correspond to one hour ahead
WINDOW_STEPS=6                                                                              #Number of steps before the actual step we are going to take to input a window for the model to predict
PREDICTION_WINDOW=AHEAD_STEPS_PREDICTION+WINDOW_STEPS                                       #Add of these two parameters mentioned earlier                                                                         #Maybe we could take a normalization parameter to normalize those values that we are going to input our model
window_count=0

for patient_index,time_series in enumerate(time_series_per_patient):                        #Loop though every patient's glucose time series
  time_diffs = time_series.index.to_series().diff()                                         #Parameter where we are going to store the sampling frequency between every element of the current time series
  time_diffs=time_diffs.shift(periods=-1)                                                   #Shift of this parameter to make it correspong to every element of the current time series
  morethan15min_positions = time_diffs[time_diffs > pd.Timedelta(minutes=45)].index         #Those index position where there is a gap of data (over 45 minutes)
  last_datetime=time_series.index[0]                                                        #We set the last datetime of the slice to be the first index of the slice in the next loop's iterations

  for iter,datetime in enumerate(morethan15min_positions):                                  #Loop trough every gap of missing data (over 45 minutes)
    current_slice=time_series[last_datetime:datetime]                                       #Slice of time series between gaps of missing data (over 45 minutes)
    if len(current_slice)>=PREDICTION_WINDOW:                                               #If the current_slice of time series is bigger that the PREDICTION_WINDOW parameter, we can window this slice, so we keep ourselves in the loop
      windows=np.zeros((len(current_slice)-PREDICTION_WINDOW+1,PREDICTION_WINDOW,1))        #Array of zeros where we are going to store the current_slice of time series after being windowed
      for ind in range(0,len(current_slice)-PREDICTION_WINDOW+1):                           #Loop through the range of number of windows that we can create as from the current slice of time series
        windows[ind,:,:]=current_slice[ind:ind + PREDICTION_WINDOW]                         #We store the current window in the array of zeros mentioned earlier
      if iter==0:                                                                           #The general_windows parameter if where we are going to store all windows from all slices of data of the current patient. At the first slice, we initialize it as the windowed time_series of the current_slice of the current_slice
        general_windows=windows
      else:                                                                                 #But in the next slices we store the windowed current_slice with the last iteration general window with the numpy command 'concat' which allow us to update the 'general_windows' parameter without losing information at every iteration
        general_windows=np.concatenate((general_windows,windows),axis=0)
    last_datetime=datetime+pd.Timedelta(seconds=1)                                          #We update the next first datetime to index the next current_slice iteration

  np.save(src_folder+patients[patient_index],general_windows,allow_pickle=True)             #Next, we store the windowed time series of all of the current slices between gaps of missing data of each patient as a npy file named after the Patient's ID
  window_count+=np.shape(general_windows)[0]

print(np.shape(general_windows))                                                            #In order to check if everything is in order, we check the shape of the last windowed time series of the last patient of the iteration to check if the shape matches (n,PREDICTION_WINDOW,1), being n a parameter that changes in terms of the time series' length
print(window_count)                                                                         #Check number of windows
# Out:
# (5915, 10, 1)
# 2832381

# %% [markdown]
# ##Train/Test Data Split

# %% [markdown]
# The development of this Master's Thesis involves choosing a sample group of patients (between 5 and 10 patients), we are going to call this group of patients 'control group'.We need to train our 'from the scratch' model individually in the control group. Next we are going to take a pretrained model, pretrained with the rest odf the patients, when it is pretrained, we are going to train this pretrained model in the every patient of the control group individually.
#
# Finally, we are going to compare the performance of this 'from the scratch' model to the pretrained one, using different metrics.
# Ideally, the time series of the patients from  the control group must be long time series, to have a good portion of time range of the time series to test the performance of our models, for that, for the control group, we should take patients with time series with good length.

# %%
from sklearn.model_selection import train_test_split

CONTROL_GROUP_SIZE=5                                                                                               #Number of patients that will be in the control group

lengths=[]
for patient in patients:                                                                                           #A loop trough every filenames patient
  array=np.load(os.path.join(src_folder,patient)+'.npy',allow_pickle=True)                                         #Load its correspondent windowed dataset
  lengths.append(len(array))                                                                                       #Store its length in the self.lengths list

# Use sorted() to get a sorted version of the list along with their indices
sorted_numbers = sorted(enumerate(lengths), key=lambda x: x[1], reverse=True)

# Get the indices of the 5 highest values
highest_length_indices = [index for index, _ in sorted_numbers[:5]]

test_patients=[patients[index] for index in highest_length_indices]                                               #The test patients are those who have the five time series with more legth within all the patients
other_patients=[patients[index] for index in range(0,len(patients)) if index not in highest_length_indices]       #The train patients are the rest of the patients
train_patients,validation_patients=train_test_split(other_patients,test_size=0.2,random_state=0)
print(len(test_patients)+len(validation_patients)+len(train_patients))                                                                     #Check if the number of total patients is correct (It's correct, 110 patients, same as before)
# Out:
# 110

# %%
timestamps_test=[]
partial_timestamps=[]

for patient_index,patient in enumerate(test_patients):
  partial_timestamp=np.array(time_series_per_patient)[patients==patient]
  partial_timestamp=partial_timestamp[0].index
  partial_timestamps.append(partial_timestamp)
  timestamps_test+=list(partial_timestamp)

# %%
from keras.utils import Sequence

class Custom_Generator(Sequence) :

  def __init__(self, filenames, batch_size) :
    self.filenames = filenames                                                                             #The list of patients that we are going to take in our fit_generator
    self.lengths=[]                                                                                        #A list where the legths of every windowed time series of each filenames patient will be stored
    self.indexes=[0]                                                                                       # The indexes where the windowed time series of every each filenames patients end

    for filename in self.filenames:                                                                        #A loop trough every filenames patient
        array=np.load(os.path.join(src_folder,filename)+'.npy',allow_pickle=True)                          #Load its correspondent windowed dataset
        self.lengths.append(len(array))                                                                    #Store its length in the self.lengths list
        self.indexes.append(np.sum(self.lengths))                                                          #And store its ending index in the self.indexes list

    self.n_frames=np.sum(self.lengths)                                                                     #self.n_frames will be the number of windows that we are going to have in this fit_generator
    self.batch_size = batch_size                                                                           #Specification of the batch size as an argument of the class
    self.current_filename=self.filenames[0]                                                                #Specification of the name of the first patient windowed time series that we are going to feed to the neural network
    self.last_iter_index=0                                                                                 #Parameter which is going to tell us if we have reached the end of a windowed file initializated to zero
    self.windowed_file=np.load(os.path.join(src_folder,self.filenames[0])+'.npy',allow_pickle=True)        #the first patient windowed file that we are going to feed to the neural network

  def __len__(self) :                                                                                      #Method which simply returns the number of steps per epoch that we need to run through an epoch of data in this fit_generator
    return (np.floor(self.n_frames / float(self.batch_size))).astype(np.int)                               #The number of steps per epoch is going to be defined as the floor of the total number of windows that we have in this fit generator divided by its batch size

  def __getitem__(self, idx) :                                                                             #Method with give us batch in terms of the input parameter idx, in the training of a model, the range of values of idx should go from zero to the number of steps per epoch
    first_batch_index=idx * self.batch_size                                                                #These two parameters combined with the self.indexes and self.lengths can give us the correspondent batches from every time series
    second_batch_index=(idx+1) * self.batch_size

    first_index=np.sum(np.array(self.indexes)<=first_batch_index)-1                                        #Indexes that specify us where the first and last window of the batch is in terms of self.filenames index positions
    last_index=np.sum(np.array(self.indexes)<=second_batch_index)-1

    beginning_filename=self.filenames[first_index]                                                         #first and windowed time series name files where the first and last windows of time series belongs to in this current batch of data
    ending_filename=self.filenames[last_index]

    series_first_index=np.abs(self.indexes[first_index]-first_batch_index)                                 #indexes wich will help us locate the windows that we want to add in the current batch of windows
    series_last_index=np.abs(self.indexes[last_index]-second_batch_index)

    batch_x=np.zeros((self.batch_size,WINDOW_STEPS,1))                                                     #arrays of zeros where we are going to store our x and y values to feed batches to the model in which the fit generator is hooked on
    batch_y=np.zeros((self.batch_size,1))

    if first_index==0 and self.last_iter_index!=0:                                                         #When we are at the first patient windowed dataset but the last iteration was not the first windowed dataset, i.e. when idx have reached the value of steps per epoch and is reseting again from zero
      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[0])+'.npy',allow_pickle=True)      #We just set the first windowed dataset as the first patient windowed dataset without taking into account that the last windowed dataset was different

    if first_index!=0:                                                                                     #Explaining this later
      if self.last_iter_index!=first_index:
        self.windowed_file=np.load(os.path.join(src_folder,self.filenames[first_index])+'.npy',allow_pickle=True)

    if first_index==last_index:
      batch_x[:,:,:]=self.windowed_file[series_first_index:series_last_index,:WINDOW_STEPS,:]
      batch_y[:,:]=self.windowed_file[series_first_index:series_last_index,-1,:]
    elif np.abs(last_index-first_index)==1:
      len_first_slice=self.indexes[last_index]-first_batch_index
      batch_x[:len_first_slice,:,:]=self.windowed_file[series_first_index:,:WINDOW_STEPS,:]
      batch_y[:len_first_slice,:]=self.windowed_file[series_first_index:,-1,:]

      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[last_index])+'.npy',allow_pickle=True)

      batch_x[len_first_slice:,:,:]=self.windowed_file[:series_last_index,:WINDOW_STEPS,:]
      batch_y[len_first_slice:,:]=self.windowed_file[:series_last_index,-1,:]
    else:
      len_first_slice=self.indexes[first_index+1]-first_batch_index
      batch_x[:len_first_slice,:,:]=self.windowed_file[series_first_index:,:WINDOW_STEPS,:]
      batch_y[:len_first_slice,:]=self.windowed_file[series_first_index:,-1,:]
      last_slice=len_first_slice

      for i in range(first_index+1,last_index):
        self.windowed_file=np.load(os.path.join(src_folder,self.filenames[i])+'.npy',allow_pickle=True)
        #print(i)
        intermediate_array=self.windowed_file[:,:,:]
        batch_x[last_slice:last_slice+len(intermediate_array),:,:]=intermediate_array[:,:WINDOW_STEPS,:]
        batch_y[last_slice:last_slice+len(intermediate_array),:]=intermediate_array[:,-1,:]
        last_slice+=len(intermediate_array)

      self.windowed_file=np.load(os.path.join(src_folder,self.filenames[last_index])+'.npy',allow_pickle=True)
      batch_x[last_slice:,:,:]=self.windowed_file[:series_last_index,:WINDOW_STEPS,:]
      batch_y[last_slice:,:]=self.windowed_file[:series_last_index,-1,:]

    #batch_x=batch_x
    #batch_y=denormalize(batch_y)
    batch=(batch_x,batch_y)
    self.last_iter_index=last_index
    return batch                                                                                                       #Returning the correspondent batch to the parameter idx

# %% [markdown]
# #Training

# %% [markdown]
# ##Neural Network Arquitecture

# %% [markdown]
# Next, It's the phase related to designing the model, training it, and extracting the correspondent results of metrics. First, the presentation of the design of the model that we have proposed for the development of this Master's Thesis.

# %%
import keras
import tensorflow as tf

TOTAL_EPOCHS=15

def create_model():                         #Function to create a recurrent neural network with a conv1d layers, a encoder LSTM, a decoder LSTM and fully connected layers at the end, this is known in the literature as an encoder-decoder recurrent neural network architecture.
  model=keras.models.Sequential()

  #model.add(keras.layers.Lambda(lambda x: x / 400))
  model.add(keras.layers.Conv1D(60,5,strides=1,padding='causal',activation='relu',input_shape=(None,1)))
  model.add(keras.layers.LSTM(64,return_sequences=True))
  model.add(keras.layers.LSTM(64,return_sequences=False))
  model.add(keras.layers.Dense(30))
  model.add(keras.layers.Dense(10))
  model.add(keras.layers.Dense(1))
  #model.add(keras.layers.Lambda(lambda x: x * 300))
  return model

model=create_model()                        #Then, we just call this function to create the correspondent model and plot it for visualization
keras.utils.vis_utils.plot_model(model, show_shapes=False, show_layer_names=False)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, None, 60)          360
#
#  lstm_10 (LSTM)              (None, None, 64)          32000
#
#  lstm_11 (LSTM)              (None, 64)                33024
#
#  dense_15 (Dense)            (None, 30)                1950
#
#  dense_16 (Dense)            (None, 10)                310
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 67,655
# Trainable params: 67,655
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Hyperparameter Optimization

# %% [markdown]
# Next, It's the time to optimize the parameters that are involved in the compile of the model, like learning rate, optimizer and loss. It's just like doing a random walk to find this parameters, but instead, we are going to use an especialized library for optimization of parameters (hyperas library). We first create the fit_generators that we are going to use for this hyperparameter optimization.

# %%
train_generator=Custom_Generator(train_patients,128)    #Instantiation of Custon Generator mentioned earlier
validation_generator=Custom_Generator(validation_patients,128)
test_generator=Custom_Generator(test_patients,128)

# %% [markdown]
# Next, we perform hyperparameters oiptimization with the library that we mantioned earlier within the range that we set for every hyperparameter, for exple, for loss, we are only going to search in the space of 4 losses: msle, mse, mae and Huber.

# %%
from hyperas.distributions import choice,loguniform,uniform
from hyperopt import Trials, STATUS_OK, tpe
from keras import backend as K
from keras.backend import clear_session
from tqdm.notebook import tqdm

optimization_startime=time.time()

losses=['mse','mae','huber_loss','msle','mean_absolute_percentage_error']                              #We first define the search space to optimize parameters
optimizers=['SGD','RMSprop','Adam','Adagrad']
space_tf = {'loss': choice('loss',losses),'optimizer': choice('optimizer',optimizers),'learning_rate':loguniform('learning_rate',np.log(1e-8),np.log(0.6))}
#space_tf = {'dense_depth':uniform('dense_depth',5,20),'n_hidden_neurons': uniform('n_hidden_neurons',1000,3000),'loss': choice('loss',losses),'optimizer': choice('optimizer',optimizers),'learning_rate':loguniform('learning_rate',np.log(1e-6),np.log(0.6))}

max_evals=15                                                     #Max of evaluations over the parameters that we want to optimize
epochs_per_eval=1                                                #number of epoch that our neural network will perform in each evaluation of the optimization of the parameters
pbar = tqdm(total=max_evals*epochs_per_eval, desc="Hyperopt")    #Custom loading bar to visualize the progress of the optimization algorithm

def create_optimized_model(space_sample):                        #Function to evaluate the performance of the algorithm with a set of hyperparameters to optimize. In this case, those parameters are the optimizer, the loos and the learning rate
    global pbar                                                  #This function just creates a model and lets it run truogh one epoch of out fit generator with with different hyperparameter combinations, those hyperparameters are in fact, the ones that we want to optimize
    clear_session()
    tf.random.set_seed(0)

    #dense_depth=int(space_sample['dense_depth'])
    #n_hidden_neurons=int(space_sample['n_hidden_neurons'])
    loss=space_sample['loss']
    optimizer=space_sample['optimizer']
    learning_rate=space_sample['learning_rate']

    model=create_model()     #n_hidden_neurons,dense_depth)
    model.compile(loss=loss,optimizer=optimizer,metrics=['mse'])
    K.set_value(model.optimizer.learning_rate, learning_rate)

    history=model.fit_generator(train_generator,epochs=epochs_per_eval,steps_per_epoch=int(train_generator.__len__()),verbose=0,shuffle=False)
    acc=np.amin(history.history['mse'])
    pbar.update()
    return acc                                                  #This function just returns the minimum loss reached trough one epoch

from hyperopt import tpe, fmin

best_classifier = fmin(create_optimized_model, space_tf, algo=tpe.suggest, max_evals=max_evals)    #function to return the best combination of hyperparameters that the earlier algorithm has reached
pbar.close()                                                                                       #Closes the progress bar

print('_________________________')

print(best_classifier)
print('Loss:',losses[best_classifier['loss']])
print('Optimizer:',optimizers[best_classifier['optimizer']])                                                                          #Print of the best combination of hyperparameters that we have reached in this cell of code
print('Learning Rate:',float(best_classifier['learning_rate']))

optimization_endtime=time.time()
optimization_time=(optimization_endtime-optimization_startime)
# Out:
# Hyperopt:   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
#   7%|▋         | 1/15 [01:34<21:57, 94.13s/trial, best loss: 4515.966796875]
#  13%|█▎        | 2/15 [03:59<26:58, 124.52s/trial, best loss: 1593.7962646484375]
#  20%|██        | 3/15 [05:33<22:03, 110.29s/trial, best loss: 1593.7962646484375]
#  27%|██▋       | 4/15 [07:04<18:49, 102.70s/trial, best loss: 1593.7962646484375]
#  33%|███▎      | 5/15 [08:37<16:32, 99.30s/trial, best loss: 1422.5037841796875]
#  40%|████      | 6/15 [11:03<17:17, 115.27s/trial, best loss: 1422.5037841796875]
#  47%|████▋     | 7/15 [12:37<14:25, 108.20s/trial, best loss: 1266.2474365234375]
#  53%|█████▎    | 8/15 [14:08<11:59, 102.84s/trial, best loss: 1266.2474365234375]
#  60%|██████    | 9/15 [15:46<10:07, 101.28s/trial, best loss: 1266.2474365234375]
#  67%|██████▋   | 10/15 [17:18<08:12, 98.41s/trial, best loss: 1266.2474365234375]
#  73%|███████▎  | 11/15 [18:52<06:27, 96.86s/trial, best loss: 1266.2474365234375]
#  80%|████████  | 12/15 [20:28<04:50, 96.84s/trial, best loss: 1266.2474365234375]
#  87%|████████▋ | 13/15 [22:03<03:12, 96.22s/trial, best loss: 1266.2474365234375]
#  93%|█████████▎| 14/15 [24:28<01:51, 111.02s/trial, best loss: 1266.2474365234375]
# 100%|██████████| 15/15 [26:00<00:00, 104.04s/trial, best loss: 1266.2474365234375]
# _________________________
# {'learning_rate': 0.008532495211677144, 'loss': 2, 'optimizer': 3}
# Loss: huber_loss
# Optimizer: Adagrad
# Learning Rate: 0.008532495211677144

# %% [markdown]
# ##Pretraining Phase

# %% [markdown]
# In this part of the notebook, we are going to pretrain a model with the optimized combination of hyperparameters that we have searched earlier with the time series data of the patients not belonging to the control group.

# %%
pretraining_startime=time.time()
loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
optimizer=optimizers[best_classifier['optimizer']]
learning_rate=float(best_classifier['learning_rate'])
EPOCHS=TOTAL_EPOCHS                                                     #define the number of epochs in which we want to pretrain the model for the next individual trainings in the patients of the control group

metrics=[tf.keras.losses.Huber(),tf.keras.losses.MeanSquaredError(),tf.keras.losses.MeanAbsoluteError(),tf.keras.losses.MeanAbsolutePercentageError(),
         tf.keras.losses.MeanSquaredLogarithmicError(),tf.keras.losses.LogCosh()]        #Define of some metrics that we could use to evaluate our models

tf.random.set_seed(0)                                         #set random set of tensorflow
model=create_model()                                          #create one neural network from scratch with our function 'create_model()'
model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
K.set_value(model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

checkpoint_folder='/content/drive/MyDrive/Checkpoint/'        #drive folder name where we are going to save our pretrained model, and to prevent executing this pretraining every time we want to execute this notebook
create_folder(checkpoint_folder)                              #create folder
model_checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_folder+'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',save_best_only=True,monitor='val_loss',mode='auto')  #save model callback in such folder mentioned in the above lines

history=model.fit_generator(train_generator,shuffle=False,epochs=EPOCHS,steps_per_epoch=int(train_generator.__len__()),validation_data=validation_generator,validation_steps=int(validation_generator.__len__()),verbose=1,callbacks=[model_checkpoint_callback])     #pretrain this model with that callback
pretraining_endtime=time.time()
pretraining_time=(pretraining_endtime-pretraining_startime)
# Out:
# Epoch 1/15
# 14722/14722 [==============================] - 144s 10ms/step - loss: 24.2274 - huber_loss: 24.2274 - mean_squared_error: 1194.4131 - mean_absolute_error: 24.7220 - mean_absolute_percentage_error: 16.5103 - mean_squared_logarithmic_error: 0.0610 - log_cosh: 24.0423 - val_loss: 23.8695 - val_huber_loss: 23.8695 - val_mean_squared_error: 1182.7794 - val_mean_absolute_error: 24.3639 - val_mean_absolute_percentage_error: 17.8880 - val_mean_squared_logarithmic_error: 0.0560 - val_log_cosh: 23.6846
# Epoch 2/15
# 14722/14722 [==============================] - 139s 9ms/step - loss: 22.3390 - huber_loss: 22.3390 - mean_squared_error: 1014.7172 - mean_absolute_error: 22.8331 - mean_absolute_percentage_error: 15.3491 - mean_squared_logarithmic_error: 0.0442 - log_cosh: 22.1545 - val_loss: 23.7567 - val_huber_loss: 23.7567 - val_mean_squared_error: 1177.1384 - val_mean_absolute_error: 24.2510 - val_mean_absolute_percentage_error: 17.7566 - val_mean_squared_logarithmic_error: 0.0556 - val_log_cosh: 23.5719
# Epoch 3/15
# 14722/14722 [==============================] - 146s 10ms/step - loss: 22.2589 - huber_loss: 22.2589 - mean_squared_error: 1009.3339 - mean_absolute_error: 22.7529 - mean_absolute_percentage_error: 15.3120 - mean_squared_logarithmic_error: 0.0441 - log_cosh: 22.0745 - val_loss: 23.7142 - val_huber_loss: 23.7142 - val_mean_squared_error: 1175.7551 - val_mean_absolute_error: 24.2086 - val_mean_absolute_percentage_error: 17.7042 - val_mean_squared_logarithmic_error: 0.0556 - val_log_cosh: 23.5295
# Epoch 4/15
# 14722/14722 [==============================] - 138s 9ms/step - loss: 22.2288 - huber_loss: 22.2288 - mean_squared_error: 1007.6392 - mean_absolute_error: 22.7228 - mean_absolute_percentage_error: 15.2956 - mean_squared_logarithmic_error: 0.0440 - log_cosh: 22.0444 - val_loss: 23.6842 - val_huber_loss: 23.6842 - val_mean_squared_error: 1174.5112 - val_mean_absolute_error: 24.1785 - val_mean_absolute_percentage_error: 17.6666 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 23.4993
# Epoch 5/15
# 14722/14722 [==============================] - 145s 10ms/step - loss: 22.2114 - huber_loss: 22.2114 - mean_squared_error: 1006.6127 - mean_absolute_error: 22.7055 - mean_absolute_percentage_error: 15.2866 - mean_squared_logarithmic_error: 0.0440 - log_cosh: 22.0270 - val_loss: 23.6751 - val_huber_loss: 23.6751 - val_mean_squared_error: 1174.8605 - val_mean_absolute_error: 24.1694 - val_mean_absolute_percentage_error: 17.6449 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 23.4903
# Epoch 6/15
# 14722/14722 [==============================] - 139s 9ms/step - loss: 22.2000 - huber_loss: 22.2000 - mean_squared_error: 1006.0157 - mean_absolute_error: 22.6940 - mean_absolute_percentage_error: 15.2805 - mean_squared_logarithmic_error: 0.0440 - log_cosh: 22.0158 - val_loss: 23.6696 - val_huber_loss: 23.6696 - val_mean_squared_error: 1175.1824 - val_mean_absolute_error: 24.1639 - val_mean_absolute_percentage_error: 17.6383 - val_mean_squared_logarithmic_error: 0.0554 - val_log_cosh: 23.4849
# Epoch 7/15
# 14722/14722 [==============================] - 140s 10ms/step - loss: 22.1901 - huber_loss: 22.1901 - mean_squared_error: 1005.4688 - mean_absolute_error: 22.6841 - mean_absolute_percentage_error: 15.2735 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 22.0058 - val_loss: 23.6643 - val_huber_loss: 23.6643 - val_mean_squared_error: 1173.7887 - val_mean_absolute_error: 24.1587 - val_mean_absolute_percentage_error: 17.6486 - val_mean_squared_logarithmic_error: 0.0553 - val_log_cosh: 23.4795
# Epoch 8/15
# 14722/14722 [==============================] - 140s 9ms/step - loss: 22.1789 - huber_loss: 22.1789 - mean_squared_error: 1004.8768 - mean_absolute_error: 22.6729 - mean_absolute_percentage_error: 15.2654 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 21.9946 - val_loss: 23.6569 - val_huber_loss: 23.6569 - val_mean_squared_error: 1173.7065 - val_mean_absolute_error: 24.1513 - val_mean_absolute_percentage_error: 17.6355 - val_mean_squared_logarithmic_error: 0.0553 - val_log_cosh: 23.4721
# Epoch 9/15
# 14722/14722 [==============================] - 141s 10ms/step - loss: 22.1730 - huber_loss: 22.1730 - mean_squared_error: 1004.4916 - mean_absolute_error: 22.6669 - mean_absolute_percentage_error: 15.2622 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 21.9887 - val_loss: 23.6503 - val_huber_loss: 23.6503 - val_mean_squared_error: 1173.4617 - val_mean_absolute_error: 24.1446 - val_mean_absolute_percentage_error: 17.6231 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4654
# Epoch 10/15
# 14722/14722 [==============================] - 145s 10ms/step - loss: 22.1673 - huber_loss: 22.1673 - mean_squared_error: 1004.0991 - mean_absolute_error: 22.6613 - mean_absolute_percentage_error: 15.2590 - mean_squared_logarithmic_error: 0.0439 - log_cosh: 21.9831 - val_loss: 23.6458 - val_huber_loss: 23.6458 - val_mean_squared_error: 1173.1475 - val_mean_absolute_error: 24.1401 - val_mean_absolute_percentage_error: 17.6169 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4610
# Epoch 11/15
# 14722/14722 [==============================] - 140s 9ms/step - loss: 22.1628 - huber_loss: 22.1628 - mean_squared_error: 1003.7852 - mean_absolute_error: 22.6568 - mean_absolute_percentage_error: 15.2560 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9786 - val_loss: 23.6415 - val_huber_loss: 23.6415 - val_mean_squared_error: 1172.6138 - val_mean_absolute_error: 24.1358 - val_mean_absolute_percentage_error: 17.6151 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4567
# Epoch 12/15
# 14722/14722 [==============================] - 147s 10ms/step - loss: 22.1588 - huber_loss: 22.1588 - mean_squared_error: 1003.5038 - mean_absolute_error: 22.6527 - mean_absolute_percentage_error: 15.2535 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9745 - val_loss: 23.6389 - val_huber_loss: 23.6389 - val_mean_squared_error: 1172.3324 - val_mean_absolute_error: 24.1332 - val_mean_absolute_percentage_error: 17.6128 - val_mean_squared_logarithmic_error: 0.0552 - val_log_cosh: 23.4540
# Epoch 13/15
# 14722/14722 [==============================] - 141s 10ms/step - loss: 22.1551 - huber_loss: 22.1551 - mean_squared_error: 1003.2657 - mean_absolute_error: 22.6491 - mean_absolute_percentage_error: 15.2512 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9709 - val_loss: 23.6384 - val_huber_loss: 23.6384 - val_mean_squared_error: 1172.1410 - val_mean_absolute_error: 24.1327 - val_mean_absolute_percentage_error: 17.6163 - val_mean_squared_logarithmic_error: 0.0551 - val_log_cosh: 23.4535
# Epoch 14/15
# 14722/14722 [==============================] - 140s 10ms/step - loss: 22.1516 - huber_loss: 22.1516 - mean_squared_error: 1003.0250 - mean_absolute_error: 22.6456 - mean_absolute_percentage_error: 15.2492 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9674 - val_loss: 23.6312 - val_huber_loss: 23.6312 - val_mean_squared_error: 1171.6025 - val_mean_absolute_error: 24.1255 - val_mean_absolute_percentage_error: 17.6099 - val_mean_squared_logarithmic_error: 0.0551 - val_log_cosh: 23.4464
# Epoch 15/15
# 14722/14722 [==============================] - 141s 10ms/step - loss: 22.1477 - huber_loss: 22.1477 - mean_squared_error: 1002.7573 - mean_absolute_error: 22.6417 - mean_absolute_percentage_error: 15.2464 - mean_squared_logarithmic_error: 0.0438 - log_cosh: 21.9635 - val_loss: 23.6297 - val_huber_loss: 23.6297 - val_mean_squared_error: 1171.0441 - val_mean_absolute_error: 24.1241 - val_mean_absolute_percentage_error: 17.6143 - val_mean_squared_logarithmic_error: 0.0550 - val_log_cosh: 23.4449

# %%
print(list(history.history.keys()))
print(list(history.history.keys())[1:7])
# Out:
# ['loss', 'huber_loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'log_cosh', 'val_loss', 'val_huber_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_mean_absolute_percentage_error', 'val_mean_squared_logarithmic_error', 'val_log_cosh']
# ['huber_loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'log_cosh']

# %% [markdown]
# This is not relevant for the Master's Thesis, but we can check out some metrics in the pretraining phase, to check wether if our model is learning while in the pretraining phase

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

keys=list(history.history.keys())[1:7]

plt.style.use("ggplot")
fig, axs = plt.subplots(3, 2, sharex=True, sharey=False, figsize=(10, 15))
fig.suptitle(t='Arquitectura '+str(ARCHITECTURE_NUMBER),y=1)
fig.supxlabel('Episodios de Entrenamiento')
fig.tight_layout()

for key_index,key in enumerate(keys):
  column=key_index%2
  row=int(key_index/2)

  axs[row,column].plot(np.arange(1,EPOCHS+1),history.history[key],label='Preentrenamiento')
  axs[row,column].plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='Validación')
  axs[row,column].grid(which='major', color='white', linewidth=1.2)
  axs[row,column].set_ylabel(key.replace("_", " " ).title())
  axs[row,column].ticklabel_format(axis="y", style="sci", scilimits=(0,0))

  if column==1:
    axs[row,column].yaxis.set_label_coords(-0.07,0.5)

  if row==0 and column==0:
    axs[row,column].legend(loc='upper center', bbox_to_anchor=(0.2, 1.20), fancybox=True, shadow=True)

plt.show()

'''
for key_index,key in list(history.history.keys())[1:7]:
  fig, ax = plt.subplots()                               #simple matplotlib visualization of the performance in training loss of the model over the training epochs
  ax.plot(np.arange(1,EPOCHS+1),history.history[key],label=key)
  ax.plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='val_'+key)
  ax.xaxis.set_major_locator(MaxNLocator(integer=True))
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid()
  plt.show()
  print('------------------------')
'''
# Out:
# "\nfor key_index,key in list(history.history.keys())[1:7]:\n  fig, ax = plt.subplots()                               #simple matplotlib visualization of the performance in training loss of the model over the training epochs\n  ax.plot(np.arange(1,EPOCHS+1),history.history[key],label=key)\n  ax.plot(np.arange(1,EPOCHS+1),history.history['val_'+key],label='val_'+key)\n  ax.xaxis.set_major_locator(MaxNLocator(integer=True))\n  plt.xlabel('Epochs')\n  plt.ylabel('Loss')\n  plt.legend()\n  plt.grid()\n  plt.show()\n  print('------------------------')\n"

# %%
test_history=model.evaluate_generator(test_generator,steps=int(test_generator.__len__()))

# %%
print(test_history)
# Out:
# [20.23409080505371, 20.23409080505371, 814.1527709960938, 20.72784423828125, 16.054691314697266, 0.043404243886470795, 20.04987144470215]

# %% [markdown]
# And yet, in this situation, we can visualize the predictions of the model over the patients in the control group, patients that our model have not yet seen. We can check visually with a simple matplotlib graph wether this predictions have some coherence comparing with the ground truth of the data over some patients in the control group.

# %%
pretrained_model = keras.models.load_model(checkpoint_folder + 'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',compile=False)

loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
optimizer=optimizers[best_classifier['optimizer']]
learning_rate=float(best_classifier['learning_rate'])

pretrained_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
K.set_value(pretrained_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

# %%
test_generator=Custom_Generator([test_patients[0]],1)     #create a fit generator over patients in the control group with batch size equal to 1

# %%
import matplotlib.pyplot as plt

X_test=np.array([np.squeeze(test_generator.__getitem__(i)[0]) for i in range(0,int(test_generator.__len__()-1))])   #we first extract the X data and the ground truth from the test generator
Y_test=np.array([np.squeeze(test_generator.__getitem__(i)[1]) for i in range(0,int(test_generator.__len__()-1))])
#X_test=denormalize(X_test)
#Y_test=denormalize(Y_test)

print(np.shape(X_test))   #Check those shapes to observe if it have coherence over the sahpe that it have to have (number of windows,WINDOW_LENGTH,1)
print(np.shape(Y_test))   #(number of windows,1)
# Out:
# (109175, 6)
# (109175,)

# %%
predictions=model.predict(X_test[:80])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()
ax.plot(timestamps_test[:80],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[:80],Y_test[:80],label='Datos Reales',color='orange')

#ax.xaxis.set_major_locator(md.MinuteLocator(byminute = [0, 20]))
ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 2s 8ms/step

# %%
predictions=model.predict(X_test[100:180])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()

ax.plot(timestamps_test[100:180],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[100:180],Y_test[100:180],label='Datos Reales',color='orange')

ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %%
predictions=model.predict(X_test[300:380])      #We check the first 150 elements predictions from the test generator and compare to its correspondent ground truth elements

fig, ax = plt.subplots()

ax.plot(timestamps_test[300:380],predictions,label='Predicción',color='green')
ax.plot(timestamps_test[300:380],Y_test[300:380],label='Datos Reales',color='orange')

ax.xaxis.set_major_formatter(md.DateFormatter('%H:%M'))
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)

plt.ylabel('Nivel de Glucosa [mg/dL]')
plt.xlabel('Tiempo')
plt.legend()
plt.grid(which='major', color='white', linewidth=1.2)
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %% [markdown]
# ##Pretrained Model vs From the Scratch Model

# %% [markdown]
# Now, we are going to try to train individually in each patient from the control group. We are going o try to do that without fit generator, fit generator was aahelpful tool to train the neural network trough all the patients with a single call and without having to worry about GPU memory, now, we are going to try to work with this data without fit generator, which is more helpful for individually training.

# %%
training_startime=time.time()
pretrained_metrics=[]                                                                             #Lists where we are going to store the control group patients metrics for the pretrained and the 'from the scratch' model
fromthescratch_metrics=[]
test_pretrained_metrics=[]                                                                             #Lists where we are going to store the control group patients metrics for the pretrained and the 'from the scratch' model
test_fromthescratch_metrics=[]

for ind,patient in enumerate(test_patients):                                                                      #A loop trough every filenames patient
  print(str(ind)+'-'+(patient)+'\n')

  pretrained_model = keras.models.load_model(checkpoint_folder + 'pretrained_glucose_predictor(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').h5',compile=False)#custom_objects={"Huber": tf.keras.losses.Huber() })    #Load the pretrained model and create a 'from the scratch' model

  fromthescratch_model=create_model()
  loss=losses[best_classifier['loss']]                           #define that last combination of relatively optimized hyperparameters into parameters that can define our next models
  optimizer=optimizers[best_classifier['optimizer']]
  learning_rate=float(best_classifier['learning_rate'])

  fromthescratch_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
  K.set_value(fromthescratch_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier
  pretrained_model.compile(loss=loss,optimizer=optimizer,metrics=metrics)  #compile the model with the optimized parameters of optimizer and loss that we searched earlier
  K.set_value(pretrained_model.optimizer.learning_rate, learning_rate)     #compile the model with the optimized parameter of learning rate that we searched earlier

  windowed_data=np.load(os.path.join(src_folder,patient)+'.npy',allow_pickle=True)                          #Load its correspondent windowed dataset
  X=np.array([window[:WINDOW_STEPS,:] for window in windowed_data])
  Y=np.array([window[-1,:] for window in windowed_data])

  X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False, random_state=42)

  print('PRETRAINED_MODEL')
  pretrained_history=pretrained_model.fit(x=X_train,y=y_train,shuffle=False,epochs=TOTAL_EPOCHS,batch_size=32,validation_split=0.1,verbose=1)
  print('\nFROMTHESCRATCH_MODEL')
  fromthescratch_history=fromthescratch_model.fit(x=X_train,y=y_train,shuffle=False,epochs=TOTAL_EPOCHS,batch_size=32,validation_split=0.1,verbose=1)

  test_pretrained_history=pretrained_model.evaluate(x=X_test,y=y_test,batch_size=32)
  test_fromthescratch_history=fromthescratch_model.evaluate(x=X_test,y=y_test,batch_size=32)

  pretrained_metrics.append(pretrained_history)
  fromthescratch_metrics.append(fromthescratch_history)
  test_pretrained_metrics.append(test_pretrained_history)
  test_fromthescratch_metrics.append(test_fromthescratch_history)

  Y_pretrained_prediction=pretrained_model.predict(X_test)
  Y_fromthescratch_prediction=fromthescratch_model.predict(X_test)
  plt.plot(partial_timestamps[ind][:300],Y_pretrained_prediction[:300],label='Predicciones Preentrenadas')
  plt.plot(partial_timestamps[ind][:300],Y_fromthescratch_prediction[:300],label='Predicciones sin Preentrenar')
  plt.plot(partial_timestamps[ind][:300],Y_test[:300],label='Datos Reales')
  plt.legend()
  plt.ylabel('Nivel de Glucosa [mg/dL]')
  plt.xlabel('Tiempo')
  plt.grid(which='major', color='white', linewidth=1.2)
  plt.show()

  print('\n-------------------------------------------------------\n')

training_endtime=time.time()
training_time=(training_endtime-training_startime)
# Out:
# 0-LIB193277
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2457/2457 [==============================] - 29s 10ms/step - loss: 17.9154 - huber_loss: 17.9159 - mean_squared_error: 617.3217 - mean_absolute_error: 18.4094 - mean_absolute_percentage_error: 15.8757 - mean_squared_logarithmic_error: 0.0422 - log_cosh: 17.7325 - val_loss: 15.4780 - val_huber_loss: 15.4776 - val_mean_squared_error: 475.8746 - val_mean_absolute_error: 15.9701 - val_mean_absolute_percentage_error: 14.3497 - val_mean_squared_logarithmic_error: 0.0358 - val_log_cosh: 15.2955
# Epoch 2/15
# 2457/2457 [==============================] - 23s 10ms/step - loss: 17.0409 - huber_loss: 17.0418 - mean_squared_error: 566.5189 - mean_absolute_error: 17.5349 - mean_absolute_percentage_error: 15.1038 - mean_squared_logarithmic_error: 0.0391 - log_cosh: 16.8590 - val_loss: 15.4219 - val_huber_loss: 15.4216 - val_mean_squared_error: 472.1932 - val_mean_absolute_error: 15.9138 - val_mean_absolute_percentage_error: 14.2970 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2398
# Epoch 3/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.9278 - huber_loss: 16.9287 - mean_squared_error: 561.3798 - mean_absolute_error: 17.4216 - mean_absolute_percentage_error: 15.0015 - mean_squared_logarithmic_error: 0.0389 - log_cosh: 16.7461 - val_loss: 15.4052 - val_huber_loss: 15.4050 - val_mean_squared_error: 472.0849 - val_mean_absolute_error: 15.8971 - val_mean_absolute_percentage_error: 14.2575 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2232
# Epoch 4/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.8722 - huber_loss: 16.8731 - mean_squared_error: 559.0018 - mean_absolute_error: 17.3660 - mean_absolute_percentage_error: 14.9545 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6905 - val_loss: 15.3987 - val_huber_loss: 15.3985 - val_mean_squared_error: 471.9431 - val_mean_absolute_error: 15.8906 - val_mean_absolute_percentage_error: 14.2534 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2168
# Epoch 5/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.8349 - huber_loss: 16.8358 - mean_squared_error: 557.5663 - mean_absolute_error: 17.3286 - mean_absolute_percentage_error: 14.9201 - mean_squared_logarithmic_error: 0.0387 - log_cosh: 16.6533 - val_loss: 15.3907 - val_huber_loss: 15.3905 - val_mean_squared_error: 472.1234 - val_mean_absolute_error: 15.8826 - val_mean_absolute_percentage_error: 14.2362 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2088
# Epoch 6/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.8087 - huber_loss: 16.8096 - mean_squared_error: 556.5399 - mean_absolute_error: 17.3023 - mean_absolute_percentage_error: 14.8953 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.6272 - val_loss: 15.3834 - val_huber_loss: 15.3832 - val_mean_squared_error: 471.9611 - val_mean_absolute_error: 15.8752 - val_mean_absolute_percentage_error: 14.2242 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2014
# Epoch 7/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.7874 - huber_loss: 16.7884 - mean_squared_error: 555.7554 - mean_absolute_error: 17.2810 - mean_absolute_percentage_error: 14.8743 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.6059 - val_loss: 15.3767 - val_huber_loss: 15.3765 - val_mean_squared_error: 471.7383 - val_mean_absolute_error: 15.8684 - val_mean_absolute_percentage_error: 14.2162 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1947
# Epoch 8/15
# 2457/2457 [==============================] - 25s 10ms/step - loss: 16.7721 - huber_loss: 16.7730 - mean_squared_error: 555.2281 - mean_absolute_error: 17.2656 - mean_absolute_percentage_error: 14.8593 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.5906 - val_loss: 15.3713 - val_huber_loss: 15.3710 - val_mean_squared_error: 471.5321 - val_mean_absolute_error: 15.8630 - val_mean_absolute_percentage_error: 14.2097 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1893
# Epoch 9/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.7595 - huber_loss: 16.7604 - mean_squared_error: 554.8152 - mean_absolute_error: 17.2530 - mean_absolute_percentage_error: 14.8468 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.5780 - val_loss: 15.3658 - val_huber_loss: 15.3656 - val_mean_squared_error: 471.2973 - val_mean_absolute_error: 15.8576 - val_mean_absolute_percentage_error: 14.2037 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1838
# Epoch 10/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.7490 - huber_loss: 16.7499 - mean_squared_error: 554.4576 - mean_absolute_error: 17.2425 - mean_absolute_percentage_error: 14.8364 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 16.5676 - val_loss: 15.3626 - val_huber_loss: 15.3624 - val_mean_squared_error: 471.0016 - val_mean_absolute_error: 15.8547 - val_mean_absolute_percentage_error: 14.2026 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1805
# Epoch 11/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.7388 - huber_loss: 16.7397 - mean_squared_error: 554.0748 - mean_absolute_error: 17.2323 - mean_absolute_percentage_error: 14.8272 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5573 - val_loss: 15.3578 - val_huber_loss: 15.3576 - val_mean_squared_error: 470.8019 - val_mean_absolute_error: 15.8499 - val_mean_absolute_percentage_error: 14.1989 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1758
# Epoch 12/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.7298 - huber_loss: 16.7307 - mean_squared_error: 553.7267 - mean_absolute_error: 17.2233 - mean_absolute_percentage_error: 14.8191 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5484 - val_loss: 15.3543 - val_huber_loss: 15.3541 - val_mean_squared_error: 470.7919 - val_mean_absolute_error: 15.8462 - val_mean_absolute_percentage_error: 14.1913 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1722
# Epoch 13/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.7226 - huber_loss: 16.7235 - mean_squared_error: 553.4617 - mean_absolute_error: 17.2161 - mean_absolute_percentage_error: 14.8121 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5412 - val_loss: 15.3517 - val_huber_loss: 15.3515 - val_mean_squared_error: 470.8208 - val_mean_absolute_error: 15.8436 - val_mean_absolute_percentage_error: 14.1883 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1696
# Epoch 14/15
# 2457/2457 [==============================] - 23s 10ms/step - loss: 16.7151 - huber_loss: 16.7160 - mean_squared_error: 553.1932 - mean_absolute_error: 17.2086 - mean_absolute_percentage_error: 14.8048 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5337 - val_loss: 15.3470 - val_huber_loss: 15.3468 - val_mean_squared_error: 470.4574 - val_mean_absolute_error: 15.8389 - val_mean_absolute_percentage_error: 14.1866 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1649
# Epoch 15/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.7088 - huber_loss: 16.7097 - mean_squared_error: 552.9445 - mean_absolute_error: 17.2022 - mean_absolute_percentage_error: 14.7989 - mean_squared_logarithmic_error: 0.0385 - log_cosh: 16.5274 - val_loss: 15.3447 - val_huber_loss: 15.3445 - val_mean_squared_error: 470.2632 - val_mean_absolute_error: 15.8366 - val_mean_absolute_percentage_error: 14.1875 - val_mean_squared_logarithmic_error: 0.0355 - val_log_cosh: 15.1625
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2457/2457 [==============================] - 29s 10ms/step - loss: 22.4350 - huber_loss: 22.4338 - mean_squared_error: 979.2838 - mean_absolute_error: 22.9284 - mean_absolute_percentage_error: 19.7927 - mean_squared_logarithmic_error: 0.1027 - log_cosh: 22.2483 - val_loss: 16.6772 - val_huber_loss: 16.6778 - val_mean_squared_error: 554.4839 - val_mean_absolute_error: 17.1708 - val_mean_absolute_percentage_error: 14.8636 - val_mean_squared_logarithmic_error: 0.0401 - val_log_cosh: 16.4953
# Epoch 2/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 18.0331 - huber_loss: 18.0327 - mean_squared_error: 624.7101 - mean_absolute_error: 18.5263 - mean_absolute_percentage_error: 15.9238 - mean_squared_logarithmic_error: 0.0423 - log_cosh: 17.8490 - val_loss: 15.9115 - val_huber_loss: 15.9117 - val_mean_squared_error: 508.5161 - val_mean_absolute_error: 16.4035 - val_mean_absolute_percentage_error: 14.3859 - val_mean_squared_logarithmic_error: 0.0375 - val_log_cosh: 15.7302
# Epoch 3/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 17.4691 - huber_loss: 17.4691 - mean_squared_error: 592.5162 - mean_absolute_error: 17.9621 - mean_absolute_percentage_error: 15.4484 - mean_squared_logarithmic_error: 0.0406 - log_cosh: 17.2859 - val_loss: 15.7031 - val_huber_loss: 15.7032 - val_mean_squared_error: 495.5821 - val_mean_absolute_error: 16.1945 - val_mean_absolute_percentage_error: 14.2752 - val_mean_squared_logarithmic_error: 0.0368 - val_log_cosh: 15.5220
# Epoch 4/15
# 2457/2457 [==============================] - 25s 10ms/step - loss: 17.2628 - huber_loss: 17.2630 - mean_squared_error: 581.1552 - mean_absolute_error: 17.7560 - mean_absolute_percentage_error: 15.2781 - mean_squared_logarithmic_error: 0.0400 - log_cosh: 17.0800 - val_loss: 15.5633 - val_huber_loss: 15.5634 - val_mean_squared_error: 484.7135 - val_mean_absolute_error: 16.0560 - val_mean_absolute_percentage_error: 14.2728 - val_mean_squared_logarithmic_error: 0.0362 - val_log_cosh: 15.3820
# Epoch 5/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 17.1341 - huber_loss: 17.1345 - mean_squared_error: 574.3732 - mean_absolute_error: 17.6274 - mean_absolute_percentage_error: 15.1661 - mean_squared_logarithmic_error: 0.0396 - log_cosh: 16.9517 - val_loss: 15.5029 - val_huber_loss: 15.5029 - val_mean_squared_error: 480.3055 - val_mean_absolute_error: 15.9948 - val_mean_absolute_percentage_error: 14.2570 - val_mean_squared_logarithmic_error: 0.0360 - val_log_cosh: 15.3216
# Epoch 6/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 17.0437 - huber_loss: 17.0442 - mean_squared_error: 569.4087 - mean_absolute_error: 17.5371 - mean_absolute_percentage_error: 15.0902 - mean_squared_logarithmic_error: 0.0394 - log_cosh: 16.8615 - val_loss: 15.4467 - val_huber_loss: 15.4466 - val_mean_squared_error: 477.6015 - val_mean_absolute_error: 15.9386 - val_mean_absolute_percentage_error: 14.2175 - val_mean_squared_logarithmic_error: 0.0358 - val_log_cosh: 15.2655
# Epoch 7/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.9689 - huber_loss: 16.9695 - mean_squared_error: 565.3895 - mean_absolute_error: 17.4624 - mean_absolute_percentage_error: 15.0254 - mean_squared_logarithmic_error: 0.0391 - log_cosh: 16.7867 - val_loss: 15.4181 - val_huber_loss: 15.4180 - val_mean_squared_error: 475.2433 - val_mean_absolute_error: 15.9094 - val_mean_absolute_percentage_error: 14.2015 - val_mean_squared_logarithmic_error: 0.0357 - val_log_cosh: 15.2368
# Epoch 8/15
# 2457/2457 [==============================] - 25s 10ms/step - loss: 16.9194 - huber_loss: 16.9201 - mean_squared_error: 562.7271 - mean_absolute_error: 17.4129 - mean_absolute_percentage_error: 14.9854 - mean_squared_logarithmic_error: 0.0390 - log_cosh: 16.7373 - val_loss: 15.4043 - val_huber_loss: 15.4042 - val_mean_squared_error: 474.6546 - val_mean_absolute_error: 15.8952 - val_mean_absolute_percentage_error: 14.1880 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2229
# Epoch 9/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.8849 - huber_loss: 16.8857 - mean_squared_error: 560.9963 - mean_absolute_error: 17.3786 - mean_absolute_percentage_error: 14.9559 - mean_squared_logarithmic_error: 0.0389 - log_cosh: 16.7031 - val_loss: 15.3957 - val_huber_loss: 15.3955 - val_mean_squared_error: 474.3605 - val_mean_absolute_error: 15.8865 - val_mean_absolute_percentage_error: 14.1800 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2143
# Epoch 10/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.8609 - huber_loss: 16.8617 - mean_squared_error: 559.9091 - mean_absolute_error: 17.3545 - mean_absolute_percentage_error: 14.9358 - mean_squared_logarithmic_error: 0.0389 - log_cosh: 16.6791 - val_loss: 15.3904 - val_huber_loss: 15.3902 - val_mean_squared_error: 474.5165 - val_mean_absolute_error: 15.8816 - val_mean_absolute_percentage_error: 14.1667 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.2089
# Epoch 11/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.8423 - huber_loss: 16.8432 - mean_squared_error: 559.0325 - mean_absolute_error: 17.3360 - mean_absolute_percentage_error: 14.9206 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6605 - val_loss: 15.3898 - val_huber_loss: 15.3896 - val_mean_squared_error: 475.3219 - val_mean_absolute_error: 15.8812 - val_mean_absolute_percentage_error: 14.1437 - val_mean_squared_logarithmic_error: 0.0357 - val_log_cosh: 15.2083
# Epoch 12/15
# 2457/2457 [==============================] - 22s 9ms/step - loss: 16.8266 - huber_loss: 16.8274 - mean_squared_error: 558.3014 - mean_absolute_error: 17.3203 - mean_absolute_percentage_error: 14.9080 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6449 - val_loss: 15.3857 - val_huber_loss: 15.3855 - val_mean_squared_error: 475.4005 - val_mean_absolute_error: 15.8773 - val_mean_absolute_percentage_error: 14.1320 - val_mean_squared_logarithmic_error: 0.0357 - val_log_cosh: 15.2042
# Epoch 13/15
# 2457/2457 [==============================] - 24s 10ms/step - loss: 16.8138 - huber_loss: 16.8147 - mean_squared_error: 557.7414 - mean_absolute_error: 17.3075 - mean_absolute_percentage_error: 14.8968 - mean_squared_logarithmic_error: 0.0388 - log_cosh: 16.6321 - val_loss: 15.3798 - val_huber_loss: 15.3796 - val_mean_squared_error: 474.8732 - val_mean_absolute_error: 15.8717 - val_mean_absolute_percentage_error: 14.1306 - val_mean_squared_logarithmic_error: 0.0357 - val_log_cosh: 15.1981
# Epoch 14/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.8028 - huber_loss: 16.8037 - mean_squared_error: 557.2558 - mean_absolute_error: 17.2963 - mean_absolute_percentage_error: 14.8872 - mean_squared_logarithmic_error: 0.0387 - log_cosh: 16.6212 - val_loss: 15.3757 - val_huber_loss: 15.3755 - val_mean_squared_error: 474.4269 - val_mean_absolute_error: 15.8675 - val_mean_absolute_percentage_error: 14.1319 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1939
# Epoch 15/15
# 2457/2457 [==============================] - 23s 9ms/step - loss: 16.7933 - huber_loss: 16.7942 - mean_squared_error: 556.8518 - mean_absolute_error: 17.2870 - mean_absolute_percentage_error: 14.8784 - mean_squared_logarithmic_error: 0.0387 - log_cosh: 16.6117 - val_loss: 15.3722 - val_huber_loss: 15.3720 - val_mean_squared_error: 474.2227 - val_mean_absolute_error: 15.8641 - val_mean_absolute_percentage_error: 14.1289 - val_mean_squared_logarithmic_error: 0.0356 - val_log_cosh: 15.1903
# 683/683 [==============================] - 3s 5ms/step - loss: 14.4841 - huber_loss: 14.4811 - mean_squared_error: 417.1170 - mean_absolute_error: 14.9730 - mean_absolute_percentage_error: 12.9581 - mean_squared_logarithmic_error: 0.0296 - log_cosh: 14.2999
# 683/683 [==============================] - 4s 6ms/step - loss: 14.5724 - huber_loss: 14.5696 - mean_squared_error: 422.4170 - mean_absolute_error: 15.0608 - mean_absolute_percentage_error: 12.9686 - mean_squared_logarithmic_error: 0.0299 - log_cosh: 14.3888
# 683/683 [==============================] - 3s 3ms/step
# 683/683 [==============================] - 3s 3ms/step
# -------------------------------------------------------
#
# 1-LIB193307
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2264/2264 [==============================] - 29s 11ms/step - loss: 23.4690 - huber_loss: 23.4678 - mean_squared_error: 1081.3401 - mean_absolute_error: 23.9627 - mean_absolute_percentage_error: 16.8456 - mean_squared_logarithmic_error: 0.0530 - log_cosh: 23.2822 - val_loss: 21.5131 - val_huber_loss: 21.5404 - val_mean_squared_error: 873.9257 - val_mean_absolute_error: 22.0347 - val_mean_absolute_percentage_error: 15.3871 - val_mean_squared_logarithmic_error: 0.0397 - val_log_cosh: 21.3550
# Epoch 2/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.6117 - huber_loss: 21.6106 - mean_squared_error: 901.0036 - mean_absolute_error: 22.1051 - mean_absolute_percentage_error: 15.5539 - mean_squared_logarithmic_error: 0.0428 - log_cosh: 21.4257 - val_loss: 21.2655 - val_huber_loss: 21.2894 - val_mean_squared_error: 860.2501 - val_mean_absolute_error: 21.7833 - val_mean_absolute_percentage_error: 14.9876 - val_mean_squared_logarithmic_error: 0.0393 - val_log_cosh: 21.1048
# Epoch 3/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.3381 - huber_loss: 21.3371 - mean_squared_error: 881.0217 - mean_absolute_error: 21.8316 - mean_absolute_percentage_error: 15.3409 - mean_squared_logarithmic_error: 0.0419 - log_cosh: 21.1521 - val_loss: 21.1964 - val_huber_loss: 21.2219 - val_mean_squared_error: 853.7749 - val_mean_absolute_error: 21.7167 - val_mean_absolute_percentage_error: 14.9080 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 21.0371
# Epoch 4/15
# 2264/2264 [==============================] - 22s 9ms/step - loss: 21.2031 - huber_loss: 21.2020 - mean_squared_error: 871.5631 - mean_absolute_error: 21.6963 - mean_absolute_percentage_error: 15.2433 - mean_squared_logarithmic_error: 0.0416 - log_cosh: 21.0172 - val_loss: 21.1527 - val_huber_loss: 21.1735 - val_mean_squared_error: 850.1290 - val_mean_absolute_error: 21.6679 - val_mean_absolute_percentage_error: 14.8649 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9890
# Epoch 5/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.1226 - huber_loss: 21.1215 - mean_squared_error: 865.9349 - mean_absolute_error: 21.6159 - mean_absolute_percentage_error: 15.1842 - mean_squared_logarithmic_error: 0.0413 - log_cosh: 20.9366 - val_loss: 21.1100 - val_huber_loss: 21.1266 - val_mean_squared_error: 847.1584 - val_mean_absolute_error: 21.6211 - val_mean_absolute_percentage_error: 14.8291 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9423
# Epoch 6/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 21.0662 - huber_loss: 21.0652 - mean_squared_error: 862.2489 - mean_absolute_error: 21.5595 - mean_absolute_percentage_error: 15.1425 - mean_squared_logarithmic_error: 0.0412 - log_cosh: 20.8803 - val_loss: 21.1022 - val_huber_loss: 21.1185 - val_mean_squared_error: 847.6863 - val_mean_absolute_error: 21.6129 - val_mean_absolute_percentage_error: 14.7794 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9341
# Epoch 7/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.0240 - huber_loss: 21.0229 - mean_squared_error: 859.5205 - mean_absolute_error: 21.5171 - mean_absolute_percentage_error: 15.1152 - mean_squared_logarithmic_error: 0.0411 - log_cosh: 20.8382 - val_loss: 21.0808 - val_huber_loss: 21.0946 - val_mean_squared_error: 845.2025 - val_mean_absolute_error: 21.5890 - val_mean_absolute_percentage_error: 14.7675 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.9101
# Epoch 8/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 20.9890 - huber_loss: 20.9879 - mean_squared_error: 857.2119 - mean_absolute_error: 21.4820 - mean_absolute_percentage_error: 15.0941 - mean_squared_logarithmic_error: 0.0410 - log_cosh: 20.8032 - val_loss: 21.0706 - val_huber_loss: 21.0819 - val_mean_squared_error: 844.9240 - val_mean_absolute_error: 21.5760 - val_mean_absolute_percentage_error: 14.7380 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8975
# Epoch 9/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 20.9606 - huber_loss: 20.9595 - mean_squared_error: 855.1843 - mean_absolute_error: 21.4537 - mean_absolute_percentage_error: 15.0758 - mean_squared_logarithmic_error: 0.0409 - log_cosh: 20.7749 - val_loss: 21.0584 - val_huber_loss: 21.0671 - val_mean_squared_error: 844.4445 - val_mean_absolute_error: 21.5613 - val_mean_absolute_percentage_error: 14.7102 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8827
# Epoch 10/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 20.9369 - huber_loss: 20.9358 - mean_squared_error: 853.5571 - mean_absolute_error: 21.4300 - mean_absolute_percentage_error: 15.0608 - mean_squared_logarithmic_error: 0.0409 - log_cosh: 20.7512 - val_loss: 21.0529 - val_huber_loss: 21.0608 - val_mean_squared_error: 844.0065 - val_mean_absolute_error: 21.5555 - val_mean_absolute_percentage_error: 14.6987 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8763
# Epoch 11/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 20.9162 - huber_loss: 20.9151 - mean_squared_error: 852.1972 - mean_absolute_error: 21.4094 - mean_absolute_percentage_error: 15.0463 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 20.7305 - val_loss: 21.0407 - val_huber_loss: 21.0469 - val_mean_squared_error: 843.1714 - val_mean_absolute_error: 21.5415 - val_mean_absolute_percentage_error: 14.6838 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8624
# Epoch 12/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 20.8992 - huber_loss: 20.8980 - mean_squared_error: 851.1797 - mean_absolute_error: 21.3922 - mean_absolute_percentage_error: 15.0337 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 20.7134 - val_loss: 21.0316 - val_huber_loss: 21.0368 - val_mean_squared_error: 842.9315 - val_mean_absolute_error: 21.5311 - val_mean_absolute_percentage_error: 14.6658 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8522
# Epoch 13/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 20.8846 - huber_loss: 20.8835 - mean_squared_error: 850.2807 - mean_absolute_error: 21.3778 - mean_absolute_percentage_error: 15.0230 - mean_squared_logarithmic_error: 0.0407 - log_cosh: 20.6989 - val_loss: 21.0302 - val_huber_loss: 21.0353 - val_mean_squared_error: 843.2942 - val_mean_absolute_error: 21.5297 - val_mean_absolute_percentage_error: 14.6472 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8508
# Epoch 14/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 20.8710 - huber_loss: 20.8699 - mean_squared_error: 849.4460 - mean_absolute_error: 21.3641 - mean_absolute_percentage_error: 15.0130 - mean_squared_logarithmic_error: 0.0407 - log_cosh: 20.6853 - val_loss: 21.0231 - val_huber_loss: 21.0277 - val_mean_squared_error: 843.1422 - val_mean_absolute_error: 21.5222 - val_mean_absolute_percentage_error: 14.6316 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8432
# Epoch 15/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 20.8593 - huber_loss: 20.8582 - mean_squared_error: 848.7109 - mean_absolute_error: 21.3525 - mean_absolute_percentage_error: 15.0042 - mean_squared_logarithmic_error: 0.0407 - log_cosh: 20.6737 - val_loss: 21.0244 - val_huber_loss: 21.0284 - val_mean_squared_error: 843.5919 - val_mean_absolute_error: 21.5227 - val_mean_absolute_percentage_error: 14.6172 - val_mean_squared_logarithmic_error: 0.0390 - val_log_cosh: 20.8440
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2264/2264 [==============================] - 28s 10ms/step - loss: 30.8123 - huber_loss: 30.8099 - mean_squared_error: 1933.0698 - mean_absolute_error: 31.3057 - mean_absolute_percentage_error: 21.9503 - mean_squared_logarithmic_error: 0.1271 - log_cosh: 30.6230 - val_loss: 23.3246 - val_huber_loss: 23.3678 - val_mean_squared_error: 1009.2542 - val_mean_absolute_error: 23.8628 - val_mean_absolute_percentage_error: 17.1432 - val_mean_squared_logarithmic_error: 0.0450 - val_log_cosh: 23.1819
# Epoch 2/15
# 2264/2264 [==============================] - 24s 11ms/step - loss: 22.7303 - huber_loss: 22.7292 - mean_squared_error: 998.5031 - mean_absolute_error: 23.2240 - mean_absolute_percentage_error: 16.2264 - mean_squared_logarithmic_error: 0.0456 - log_cosh: 22.5437 - val_loss: 21.6865 - val_huber_loss: 21.7328 - val_mean_squared_error: 901.3004 - val_mean_absolute_error: 22.2278 - val_mean_absolute_percentage_error: 15.2274 - val_mean_squared_logarithmic_error: 0.0401 - val_log_cosh: 21.5477
# Epoch 3/15
# 2264/2264 [==============================] - 21s 9ms/step - loss: 21.8816 - huber_loss: 21.8806 - mean_squared_error: 924.1547 - mean_absolute_error: 22.3752 - mean_absolute_percentage_error: 15.6792 - mean_squared_logarithmic_error: 0.0432 - log_cosh: 21.6956 - val_loss: 21.3282 - val_huber_loss: 21.3662 - val_mean_squared_error: 867.4851 - val_mean_absolute_error: 21.8606 - val_mean_absolute_percentage_error: 15.0385 - val_mean_squared_logarithmic_error: 0.0395 - val_log_cosh: 21.1812
# Epoch 4/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.5700 - huber_loss: 21.5691 - mean_squared_error: 898.7205 - mean_absolute_error: 22.0635 - mean_absolute_percentage_error: 15.4852 - mean_squared_logarithmic_error: 0.0424 - log_cosh: 21.3840 - val_loss: 21.3391 - val_huber_loss: 21.3772 - val_mean_squared_error: 871.8825 - val_mean_absolute_error: 21.8704 - val_mean_absolute_percentage_error: 14.9205 - val_mean_squared_logarithmic_error: 0.0397 - val_log_cosh: 21.1933
# Epoch 5/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 21.4268 - huber_loss: 21.4259 - mean_squared_error: 887.3076 - mean_absolute_error: 21.9204 - mean_absolute_percentage_error: 15.3887 - mean_squared_logarithmic_error: 0.0420 - log_cosh: 21.2408 - val_loss: 21.1995 - val_huber_loss: 21.2324 - val_mean_squared_error: 856.2166 - val_mean_absolute_error: 21.7263 - val_mean_absolute_percentage_error: 14.8672 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 21.0477
# Epoch 6/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.2741 - huber_loss: 21.2731 - mean_squared_error: 876.5303 - mean_absolute_error: 21.7674 - mean_absolute_percentage_error: 15.2864 - mean_squared_logarithmic_error: 0.0416 - log_cosh: 21.0882 - val_loss: 21.1214 - val_huber_loss: 21.1514 - val_mean_squared_error: 847.9211 - val_mean_absolute_error: 21.6461 - val_mean_absolute_percentage_error: 14.8670 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9666
# Epoch 7/15
# 2264/2264 [==============================] - 24s 10ms/step - loss: 21.1854 - huber_loss: 21.1844 - mean_squared_error: 869.4716 - mean_absolute_error: 21.6789 - mean_absolute_percentage_error: 15.2304 - mean_squared_logarithmic_error: 0.0414 - log_cosh: 20.9995 - val_loss: 21.2143 - val_huber_loss: 21.2498 - val_mean_squared_error: 856.4685 - val_mean_absolute_error: 21.7447 - val_mean_absolute_percentage_error: 14.7810 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 21.0650
# Epoch 8/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.1258 - huber_loss: 21.1248 - mean_squared_error: 865.0236 - mean_absolute_error: 21.6195 - mean_absolute_percentage_error: 15.1873 - mean_squared_logarithmic_error: 0.0412 - log_cosh: 20.9399 - val_loss: 21.1836 - val_huber_loss: 21.2174 - val_mean_squared_error: 854.9353 - val_mean_absolute_error: 21.7116 - val_mean_absolute_percentage_error: 14.7393 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 21.0326
# Epoch 9/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 21.0770 - huber_loss: 21.0760 - mean_squared_error: 861.6303 - mean_absolute_error: 21.5704 - mean_absolute_percentage_error: 15.1527 - mean_squared_logarithmic_error: 0.0411 - log_cosh: 20.8912 - val_loss: 21.1441 - val_huber_loss: 21.1751 - val_mean_squared_error: 852.4449 - val_mean_absolute_error: 21.6695 - val_mean_absolute_percentage_error: 14.7122 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9902
# Epoch 10/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.0395 - huber_loss: 21.0385 - mean_squared_error: 858.7270 - mean_absolute_error: 21.5328 - mean_absolute_percentage_error: 15.1275 - mean_squared_logarithmic_error: 0.0410 - log_cosh: 20.8537 - val_loss: 21.1286 - val_huber_loss: 21.1579 - val_mean_squared_error: 851.2588 - val_mean_absolute_error: 21.6522 - val_mean_absolute_percentage_error: 14.6964 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9728
# Epoch 11/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 21.0106 - huber_loss: 21.0096 - mean_squared_error: 856.6525 - mean_absolute_error: 21.5039 - mean_absolute_percentage_error: 15.1076 - mean_squared_logarithmic_error: 0.0410 - log_cosh: 20.8248 - val_loss: 21.0948 - val_huber_loss: 21.1205 - val_mean_squared_error: 848.8546 - val_mean_absolute_error: 21.6152 - val_mean_absolute_percentage_error: 14.6842 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9356
# Epoch 12/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 20.9864 - huber_loss: 20.9853 - mean_squared_error: 855.0125 - mean_absolute_error: 21.4796 - mean_absolute_percentage_error: 15.0923 - mean_squared_logarithmic_error: 0.0409 - log_cosh: 20.8006 - val_loss: 21.1018 - val_huber_loss: 21.1259 - val_mean_squared_error: 849.5214 - val_mean_absolute_error: 21.6205 - val_mean_absolute_percentage_error: 14.6749 - val_mean_squared_logarithmic_error: 0.0391 - val_log_cosh: 20.9409
# Epoch 13/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 20.9643 - huber_loss: 20.9632 - mean_squared_error: 853.5580 - mean_absolute_error: 21.4575 - mean_absolute_percentage_error: 15.0767 - mean_squared_logarithmic_error: 0.0409 - log_cosh: 20.7785 - val_loss: 21.1072 - val_huber_loss: 21.1303 - val_mean_squared_error: 850.0984 - val_mean_absolute_error: 21.6250 - val_mean_absolute_percentage_error: 14.6621 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9452
# Epoch 14/15
# 2264/2264 [==============================] - 22s 10ms/step - loss: 20.9451 - huber_loss: 20.9440 - mean_squared_error: 852.3933 - mean_absolute_error: 21.4384 - mean_absolute_percentage_error: 15.0633 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 20.7593 - val_loss: 21.1042 - val_huber_loss: 21.1264 - val_mean_squared_error: 850.2112 - val_mean_absolute_error: 21.6211 - val_mean_absolute_percentage_error: 14.6529 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9413
# Epoch 15/15
# 2264/2264 [==============================] - 23s 10ms/step - loss: 20.9282 - huber_loss: 20.9271 - mean_squared_error: 851.3035 - mean_absolute_error: 21.4216 - mean_absolute_percentage_error: 15.0517 - mean_squared_logarithmic_error: 0.0408 - log_cosh: 20.7423 - val_loss: 21.1041 - val_huber_loss: 21.1257 - val_mean_squared_error: 850.4203 - val_mean_absolute_error: 21.6206 - val_mean_absolute_percentage_error: 14.6448 - val_mean_squared_logarithmic_error: 0.0392 - val_log_cosh: 20.9407
# 629/629 [==============================] - 3s 5ms/step - loss: 21.3137 - huber_loss: 21.3129 - mean_squared_error: 859.1068 - mean_absolute_error: 21.8073 - mean_absolute_percentage_error: 14.5738 - mean_squared_logarithmic_error: 0.0392 - log_cosh: 21.1282
# 629/629 [==============================] - 3s 5ms/step - loss: 21.3567 - huber_loss: 21.3562 - mean_squared_error: 860.4905 - mean_absolute_error: 21.8507 - mean_absolute_percentage_error: 14.5661 - mean_squared_logarithmic_error: 0.0390 - log_cosh: 21.1715
# 629/629 [==============================] - 4s 4ms/step
# 629/629 [==============================] - 3s 3ms/step
# -------------------------------------------------------
#
# 2-LIB193385
#
# PRETRAINED_MODEL
# Epoch 1/15
# 2043/2043 [==============================] - 27s 11ms/step - loss: 16.0880 - huber_loss: 16.0875 - mean_squared_error: 545.3752 - mean_absolute_error: 16.5793 - mean_absolute_percentage_error: 13.6845 - mean_squared_logarithmic_error: 0.0346 - log_cosh: 15.9063 - val_loss: 15.3426 - val_huber_loss: 15.3436 - val_mean_squared_error: 435.3130 - val_mean_absolute_error: 15.8361 - val_mean_absolute_percentage_error: 13.5765 - val_mean_squared_logarithmic_error: 0.0288 - val_log_cosh: 15.1611
# Epoch 2/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.2139 - huber_loss: 15.2136 - mean_squared_error: 501.3636 - mean_absolute_error: 15.7049 - mean_absolute_percentage_error: 12.8717 - mean_squared_logarithmic_error: 0.0317 - log_cosh: 15.0334 - val_loss: 15.1097 - val_huber_loss: 15.1108 - val_mean_squared_error: 430.6045 - val_mean_absolute_error: 15.6031 - val_mean_absolute_percentage_error: 13.2268 - val_mean_squared_logarithmic_error: 0.0282 - val_log_cosh: 14.9291
# Epoch 3/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.1108 - huber_loss: 15.1105 - mean_squared_error: 497.5054 - mean_absolute_error: 15.6014 - mean_absolute_percentage_error: 12.7843 - mean_squared_logarithmic_error: 0.0315 - log_cosh: 14.9307 - val_loss: 14.9917 - val_huber_loss: 14.9929 - val_mean_squared_error: 428.0419 - val_mean_absolute_error: 15.4853 - val_mean_absolute_percentage_error: 13.0683 - val_mean_squared_logarithmic_error: 0.0279 - val_log_cosh: 14.8111
# Epoch 4/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.0618 - huber_loss: 15.0616 - mean_squared_error: 495.4149 - mean_absolute_error: 15.5523 - mean_absolute_percentage_error: 12.7445 - mean_squared_logarithmic_error: 0.0314 - log_cosh: 14.8819 - val_loss: 14.9321 - val_huber_loss: 14.9334 - val_mean_squared_error: 427.5225 - val_mean_absolute_error: 15.4256 - val_mean_absolute_percentage_error: 12.9854 - val_mean_squared_logarithmic_error: 0.0278 - val_log_cosh: 14.7518
# Epoch 5/15
# 2043/2043 [==============================] - 23s 11ms/step - loss: 15.0312 - huber_loss: 15.0310 - mean_squared_error: 494.5311 - mean_absolute_error: 15.5219 - mean_absolute_percentage_error: 12.7182 - mean_squared_logarithmic_error: 0.0314 - log_cosh: 14.8515 - val_loss: 14.8866 - val_huber_loss: 14.8879 - val_mean_squared_error: 427.1505 - val_mean_absolute_error: 15.3797 - val_mean_absolute_percentage_error: 12.9180 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.7065
# Epoch 6/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.0088 - huber_loss: 15.0087 - mean_squared_error: 493.4742 - mean_absolute_error: 15.4997 - mean_absolute_percentage_error: 12.6978 - mean_squared_logarithmic_error: 0.0313 - log_cosh: 14.8290 - val_loss: 14.8476 - val_huber_loss: 14.8489 - val_mean_squared_error: 426.5743 - val_mean_absolute_error: 15.3405 - val_mean_absolute_percentage_error: 12.8514 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6675
# Epoch 7/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 14.9905 - huber_loss: 14.9903 - mean_squared_error: 492.5311 - mean_absolute_error: 15.4814 - mean_absolute_percentage_error: 12.6830 - mean_squared_logarithmic_error: 0.0313 - log_cosh: 14.8107 - val_loss: 14.8188 - val_huber_loss: 14.8201 - val_mean_squared_error: 426.4438 - val_mean_absolute_error: 15.3114 - val_mean_absolute_percentage_error: 12.8070 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.6388
# Epoch 8/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 14.9785 - huber_loss: 14.9783 - mean_squared_error: 492.1972 - mean_absolute_error: 15.4691 - mean_absolute_percentage_error: 12.6740 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7987 - val_loss: 14.7966 - val_huber_loss: 14.7979 - val_mean_squared_error: 426.4381 - val_mean_absolute_error: 15.2892 - val_mean_absolute_percentage_error: 12.7738 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.6167
# Epoch 9/15
# 2043/2043 [==============================] - 19s 10ms/step - loss: 14.9690 - huber_loss: 14.9688 - mean_squared_error: 491.9943 - mean_absolute_error: 15.4595 - mean_absolute_percentage_error: 12.6658 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7892 - val_loss: 14.7776 - val_huber_loss: 14.7789 - val_mean_squared_error: 426.1958 - val_mean_absolute_error: 15.2702 - val_mean_absolute_percentage_error: 12.7525 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5979
# Epoch 10/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 14.9614 - huber_loss: 14.9612 - mean_squared_error: 491.6755 - mean_absolute_error: 15.4519 - mean_absolute_percentage_error: 12.6606 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7818 - val_loss: 14.7726 - val_huber_loss: 14.7739 - val_mean_squared_error: 425.7178 - val_mean_absolute_error: 15.2652 - val_mean_absolute_percentage_error: 12.7539 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5927
# Epoch 11/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 14.9517 - huber_loss: 14.9515 - mean_squared_error: 491.1901 - mean_absolute_error: 15.4421 - mean_absolute_percentage_error: 12.6509 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7721 - val_loss: 14.7655 - val_huber_loss: 14.7669 - val_mean_squared_error: 425.7523 - val_mean_absolute_error: 15.2582 - val_mean_absolute_percentage_error: 12.7417 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5857
# Epoch 12/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 14.9440 - huber_loss: 14.9439 - mean_squared_error: 490.9588 - mean_absolute_error: 15.4345 - mean_absolute_percentage_error: 12.6440 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7644 - val_loss: 14.7501 - val_huber_loss: 14.7515 - val_mean_squared_error: 425.4488 - val_mean_absolute_error: 15.2435 - val_mean_absolute_percentage_error: 12.7298 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5705
# Epoch 13/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 14.9349 - huber_loss: 14.9347 - mean_squared_error: 490.4297 - mean_absolute_error: 15.4252 - mean_absolute_percentage_error: 12.6382 - mean_squared_logarithmic_error: 0.0312 - log_cosh: 14.7553 - val_loss: 14.7262 - val_huber_loss: 14.7275 - val_mean_squared_error: 425.4661 - val_mean_absolute_error: 15.2194 - val_mean_absolute_percentage_error: 12.6912 - val_mean_squared_logarithmic_error: 0.0275 - val_log_cosh: 14.5466
# Epoch 14/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 14.9256 - huber_loss: 14.9254 - mean_squared_error: 489.9103 - mean_absolute_error: 15.4159 - mean_absolute_percentage_error: 12.6314 - mean_squared_logarithmic_error: 0.0311 - log_cosh: 14.7460 - val_loss: 14.7174 - val_huber_loss: 14.7187 - val_mean_squared_error: 425.6245 - val_mean_absolute_error: 15.2101 - val_mean_absolute_percentage_error: 12.6781 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5377
# Epoch 15/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 14.9155 - huber_loss: 14.9154 - mean_squared_error: 489.3442 - mean_absolute_error: 15.4058 - mean_absolute_percentage_error: 12.6242 - mean_squared_logarithmic_error: 0.0311 - log_cosh: 14.7360 - val_loss: 14.7127 - val_huber_loss: 14.7141 - val_mean_squared_error: 425.6249 - val_mean_absolute_error: 15.2057 - val_mean_absolute_percentage_error: 12.6714 - val_mean_squared_logarithmic_error: 0.0275 - val_log_cosh: 14.5330
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 2043/2043 [==============================] - 25s 10ms/step - loss: 20.4785 - huber_loss: 20.4772 - mean_squared_error: 850.6169 - mean_absolute_error: 20.9713 - mean_absolute_percentage_error: 17.4787 - mean_squared_logarithmic_error: 0.1212 - log_cosh: 20.2928 - val_loss: 17.1901 - val_huber_loss: 17.1909 - val_mean_squared_error: 524.9668 - val_mean_absolute_error: 17.6849 - val_mean_absolute_percentage_error: 15.0921 - val_mean_squared_logarithmic_error: 0.0341 - val_log_cosh: 17.0072
# Epoch 2/15
# 2043/2043 [==============================] - 22s 11ms/step - loss: 16.4489 - huber_loss: 16.4483 - mean_squared_error: 569.2102 - mean_absolute_error: 16.9403 - mean_absolute_percentage_error: 13.8421 - mean_squared_logarithmic_error: 0.0355 - log_cosh: 16.2667 - val_loss: 15.8843 - val_huber_loss: 15.8854 - val_mean_squared_error: 463.2607 - val_mean_absolute_error: 16.3786 - val_mean_absolute_percentage_error: 14.0101 - val_mean_squared_logarithmic_error: 0.0304 - val_log_cosh: 15.7025
# Epoch 3/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.7336 - huber_loss: 15.7331 - mean_squared_error: 534.8848 - mean_absolute_error: 16.2249 - mean_absolute_percentage_error: 13.2411 - mean_squared_logarithmic_error: 0.0335 - log_cosh: 15.5525 - val_loss: 15.3480 - val_huber_loss: 15.3493 - val_mean_squared_error: 445.3975 - val_mean_absolute_error: 15.8415 - val_mean_absolute_percentage_error: 13.3821 - val_mean_squared_logarithmic_error: 0.0289 - val_log_cosh: 15.1671
# Epoch 4/15
# 2043/2043 [==============================] - 22s 11ms/step - loss: 15.4451 - huber_loss: 15.4448 - mean_squared_error: 518.8918 - mean_absolute_error: 15.9359 - mean_absolute_percentage_error: 13.0206 - mean_squared_logarithmic_error: 0.0326 - log_cosh: 15.2646 - val_loss: 15.1403 - val_huber_loss: 15.1415 - val_mean_squared_error: 437.5417 - val_mean_absolute_error: 15.6338 - val_mean_absolute_percentage_error: 13.1828 - val_mean_squared_logarithmic_error: 0.0284 - val_log_cosh: 14.9597
# Epoch 5/15
# 2043/2043 [==============================] - 22s 11ms/step - loss: 15.3131 - huber_loss: 15.3128 - mean_squared_error: 512.2366 - mean_absolute_error: 15.8039 - mean_absolute_percentage_error: 12.9171 - mean_squared_logarithmic_error: 0.0322 - log_cosh: 15.1327 - val_loss: 15.0306 - val_huber_loss: 15.0319 - val_mean_squared_error: 433.6487 - val_mean_absolute_error: 15.5244 - val_mean_absolute_percentage_error: 13.0841 - val_mean_squared_logarithmic_error: 0.0282 - val_log_cosh: 14.8503
# Epoch 6/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.2479 - huber_loss: 15.2476 - mean_squared_error: 508.9779 - mean_absolute_error: 15.7384 - mean_absolute_percentage_error: 12.8669 - mean_squared_logarithmic_error: 0.0320 - log_cosh: 15.0677 - val_loss: 14.9675 - val_huber_loss: 14.9687 - val_mean_squared_error: 431.1902 - val_mean_absolute_error: 15.4609 - val_mean_absolute_percentage_error: 13.0399 - val_mean_squared_logarithmic_error: 0.0281 - val_log_cosh: 14.7871
# Epoch 7/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.2000 - huber_loss: 15.1998 - mean_squared_error: 506.3812 - mean_absolute_error: 15.6906 - mean_absolute_percentage_error: 12.8320 - mean_squared_logarithmic_error: 0.0319 - log_cosh: 15.0201 - val_loss: 14.9055 - val_huber_loss: 14.9067 - val_mean_squared_error: 428.7803 - val_mean_absolute_error: 15.3984 - val_mean_absolute_percentage_error: 12.9702 - val_mean_squared_logarithmic_error: 0.0279 - val_log_cosh: 14.7248
# Epoch 8/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.1625 - huber_loss: 15.1623 - mean_squared_error: 503.9947 - mean_absolute_error: 15.6531 - mean_absolute_percentage_error: 12.8012 - mean_squared_logarithmic_error: 0.0318 - log_cosh: 14.9827 - val_loss: 14.8687 - val_huber_loss: 14.8699 - val_mean_squared_error: 427.4344 - val_mean_absolute_error: 15.3619 - val_mean_absolute_percentage_error: 12.9404 - val_mean_squared_logarithmic_error: 0.0279 - val_log_cosh: 14.6885
# Epoch 9/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.1260 - huber_loss: 15.1257 - mean_squared_error: 501.9042 - mean_absolute_error: 15.6165 - mean_absolute_percentage_error: 12.7794 - mean_squared_logarithmic_error: 0.0317 - log_cosh: 14.9462 - val_loss: 14.8460 - val_huber_loss: 14.8472 - val_mean_squared_error: 426.7464 - val_mean_absolute_error: 15.3392 - val_mean_absolute_percentage_error: 12.9084 - val_mean_squared_logarithmic_error: 0.0278 - val_log_cosh: 14.6659
# Epoch 10/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.1056 - huber_loss: 15.1053 - mean_squared_error: 500.8907 - mean_absolute_error: 15.5958 - mean_absolute_percentage_error: 12.7665 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.9259 - val_loss: 14.8211 - val_huber_loss: 14.8223 - val_mean_squared_error: 426.4545 - val_mean_absolute_error: 15.3141 - val_mean_absolute_percentage_error: 12.8686 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6411
# Epoch 11/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.0921 - huber_loss: 15.0919 - mean_squared_error: 500.2541 - mean_absolute_error: 15.5824 - mean_absolute_percentage_error: 12.7572 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.9125 - val_loss: 14.8000 - val_huber_loss: 14.8013 - val_mean_squared_error: 426.3669 - val_mean_absolute_error: 15.2927 - val_mean_absolute_percentage_error: 12.8315 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6202
# Epoch 12/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.0792 - huber_loss: 15.0790 - mean_squared_error: 499.6738 - mean_absolute_error: 15.5694 - mean_absolute_percentage_error: 12.7477 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.8997 - val_loss: 14.7861 - val_huber_loss: 14.7874 - val_mean_squared_error: 426.6705 - val_mean_absolute_error: 15.2784 - val_mean_absolute_percentage_error: 12.8011 - val_mean_squared_logarithmic_error: 0.0277 - val_log_cosh: 14.6064
# Epoch 13/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.0717 - huber_loss: 15.0715 - mean_squared_error: 499.2844 - mean_absolute_error: 15.5619 - mean_absolute_percentage_error: 12.7432 - mean_squared_logarithmic_error: 0.0316 - log_cosh: 14.8923 - val_loss: 14.7728 - val_huber_loss: 14.7741 - val_mean_squared_error: 426.3033 - val_mean_absolute_error: 15.2655 - val_mean_absolute_percentage_error: 12.7830 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5931
# Epoch 14/15
# 2043/2043 [==============================] - 21s 10ms/step - loss: 15.0610 - huber_loss: 15.0608 - mean_squared_error: 498.7597 - mean_absolute_error: 15.5512 - mean_absolute_percentage_error: 12.7354 - mean_squared_logarithmic_error: 0.0315 - log_cosh: 14.8815 - val_loss: 14.7645 - val_huber_loss: 14.7658 - val_mean_squared_error: 426.3789 - val_mean_absolute_error: 15.2575 - val_mean_absolute_percentage_error: 12.7656 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5849
# Epoch 15/15
# 2043/2043 [==============================] - 20s 10ms/step - loss: 15.0527 - huber_loss: 15.0525 - mean_squared_error: 498.3808 - mean_absolute_error: 15.5429 - mean_absolute_percentage_error: 12.7297 - mean_squared_logarithmic_error: 0.0315 - log_cosh: 14.8732 - val_loss: 14.7576 - val_huber_loss: 14.7589 - val_mean_squared_error: 426.3223 - val_mean_absolute_error: 15.2508 - val_mean_absolute_percentage_error: 12.7537 - val_mean_squared_logarithmic_error: 0.0276 - val_log_cosh: 14.5779
# 568/568 [==============================] - 3s 5ms/step - loss: 14.8400 - huber_loss: 14.8487 - mean_squared_error: 468.6271 - mean_absolute_error: 15.3400 - mean_absolute_percentage_error: 11.9836 - mean_squared_logarithmic_error: 0.0273 - log_cosh: 14.6688
# 568/568 [==============================] - 4s 7ms/step - loss: 14.8456 - huber_loss: 14.8550 - mean_squared_error: 467.7055 - mean_absolute_error: 15.3464 - mean_absolute_percentage_error: 12.0284 - mean_squared_logarithmic_error: 0.0273 - log_cosh: 14.6751
# 568/568 [==============================] - 2s 3ms/step
# 568/568 [==============================] - 2s 3ms/step
# -------------------------------------------------------
#
# 3-LIB193367
#
# PRETRAINED_MODEL
# Epoch 1/15
# ...
# 452/452 [==============================] - 2s 3ms/step
# -------------------------------------------------------
#
# 4-LIB193310
#
# PRETRAINED_MODEL
# Epoch 1/15
# 1580/1580 [==============================] - 22s 11ms/step - loss: 23.3797 - huber_loss: 23.3798 - mean_squared_error: 1089.3291 - mean_absolute_error: 23.8743 - mean_absolute_percentage_error: 16.9798 - mean_squared_logarithmic_error: 0.0644 - log_cosh: 23.1947 - val_loss: 21.5630 - val_huber_loss: 21.5553 - val_mean_squared_error: 787.8212 - val_mean_absolute_error: 22.0516 - val_mean_absolute_percentage_error: 18.2042 - val_mean_squared_logarithmic_error: 0.0462 - val_log_cosh: 21.3685
# Epoch 2/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.5726 - huber_loss: 21.5737 - mean_squared_error: 944.5177 - mean_absolute_error: 22.0677 - mean_absolute_percentage_error: 15.7711 - mean_squared_logarithmic_error: 0.0461 - log_cosh: 21.3894 - val_loss: 20.2920 - val_huber_loss: 20.2837 - val_mean_squared_error: 740.7222 - val_mean_absolute_error: 20.7791 - val_mean_absolute_percentage_error: 16.7638 - val_mean_squared_logarithmic_error: 0.0430 - val_log_cosh: 20.0973
# Epoch 3/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.3479 - huber_loss: 21.3491 - mean_squared_error: 930.9872 - mean_absolute_error: 21.8427 - mean_absolute_percentage_error: 15.6146 - mean_squared_logarithmic_error: 0.0455 - log_cosh: 21.1649 - val_loss: 19.8313 - val_huber_loss: 19.8235 - val_mean_squared_error: 726.6777 - val_mean_absolute_error: 20.3182 - val_mean_absolute_percentage_error: 16.2269 - val_mean_squared_logarithmic_error: 0.0420 - val_log_cosh: 19.6375
# Epoch 4/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.2330 - huber_loss: 21.2341 - mean_squared_error: 924.5709 - mean_absolute_error: 21.7278 - mean_absolute_percentage_error: 15.5340 - mean_squared_logarithmic_error: 0.0453 - log_cosh: 21.0503 - val_loss: 19.6777 - val_huber_loss: 19.6694 - val_mean_squared_error: 722.7060 - val_mean_absolute_error: 20.1645 - val_mean_absolute_percentage_error: 16.0408 - val_mean_squared_logarithmic_error: 0.0417 - val_log_cosh: 19.4837
# Epoch 5/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.1694 - huber_loss: 21.1706 - mean_squared_error: 920.9258 - mean_absolute_error: 21.6644 - mean_absolute_percentage_error: 15.4863 - mean_squared_logarithmic_error: 0.0452 - log_cosh: 20.9867 - val_loss: 19.5276 - val_huber_loss: 19.5191 - val_mean_squared_error: 719.2335 - val_mean_absolute_error: 20.0135 - val_mean_absolute_percentage_error: 15.8479 - val_mean_squared_logarithmic_error: 0.0414 - val_log_cosh: 19.3340
# Epoch 6/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.1253 - huber_loss: 21.1266 - mean_squared_error: 918.5602 - mean_absolute_error: 21.6204 - mean_absolute_percentage_error: 15.4530 - mean_squared_logarithmic_error: 0.0451 - log_cosh: 20.9427 - val_loss: 19.3953 - val_huber_loss: 19.3867 - val_mean_squared_error: 716.6454 - val_mean_absolute_error: 19.8812 - val_mean_absolute_percentage_error: 15.6770 - val_mean_squared_logarithmic_error: 0.0411 - val_log_cosh: 19.2020
# Epoch 7/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.0911 - huber_loss: 21.0923 - mean_squared_error: 916.7492 - mean_absolute_error: 21.5862 - mean_absolute_percentage_error: 15.4284 - mean_squared_logarithmic_error: 0.0450 - log_cosh: 20.9085 - val_loss: 19.3165 - val_huber_loss: 19.3077 - val_mean_squared_error: 715.2110 - val_mean_absolute_error: 19.8025 - val_mean_absolute_percentage_error: 15.5702 - val_mean_squared_logarithmic_error: 0.0410 - val_log_cosh: 19.1232
# Epoch 8/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.0646 - huber_loss: 21.0659 - mean_squared_error: 915.4691 - mean_absolute_error: 21.5596 - mean_absolute_percentage_error: 15.4090 - mean_squared_logarithmic_error: 0.0450 - log_cosh: 20.8821 - val_loss: 19.2501 - val_huber_loss: 19.2414 - val_mean_squared_error: 714.4263 - val_mean_absolute_error: 19.7356 - val_mean_absolute_percentage_error: 15.4770 - val_mean_squared_logarithmic_error: 0.0409 - val_log_cosh: 19.0568
# Epoch 9/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.0426 - huber_loss: 21.0438 - mean_squared_error: 914.4147 - mean_absolute_error: 21.5375 - mean_absolute_percentage_error: 15.3889 - mean_squared_logarithmic_error: 0.0449 - log_cosh: 20.8600 - val_loss: 19.2030 - val_huber_loss: 19.1941 - val_mean_squared_error: 714.1783 - val_mean_absolute_error: 19.6878 - val_mean_absolute_percentage_error: 15.4000 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 19.0097
# Epoch 10/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.0203 - huber_loss: 21.0215 - mean_squared_error: 913.3804 - mean_absolute_error: 21.5152 - mean_absolute_percentage_error: 15.3737 - mean_squared_logarithmic_error: 0.0449 - log_cosh: 20.8378 - val_loss: 19.1582 - val_huber_loss: 19.1492 - val_mean_squared_error: 713.7166 - val_mean_absolute_error: 19.6428 - val_mean_absolute_percentage_error: 15.3371 - val_mean_squared_logarithmic_error: 0.0408 - val_log_cosh: 18.9650
# Epoch 11/15
# 1580/1580 [==============================] - 17s 11ms/step - loss: 21.0019 - huber_loss: 21.0031 - mean_squared_error: 912.5687 - mean_absolute_error: 21.4967 - mean_absolute_percentage_error: 15.3589 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.8195 - val_loss: 19.1330 - val_huber_loss: 19.1239 - val_mean_squared_error: 713.8223 - val_mean_absolute_error: 19.6176 - val_mean_absolute_percentage_error: 15.2934 - val_mean_squared_logarithmic_error: 0.0407 - val_log_cosh: 18.9399
# Epoch 12/15
# 1580/1580 [==============================] - 17s 11ms/step - loss: 20.9868 - huber_loss: 20.9879 - mean_squared_error: 911.8253 - mean_absolute_error: 21.4815 - mean_absolute_percentage_error: 15.3479 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.8044 - val_loss: 19.1099 - val_huber_loss: 19.1008 - val_mean_squared_error: 713.5413 - val_mean_absolute_error: 19.5944 - val_mean_absolute_percentage_error: 15.2630 - val_mean_squared_logarithmic_error: 0.0407 - val_log_cosh: 18.9169
# Epoch 13/15
# 1580/1580 [==============================] - 17s 11ms/step - loss: 20.9756 - huber_loss: 20.9768 - mean_squared_error: 911.3350 - mean_absolute_error: 21.4704 - mean_absolute_percentage_error: 15.3393 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.7932 - val_loss: 19.0846 - val_huber_loss: 19.0754 - val_mean_squared_error: 713.7050 - val_mean_absolute_error: 19.5689 - val_mean_absolute_percentage_error: 15.2212 - val_mean_squared_logarithmic_error: 0.0407 - val_log_cosh: 18.8918
# Epoch 14/15
# 1580/1580 [==============================] - 18s 11ms/step - loss: 20.9635 - huber_loss: 20.9646 - mean_squared_error: 910.7437 - mean_absolute_error: 21.4583 - mean_absolute_percentage_error: 15.3301 - mean_squared_logarithmic_error: 0.0448 - log_cosh: 20.7811 - val_loss: 19.0627 - val_huber_loss: 19.0534 - val_mean_squared_error: 713.5526 - val_mean_absolute_error: 19.5467 - val_mean_absolute_percentage_error: 15.1889 - val_mean_squared_logarithmic_error: 0.0407 - val_log_cosh: 18.8699
# Epoch 15/15
# 1580/1580 [==============================] - 17s 10ms/step - loss: 20.9539 - huber_loss: 20.9551 - mean_squared_error: 910.3717 - mean_absolute_error: 21.4486 - mean_absolute_percentage_error: 15.3228 - mean_squared_logarithmic_error: 0.0447 - log_cosh: 20.7716 - val_loss: 19.0401 - val_huber_loss: 19.0308 - val_mean_squared_error: 713.4180 - val_mean_absolute_error: 19.5240 - val_mean_absolute_percentage_error: 15.1522 - val_mean_squared_logarithmic_error: 0.0407 - val_log_cosh: 18.8475
#
# FROMTHESCRATCH_MODEL
# Epoch 1/15
# 1580/1580 [==============================] - 23s 11ms/step - loss: 34.4867 - huber_loss: 34.4840 - mean_squared_error: 2225.5557 - mean_absolute_error: 34.9803 - mean_absolute_percentage_error: 25.3119 - mean_squared_logarithmic_error: 0.1844 - log_cosh: 34.2963 - val_loss: 27.0223 - val_huber_loss: 27.0244 - val_mean_squared_error: 1116.3016 - val_mean_absolute_error: 27.5217 - val_mean_absolute_percentage_error: 23.6337 - val_mean_squared_logarithmic_error: 0.0669 - val_log_cosh: 26.8357
# Epoch 2/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 26.0663 - huber_loss: 26.0675 - mean_squared_error: 1290.9541 - mean_absolute_error: 26.5629 - mean_absolute_percentage_error: 18.9759 - mean_squared_logarithmic_error: 0.0605 - log_cosh: 25.8813 - val_loss: 24.3060 - val_huber_loss: 24.3004 - val_mean_squared_error: 941.9550 - val_mean_absolute_error: 24.7967 - val_mean_absolute_percentage_error: 20.8739 - val_mean_squared_logarithmic_error: 0.0562 - val_log_cosh: 24.1122
# Epoch 3/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 24.6695 - huber_loss: 24.6705 - mean_squared_error: 1181.1609 - mean_absolute_error: 25.1657 - mean_absolute_percentage_error: 17.9966 - mean_squared_logarithmic_error: 0.0559 - log_cosh: 24.4846 - val_loss: 23.3497 - val_huber_loss: 23.3443 - val_mean_squared_error: 898.3647 - val_mean_absolute_error: 23.8403 - val_mean_absolute_percentage_error: 19.8778 - val_mean_squared_logarithmic_error: 0.0530 - val_log_cosh: 23.1564
# Epoch 4/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 23.7301 - huber_loss: 23.7313 - mean_squared_error: 1108.5891 - mean_absolute_error: 24.2259 - mean_absolute_percentage_error: 17.3389 - mean_squared_logarithmic_error: 0.0530 - log_cosh: 23.5459 - val_loss: 22.4796 - val_huber_loss: 22.4737 - val_mean_squared_error: 853.1962 - val_mean_absolute_error: 22.9689 - val_mean_absolute_percentage_error: 19.0142 - val_mean_squared_logarithmic_error: 0.0501 - val_log_cosh: 22.2864
# Epoch 5/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 23.0871 - huber_loss: 23.0885 - mean_squared_error: 1058.4908 - mean_absolute_error: 23.5829 - mean_absolute_percentage_error: 16.8765 - mean_squared_logarithmic_error: 0.0510 - log_cosh: 22.9033 - val_loss: 21.6682 - val_huber_loss: 21.6614 - val_mean_squared_error: 812.2326 - val_mean_absolute_error: 22.1566 - val_mean_absolute_percentage_error: 18.1823 - val_mean_squared_logarithmic_error: 0.0477 - val_log_cosh: 21.4748
# Epoch 6/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 22.6546 - huber_loss: 22.6560 - mean_squared_error: 1027.6710 - mean_absolute_error: 23.1504 - mean_absolute_percentage_error: 16.5665 - mean_squared_logarithmic_error: 0.0497 - log_cosh: 22.4710 - val_loss: 21.1739 - val_huber_loss: 21.1664 - val_mean_squared_error: 787.6884 - val_mean_absolute_error: 21.6620 - val_mean_absolute_percentage_error: 17.6571 - val_mean_squared_logarithmic_error: 0.0461 - val_log_cosh: 20.9797
# Epoch 7/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 22.3574 - huber_loss: 22.3589 - mean_squared_error: 1005.8564 - mean_absolute_error: 22.8531 - mean_absolute_percentage_error: 16.3523 - mean_squared_logarithmic_error: 0.0488 - log_cosh: 22.1743 - val_loss: 20.7588 - val_huber_loss: 20.7512 - val_mean_squared_error: 770.7207 - val_mean_absolute_error: 21.2463 - val_mean_absolute_percentage_error: 17.2183 - val_mean_squared_logarithmic_error: 0.0449 - val_log_cosh: 20.5649
# Epoch 8/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 22.1383 - huber_loss: 22.1396 - mean_squared_error: 989.6234 - mean_absolute_error: 22.6338 - mean_absolute_percentage_error: 16.1893 - mean_squared_logarithmic_error: 0.0481 - log_cosh: 21.9551 - val_loss: 20.6399 - val_huber_loss: 20.6319 - val_mean_squared_error: 765.2457 - val_mean_absolute_error: 21.1278 - val_mean_absolute_percentage_error: 17.0994 - val_mean_squared_logarithmic_error: 0.0446 - val_log_cosh: 20.4455
# Epoch 9/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.9715 - huber_loss: 21.9727 - mean_squared_error: 977.7180 - mean_absolute_error: 22.4668 - mean_absolute_percentage_error: 16.0718 - mean_squared_logarithmic_error: 0.0476 - log_cosh: 21.7883 - val_loss: 20.5127 - val_huber_loss: 20.5043 - val_mean_squared_error: 758.3692 - val_mean_absolute_error: 20.9996 - val_mean_absolute_percentage_error: 16.9842 - val_mean_squared_logarithmic_error: 0.0442 - val_log_cosh: 20.3179
# Epoch 10/15
# 1580/1580 [==============================] - 17s 10ms/step - loss: 21.8414 - huber_loss: 21.8424 - mean_squared_error: 968.2011 - mean_absolute_error: 22.3363 - mean_absolute_percentage_error: 15.9784 - mean_squared_logarithmic_error: 0.0472 - log_cosh: 21.6581 - val_loss: 20.3691 - val_huber_loss: 20.3602 - val_mean_squared_error: 752.0631 - val_mean_absolute_error: 20.8548 - val_mean_absolute_percentage_error: 16.8308 - val_mean_squared_logarithmic_error: 0.0437 - val_log_cosh: 20.1743
# Epoch 11/15
# 1580/1580 [==============================] - 17s 11ms/step - loss: 21.7284 - huber_loss: 21.7293 - mean_squared_error: 959.7577 - mean_absolute_error: 22.2233 - mean_absolute_percentage_error: 15.8969 - mean_squared_logarithmic_error: 0.0468 - log_cosh: 21.5451 - val_loss: 20.2012 - val_huber_loss: 20.1922 - val_mean_squared_error: 745.8154 - val_mean_absolute_error: 20.6864 - val_mean_absolute_percentage_error: 16.6455 - val_mean_squared_logarithmic_error: 0.0433 - val_log_cosh: 20.0067
# Epoch 12/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.6279 - huber_loss: 21.6288 - mean_squared_error: 952.3416 - mean_absolute_error: 22.1226 - mean_absolute_percentage_error: 15.8240 - mean_squared_logarithmic_error: 0.0465 - log_cosh: 21.4448 - val_loss: 20.0547 - val_huber_loss: 20.0458 - val_mean_squared_error: 739.8334 - val_mean_absolute_error: 20.5399 - val_mean_absolute_percentage_error: 16.4925 - val_mean_squared_logarithmic_error: 0.0429 - val_log_cosh: 19.8603
# Epoch 13/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.5471 - huber_loss: 21.5479 - mean_squared_error: 946.1181 - mean_absolute_error: 22.0417 - mean_absolute_percentage_error: 15.7676 - mean_squared_logarithmic_error: 0.0462 - log_cosh: 21.3639 - val_loss: 19.9892 - val_huber_loss: 19.9804 - val_mean_squared_error: 736.3318 - val_mean_absolute_error: 20.4749 - val_mean_absolute_percentage_error: 16.4251 - val_mean_squared_logarithmic_error: 0.0426 - val_log_cosh: 19.7948
# Epoch 14/15
# 1580/1580 [==============================] - 16s 10ms/step - loss: 21.4794 - huber_loss: 21.4801 - mean_squared_error: 941.3140 - mean_absolute_error: 21.9739 - mean_absolute_percentage_error: 15.7218 - mean_squared_logarithmic_error: 0.0460 - log_cosh: 21.2962 - val_loss: 19.9235 - val_huber_loss: 19.9146 - val_mean_squared_error: 733.4397 - val_mean_absolute_error: 20.4097 - val_mean_absolute_percentage_error: 16.3562 - val_mean_squared_logarithmic_error: 0.0425 - val_log_cosh: 19.7290
# Epoch 15/15
# 1580/1580 [==============================] - 17s 11ms/step - loss: 21.4202 - huber_loss: 21.4210 - mean_squared_error: 937.5099 - mean_absolute_error: 21.9149 - mean_absolute_percentage_error: 15.6801 - mean_squared_logarithmic_error: 0.0459 - log_cosh: 21.2369 - val_loss: 19.8869 - val_huber_loss: 19.8781 - val_mean_squared_error: 731.5048 - val_mean_absolute_error: 20.3730 - val_mean_absolute_percentage_error: 16.3213 - val_mean_squared_logarithmic_error: 0.0423 - val_log_cosh: 19.6923
# 439/439 [==============================] - 2s 5ms/step - loss: 18.3013 - huber_loss: 18.2952 - mean_squared_error: 656.2681 - mean_absolute_error: 18.7887 - mean_absolute_percentage_error: 14.6304 - mean_squared_logarithmic_error: 0.0386 - log_cosh: 18.1116
# 439/439 [==============================] - 2s 5ms/step - loss: 19.1450 - huber_loss: 19.1385 - mean_squared_error: 666.3676 - mean_absolute_error: 19.6338 - mean_absolute_percentage_error: 15.7974 - mean_squared_logarithmic_error: 0.0400 - log_cosh: 18.9526
# 439/439 [==============================] - 3s 4ms/step
# 439/439 [==============================] - 3s 4ms/step
# -------------------------------------------------------

# %%
for ind in range(0,len(test_patients)):
  np.save(checkpoint_folder+'pretrained_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',pretrained_metrics[ind].history)
  np.save(checkpoint_folder+'fromthescratch_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',fromthescratch_metrics[ind].history)
  np.save(checkpoint_folder+'test_pretrained_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',np.array(test_pretrained_metrics[ind]))
  np.save(checkpoint_folder+'test_fromthescratch_metrics_'+str(ind)+'(ARCHITECTURE_'+str(ARCHITECTURE_NUMBER)+').npy',np.array(test_fromthescratch_metrics[ind]))

# %%
notebook_endtime=time.time()
notebook_time=(notebook_endtime-notebook_startime)

print(notebook_time)
print(optimization_time)
print(pretraining_time)
print(training_time)
# Out:
# 7038.705477952957
# 1560.7023618221283
# 2132.518099784851
# 3089.8946018218994

# %%
print('Notebook Execution Time: '+str(round(notebook_time/3600,2))+' hours')
print('Hyperparameter Optimization Execution Time: '+str(round(optimization_time/3600,2))+' hours')
print('Pretraining Execution Time: '+str(round(pretraining_time/3600,2))+' hours')
print('Training Execution Time: '+str(round(training_time/3600,2))+' hours')
# Out:
# Notebook Execution Time: 1.96 hours
# Hyperparameter Optimization Execution Time: 0.43 hours
# Pretraining Execution Time: 0.59 hours
# Training Execution Time: 0.86 hours
